# %% [markdown]
# # CUARTO NOTEBOOK - TOPIC MODELING LDA EN OBSERVACIONES

# %% [markdown]
# ## I. DISEÑO DEL ALGORITMO

# %% [markdown]
# #### Importar paquetes

# %%
import re, spacy, numpy as np, pandas as pd
from pprint import pprint
from wordcloud import WordCloud
import matplotlib.colors as mcolors

# Gensim
import gensim, gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# Plotting tools
import pyLDAvis, pyLDAvis.sklearn, pyLDAvis.gensim  
import matplotlib.pyplot as plt

# Sklearn
from sklearn.decomposition import LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
warnings.simplefilter('ignore')
pd.options.mode.chained_assignment = None  # default='warn' ---> Not showing warnings about iloc

# Stop Words
with open('spanish2.0.txt','r') as f:
    stop_words = f.read().splitlines()
    
# NLP from Spacy
nlp = spacy.load('es_core_news_md', disable=['parser', 'ner'])

# %% [markdown]
# #### Estructura del algoritmo

# %%
def texts_id2word_corpus(texts, stop_words=stop_words, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV','PROPN']):  
    # Tokenization
    texts = [gensim.utils.simple_preprocess(str(sentence), deacc=True) for sentence in texts]
    # Remove stopwords
    texts = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]
    # lemmatization
    texts_out = []
    for sent in texts:
        doc = nlp(u" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    # Remove stopwords once more after lemmatization
    texts_out = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts_out] 
    # Create Dictionary
    id2word = corpora.Dictionary(texts_out)
    # Create Corpus: Term Document Frequency
    corpus = [id2word.doc2bow(text) for text in texts_out]
    return texts_out,id2word,corpus

def compute_coherence_values(dictionary, corpus, texts, start=2, limit=31,step=4):
    coherence_values = []
    model_list = []
    mallet_path = 'C:/Users/alexa/mallet-2.0.8/bin/mallet.bat' 
    for num_topics in range(start, limit, step):
        model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word, random_seed = 42)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
    return model_list, coherence_values

def plot_coherence(c_values, start=2,limit=31,step=4):
    x = range(start, limit, step)
    plt.rcParams.update({'figure.figsize':(10,7)})
    plt.plot(x, c_values)
    plt.xlabel("Topics")
    plt.ylabel("Coherence score")
    plt.legend(("c_values"), loc='best')
    plt.show()

# %%
def format_topics_sentences(ldamodel, corpus, texts):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)

def plot_freqdist(doc_lens):
    plt.figure(figsize=(10,6))
    plt.hist(doc_lens, bins = 300, color='royalblue')
    plt.text(750, 100, "Mean   : " + str(round(np.mean(doc_lens))))
    plt.text(750,  90, "Median : " + str(round(np.median(doc_lens))))
    plt.text(750,  80, "Stdev   : " + str(round(np.std(doc_lens))))
    plt.text(750,  70, "1%ile    : " + str(round(np.quantile(doc_lens, q=0.01))))
    plt.text(750,  60, "99%ile  : " + str(round(np.quantile(doc_lens, q=0.99))))

    plt.gca().set(xlim=(0, 500), ylabel='Number of Documents', xlabel='Document Word Count')
    plt.tick_params(size=16)
    plt.xticks(np.linspace(0,500,11))
    plt.title('Distribution of Document Word Counts', fontdict=dict(size=18))
    plt.show()
    
def word_cloud(lda_model,figsize = (16,16)):
    # figsize = (width,height)
    from math import floor
    cols = ['#e6194B', '#3cb44b', '#ffe119', '#4363d8', '#f58231', '#911eb4', '#42d4f4', '#f032e6', '#bfef45', '#fabed4', '#469990', '#dcbeff', '#9A6324', '#ffe119', '#800000', '#3cb44b', '#808000', '#f58231', '#000075', '#a9a9a9', '#000000','#e6194B', '#3cb44b', '#ffe119', '#4363d8', '#f58231', '#911eb4', '#42d4f4', '#f032e6', '#bfef45', '#fabed4', '#469990', '#dcbeff', '#9A6324', '#ffe119', '#800000', '#3cb44b', '#808000', '#f58231', '#000075', '#a9a9a9', '#000000']
    cloud = WordCloud(stopwords=stop_words,background_color='white',width=2500,height=1800,max_words=10,colormap='tab10',color_func=lambda *args, **kwargs: cols[i],prefer_horizontal=1.0)
    topics = lda_model.show_topics(formatted=False,num_topics=100)
    
    fig, axes = plt.subplots(floor(len(topics)/3), 3, figsize=figsize, sharex=True, sharey=True)
    
    for i, ax in enumerate(axes.flatten()):
        fig.add_subplot(ax)
        topic_words = dict(topics[i][1])
        cloud.generate_from_frequencies(topic_words, max_font_size=300)
        plt.gca().imshow(cloud)
        plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
        plt.gca().axis('off')
        
    plt.subplots_adjust(wspace=0, hspace=0)
    plt.axis('off')
    plt.margins(x=0, y=0)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# <div class="alert alert-success" style="margin: 20px">En todos los data frames ya está implementada la función word_cleaner() que permitió limpiar la base de datos. Para más información de esta función ir al segundo notebook.</div>

# %% [markdown]
# ## II. RESULTADOS

# %% [markdown]
# ## 1. TIPO DE FALLA

# %%
from IPython.display import Image
Image(filename='OGC_Tiposdefallas.png',width=700, height=500)

# %% [markdown]
# #### 1.1. Importar Data Frame

# %%
# Se trabaja con el data frame que contiene registros en formato de sentences ([sent1,sent2,...,sentn])
pd.reset_option('^display.', silent=True)
df_falla_sentences = pd.read_pickle('df_falla_sentences.pkl')
df_falla_sentences.head()
# Out:
#                                                                                           Observación  \
# Carrete RetractilOTROOTRO                           [se cambia placa de tk 2 gas95 por placa que i...
# SURTIDOR / DISPENSERACCESORIOS & FILTROSOTROS       [se chequea falla y se reajusta correa suelta ...
# PROGRAMA MANTENCIÓN PREVENTIVASURTIDORES / ESTA...  [sello de centrifuga o unidad de bombeo con fi...
# SURTIDOR / DISPENSERCABEZALOTROS                    [se realiza el cambio de 1 motor monofasico 34...
# SURTIDOR / DISPENSERACCESORIOS & FILTROSPISTOLA     [se realiza mantencion correctiva en surtidor ...
#
#                                                                                         Requerimiento
# Carrete RetractilOTROOTRO                           [area de atencion surtidor no marca correctame...
# SURTIDOR / DISPENSERACCESORIOS & FILTROSOTROS       [pistola 4 surte demasiado lento, surtidor 7 n...
# PROGRAMA MANTENCIÓN PREVENTIVASURTIDORES / ESTA...  [mantencion preventiva completa, mantencion pr...
# SURTIDOR / DISPENSERCABEZALOTROS                    [octuple no funciona 50 eds funcionando, se so...
# SURTIDOR / DISPENSERACCESORIOS & FILTROSPISTOLA     [pistola n 5 no entrega suministro, pistola di...

# %%
# Extracto obs tipo de falla
df_falla_sentences['Observación']['SURTIDOR / DISPENSERCABEZALOTROS'][:2]
# Out:
# ['se realiza el cambio de 1 motor monofasico 34 hp proporcionado por sercon quedando equipo operativo',
#  'en dispensador 2 diesel se cambia orings de eje punta del medidor lo que mojaba el pulser y arrojaba error 2 0 se realizan pruebas y se verifica que no alla filtracion equipo queda 100 operativo ambas bocas en dispensador 2 diesel se cambia orings de eje punta del medidor lo que mojaba el pulser y arrojaba error 2 0 se realizan pruebas y se verifica que no alla filtracion equipo queda 100 operativo ambas bocas']

# %%
# Length Sentences
len(df_falla_sentences['Observación']['SURTIDOR / DISPENSERCABEZALOTROS'])
# Out:
# 1561

# %% [markdown]
# #### 1.2. Ejecutar el algoritmo para un tipo de falla

# %%
# Asignar data
data = df_falla_sentences['Observación']['SURTIDOR / DISPENSERCABEZALOTROS']
texts,id2word,corpus = texts_id2word_corpus(texts = data)

# %%
# %%time
# Conocer el mejor n_clusters (Puede tomar varios minutos)
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=texts,start=2, limit=31, step=4)
plot_coherence(c_values = coherence_values,start=2, limit=31, step=4)
# Out:
# Wall time: 4min 58s

# %%
for m, cv in zip(range(2,31,4), coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))
# Out:
# Num Topics = 2  has Coherence Value of 0.3226
# Num Topics = 6  has Coherence Value of 0.4126
# Num Topics = 10  has Coherence Value of 0.3532
# Num Topics = 14  has Coherence Value of 0.3944
# Num Topics = 18  has Coherence Value of 0.389
# Num Topics = 22  has Coherence Value of 0.4014
# Num Topics = 26  has Coherence Value of 0.3973
# Num Topics = 30  has Coherence Value of 0.4192

# %%
# Seleccionar el mejor model y mostrar los tópicos
optimal_model = model_list[1]
#model_topics = optimal_model.show_topics(formatted=False)
pprint(optimal_model.print_topics(num_words=10))
# Out:
# [(0,
#   '0.027*"flujo" + 0.026*"filtracion" + 0.025*"funcionamiento" + '
#   '0.023*"realizar" + 0.022*"presentar" + 0.022*"bombo" + 0.022*"surtidor" + '
#   '0.022*"linear" + 0.020*"incidencia" + 0.019*"filtro"'),
#  (1,
#   '0.110*"dispensador" + 0.054*"venta" + 0.043*"normal" + 0.037*"lado" + '
#   '0.030*"cortar" + 0.029*"fallo" + 0.020*"tablero" + 0.017*"orpak" + '
#   '0.017*"electrico" + 0.016*"operar"'),
#  (2,
#   '0.202*"equipar" + 0.060*"cambiar" + 0.034*"mal" + 0.030*"pos" + '
#   '0.026*"equipo" + 0.026*"reemplazar" + 0.025*"pendiente" + 0.023*"eds" + '
#   '0.021*"ampolleta" + 0.019*"quemar"'),
#  (3,
#   '0.075*"disp" + 0.066*"fallo" + 0.051*"surt" + 0.043*"cliente" + '
#   '0.038*"remplazar" + 0.025*"chequeo" + 0.023*"correar" + 0.021*"revison" + '
#   '0.019*"limpieza" + 0.018*"placa"'),
#  (4,
#   '0.123*"cambiar" + 0.063*"valvula" + 0.049*"medidor" + 0.039*"producto" + '
#   '0.038*"motor" + 0.033*"reponer" + 0.033*"proporcional" + 0.032*"tapar" + '
#   '0.027*"reparacion" + 0.025*"valvulas"'),
#  (5,
#   '0.082*"surtidor" + 0.079*"gas" + 0.077*"boca" + 0.071*"diesel" + '
#   '0.063*"producto" + 0.054*"pistola" + 0.029*"cambiar" + 0.024*"manguera" + '
#   '0.022*"filtrar" + 0.019*"servicio"')]

# %% [markdown]
# #### 1.3. Visualización

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
LDAmallet_gensim = gensim.models.wrappers.ldamallet.malletmodel2ldamodel(optimal_model)
vis = pyLDAvis.gensim.prepare(LDAmallet_gensim, corpus, id2word)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 4     -0.166387  0.105716       1        1  18.248645
# 5     -0.227979 -0.134218       2        1  17.816397
# 0      0.122817 -0.362094       3        1  16.930797
# 1      0.265139  0.017590       4        1  16.908050
# 2     -0.212781  0.127234       5        1  15.186708
# 3      0.219191  0.245773       6        1  14.909403, topic_info=            Term         Freq        Total Category  logprob  loglift
# 1        equipar  1078.000000  1078.000000  Default  30.0000  30.0000
# 10   dispensador   651.000000   651.000000  Default  29.0000  29.0000
# 0        cambiar  1290.000000  1290.000000  Default  28.0000  28.0000
# 266          gas   496.000000   496.000000  Default  27.0000  27.0000
# 8           boca   479.000000   479.000000  Default  26.0000  26.0000
# ..           ...          ...          ...      ...      ...      ...
# 57         fallo   348.396396   569.573286   Topic6  -2.7108   1.4116
# 590        placa    92.701965   149.390492   Topic6  -4.0347   1.4260
# 273        hacer    45.841631    70.374164   Topic6  -4.7389   1.4745
# 259     interior    38.710711    54.476822   Topic6  -4.9080   1.5615
# 497  instalacion    39.729414    90.969276   Topic6  -4.8820   1.0747
#
# [441 rows x 6 columns], token_table=      Topic      Freq           Term
# term
# 1103      4  1.006450          abril
# 449       2  0.978771      accesorio
# 449       3  0.023585      accesorio
# 464       5  1.005494  accionamiento
# 1046      5  1.005494         acerar
# ...     ...       ...            ...
# 220       1  0.999688          wayne
# 1196      6  1.008908          weyne
# 671       1  0.769595            wip
# 671       6  0.228028            wip
# 917       2  0.978293          wyane
#
# [452 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[5, 6, 1, 2, 3, 4])

# %%
# Tópico dominante y su porcentaje de contribución en cada doc
pd.options.display.max_colwidth = 80
df_topic_sents_keywords = format_topics_sentences(ldamodel=LDAmallet_gensim, corpus=corpus, texts=texts)
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic.head(10)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0             4.0              0.2133
# 1            1             4.0              0.2587
# 2            2             1.0              0.4077
# 3            3             4.0              0.1851
# 4            4             0.0              0.2124
# 5            5             1.0              0.3271
# 6            6             1.0              0.2209
# 7            7             4.0              0.2258
# 8            8             0.0              0.2665
# 9            9             2.0              0.5342
#
#                                                                           Keywords  \
# 0  cambiar, valvula, medidor, producto, motor, reponer, proporcional, tapar, re...
# 1  cambiar, valvula, medidor, producto, motor, reponer, proporcional, tapar, re...
# 2  dispensador, venta, normal, lado, cortar, fallo, tablero, orpak, electrico, ...
# 3  cambiar, valvula, medidor, producto, motor, reponer, proporcional, tapar, re...
# 4  flujo, filtracion, funcionamiento, realizar, presentar, bombo, surtidor, lin...
# 5  dispensador, venta, normal, lado, cortar, fallo, tablero, orpak, electrico, ...
# 6  dispensador, venta, normal, lado, cortar, fallo, tablero, orpak, electrico, ...
# 7  cambiar, valvula, medidor, producto, motor, reponer, proporcional, tapar, re...
# 8  flujo, filtracion, funcionamiento, realizar, presentar, bombo, surtidor, lin...
# 9  equipar, cambiar, mal, pos, equipo, reemplazar, pendiente, eds, ampolleta, q...
#
#                                                                               Text
# 0                          [cambiar, motor, monofasico, hp, proporcionar, equipar]
# 1  [dispensador, diesel, cambiar, orings, eje, punta, medidor, mojar, pulser, a...
# 2  [surtidor, boca, detectar, medición, voltages, existir, voltage, alimentacio...
# 3   [cambiar, filtrar, spin, efectua, limpieza, mantencion, valvula, pie, equipar]
# 4                    [tomar, contactar, encargar, coordinar, laborar, dia, sabado]
# 5  [cambiar, pulser, lado, lado, fallo, producir, ahora, lado, solicitar, repon...
# 6  [dispensador, doblar, alto, galonaje, diesel, producto, pulser, trancar, des...
# 7    [equipar, emisor, pulsar, posicion, humedo, secar, fijacion, pulser, equipar]
# 8  [observar, portar, pistola, caro, rotar, permitir, pistola, descansar, corre...
# 9  [totalizador, mecanico, equipar, industrial, engranaje, quebrar, informar, c...

# %%
# Distribución de los tópicos a través de los docs
pd.reset_option('^display.', silent=True)
df_topic_distribution = df_dominant_topic['Dominant_Topic'].value_counts().reset_index(name="Num Documents")
df_topic_distribution.columns = ['Topic Num', 'Num Documents']
df_topic_distribution.sort_values('Topic Num')
# Out:
#    Topic Num  Num Documents
# 2        0.0            283
# 4        1.0            230
# 0        2.0            346
# 1        3.0            288
# 3        4.0            235
# 5        5.0            179

# %%
# La oración más representativa por cada tópico
pd.options.display.max_colwidth = 92
#pd.reset_option('^display.', silent=True)
sent_topics_sorteddf_mallet = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, grp.sort_values(['Perc_Contribution'], ascending=False).head(1)], axis=0)
    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]
sent_topics_sorteddf_mallet
# Out:
#    Topic_Num  Topic_Perc_Contrib  \
# 0        0.0              0.5798
# 1        1.0              0.6256
# 2        2.0              0.5933
# 3        3.0              0.5584
# 4        4.0              0.6118
# 5        5.0              0.8434
#
#                                                                                       Keywords  \
# 0  flujo, filtracion, funcionamiento, realizar, presentar, bombo, surtidor, linear, inciden...
# 1           dispensador, venta, normal, lado, cortar, fallo, tablero, orpak, electrico, operar
# 2            equipar, cambiar, mal, pos, equipo, reemplazar, pendiente, eds, ampolleta, quemar
# 3            disp, fallo, surt, cliente, remplazar, chequeo, correar, revison, limpieza, placa
# 4  cambiar, valvula, medidor, producto, motor, reponer, proporcional, tapar, reparacion, va...
# 5         surtidor, gas, boca, diesel, producto, pistola, cambiar, manguera, filtrar, servicio
#
#                                                                            Representative Text
# 0  [valvula, check, tipo, bombo, sumergir, gas, caidas, repentino, presion, valvula, bueno,...
# 1  [dispensador, isla, bloquear, sistema, orpak, desconeta, alimentador, igem, volver, sist...
# 2  [pos, producto, autoservicio, display, danado, pantalla, quebrar, teceros, visor, quebra...
# 3  [disp, remplazar, wip, disp, remplazar, oring, tapar, superior, med, disp, limpieza, dis...
# 4  [chequeo, calibracion, dispensador, gas, normalidad, surtidor, arrojar, mililitro, surt,...
# 5  [revolución, levantamiento, servicio, isla, manguera, combustible, diesel, pisar, danada...

# %%
# Distribución de la frecuencia de las palabras en los documentos 
doc_lens = [len(d) for d in df_dominant_topic.Text]
plot_freqdist(doc_lens)

# %%
# Nube de palabras
word_cloud(lda_model = optimal_model,figsize=(12,8))

# %% [markdown]
# ## 2. ESTACIONES

# %%
from IPython.display import Image
Image(filename='OGC_Estaciones.png',width=600, height=400)

# %% [markdown]
# #### 2.1. Importar Data Frame

# %%
# Se trabaja con el data frame que contiene registros en formato de sentences ([sent1,sent2,...,sentn])
pd.reset_option('^display.', silent=True)
df_estacion_sentences = pd.read_pickle('df_estacion_sentences.pkl')
df_estacion_sentences.head()
# Out:
#                                                                               Observación  \
# OPERACIONES Y SERVICIOS TERPEL LTDA.    [se chequea falla y se detecta ortirak que cua...
# OPERACIONES Y SERVICIO TERPEL LTDA.     [se solicita tapa spil p15200 para estanque pr...
# Inversiones Enex                        [se rechaza orden por no corresponder a contra...
# SOCIEDAD DE COMBUSTIBLES AUSTRAL LTDA.  [visita se cierra bajo ot 7 visita se cierra b...
# CL - Buses Vule S.A.                    [en surtidor numero 1 se detecto se cambio 01 ...
#
#                                                                             Requerimiento
# OPERACIONES Y SERVICIOS TERPEL LTDA.    [area de atencion surtidor 1 y 2 boton de sele...
# OPERACIONES Y SERVICIO TERPEL LTDA.     [area de atencion tapa spill de estanque diese...
# Inversiones Enex                        [area de atencion se solicita reparacion de br...
# SOCIEDAD DE COMBUSTIBLES AUSTRAL LTDA.  [area de atencion sin venta gas 95 y 97 en tod...
# CL - Buses Vule S.A.                    [area de atencion breakaway esta suelto y filt...

# %%
# Extracto obs estaciones
df_estacion_sentences['Observación']['OPERACIONES Y SERVICIOS TERPEL LTDA.'][:1]
# Out:
# ['se chequea falla y se detecta ortirak que cuando le da el sol directo se borra por completo esto no permite el corrrecto uso del mismo se informa y solicita reparacion a empresa encargada se chequea falla y se detecta ortirak que cuando le da el sol directo se borra por completo esto no permite el corrrecto uso del mismo se informa y solicita reparacion a empresa encargada se niega firma por no estar reparado don marcelo olate']

# %%
len(df_estacion_sentences['Observación']['OPERACIONES Y SERVICIOS TERPEL LTDA.'])
# Out:
# 416

# %% [markdown]
# #### 2.2. Ejecutar el algoritmo para una estación

# %%
# Asignar data
data = df_estacion_sentences['Observación']['OPERACIONES Y SERVICIOS TERPEL LTDA.']
texts,id2word,corpus = texts_id2word_corpus(data)

# %%
# %%time
# Conocer el mejor n_clusters (Puede tomar varios minutos)
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=texts)
plot_coherence(c_values = coherence_values)
# Out:
# Wall time: 4min 59s

# %%
for m, cv in zip(range(2,31,4), coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))
# Out:
# Num Topics = 2  has Coherence Value of 0.3923
# Num Topics = 6  has Coherence Value of 0.4671
# Num Topics = 10  has Coherence Value of 0.462
# Num Topics = 14  has Coherence Value of 0.4895
# Num Topics = 18  has Coherence Value of 0.5406
# Num Topics = 22  has Coherence Value of 0.539
# Num Topics = 26  has Coherence Value of 0.5237
# Num Topics = 30  has Coherence Value of 0.567

# %%
# Seleccionar el mejor model y mostrar los tópicos
optimal_model = model_list[1]
#model_topics = optimal_model.show_topics(formatted=False)
pprint(optimal_model.print_topics(num_words=10))
# Out:
# [(0,
#   '0.139*"dispensador" + 0.131*"cambiar" + 0.076*"venta" + 0.056*"producto" + '
#   '0.037*"detectar" + 0.031*"reponer" + 0.029*"encore" + 0.026*"valvula" + '
#   '0.022*"preset" + 0.020*"filtracion"'),
#  (1,
#   '0.194*"disp" + 0.135*"remplazar" + 0.114*"pistola" + 0.054*"manguera" + '
#   '0.054*"opw" + 0.030*"breckawey" + 0.022*"hose" + 0.021*"conv" + '
#   '0.021*"surt" + 0.019*"swivel"'),
#  (2,
#   '0.076*"boca" + 0.070*"lado" + 0.053*"mantencion" + 0.052*"preventivo" + '
#   '0.047*"tapar" + 0.044*"equipo" + 0.041*"spill" + 0.039*"descargar" + '
#   '0.035*"calibrar" + 0.034*"accesorio"'),
#  (3,
#   '0.087*"gas" + 0.065*"cambiar" + 0.053*"fugar" + 0.046*"detector" + '
#   '0.034*"psi" + 0.024*"diesel" + 0.019*"revolución" + 0.018*"estancar" + '
#   '0.017*"normalmente" + 0.017*"presion"'),
#  (4,
#   '0.161*"fallo" + 0.037*"normal" + 0.034*"operar" + 0.030*"atender" + '
#   '0.029*"ot" + 0.024*"incidencia" + 0.023*"eds" + 0.023*"describir" + '
#   '0.021*"cortar" + 0.019*"encargar"'),
#  (5,
#   '0.122*"equipar" + 0.071*"surtidor" + 0.038*"cliente" + 0.028*"aguar" + '
#   '0.028*"bodega" + 0.023*"revison" + 0.022*"medidor" + 0.021*"breackaway" + '
#   '0.017*"terminal" + 0.017*"display"')]

# %% [markdown]
# #### 2.3. Visualización

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
LDAmallet_gensim = gensim.models.wrappers.ldamallet.malletmodel2ldamodel(optimal_model)
vis = pyLDAvis.gensim.prepare(LDAmallet_gensim, corpus, id2word)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 3     -0.296336  0.073320       1        1  19.275738
# 2      0.103002  0.301926       2        1  17.310964
# 1      0.104945 -0.066282       3        1  16.401965
# 0     -0.284498 -0.075575       4        1  16.116948
# 4      0.228647  0.115488       5        1  15.848830
# 5      0.144240 -0.348878       6        1  15.045555, topic_info=             Term        Freq       Total Category  logprob  loglift
# 38           disp  227.000000  227.000000  Default  30.0000  30.0000
# 7           fallo  182.000000  182.000000  Default  29.0000  29.0000
# 20    dispensador  160.000000  160.000000  Default  28.0000  28.0000
# 375     remplazar  158.000000  158.000000  Default  27.0000  27.0000
# 46        cambiar  240.000000  240.000000  Default  26.0000  26.0000
# ..            ...         ...         ...      ...      ...      ...
# 402      personal    7.462177    7.462177   Topic6  -4.9698   1.8941
# 91      registrar    7.462177    7.462177   Topic6  -4.9698   1.8941
# 787   reconeccion    7.462177    7.462177   Topic6  -4.9698   1.8941
# 382  detectandose    9.594228   10.518797   Topic6  -4.7185   1.8021
# 16        reparar   12.792304   17.640966   Topic6  -4.4308   1.5727
#
# [370 rows x 6 columns], token_table=      Topic      Freq         Term
# term
# 521       5  1.008902       acceso
# 100       2  0.869303    accesorio
# 100       3  0.124186    accesorio
# 522       5  1.008902       achapa
# 550       3  0.927073   activacion
# ...     ...       ...          ...
# 180       2  1.003762  volumetrica
# 569       6  1.055322        wayne
# 266       2  1.003762        whipe
# 295       3  1.021498         wipe
# 156       4  1.031212     wipehose
#
# [349 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[4, 3, 2, 1, 5, 6])

# %%
# Tópico dominante y su porcentaje de contribución en cada doc
pd.options.display.max_colwidth = 80
df_topic_sents_keywords = format_topics_sentences(ldamodel=LDAmallet_gensim, corpus=corpus, texts=texts)
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic.head(10)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0             4.0              0.3398
# 1            1             0.0              0.2754
# 2            2             0.0              0.3081
# 3            3             1.0              0.2792
# 4            4             5.0              0.2108
# 5            5             0.0              0.3505
# 6            6             5.0              0.2389
# 7            7             4.0              0.3562
# 8            8             4.0              0.2138
# 9            9             4.0              0.1845
#
#                                                                           Keywords  \
# 0  fallo, normal, operar, atender, ot, incidencia, eds, describir, cortar, enca...
# 1  dispensador, cambiar, venta, producto, detectar, reponer, encore, valvula, p...
# 2  dispensador, cambiar, venta, producto, detectar, reponer, encore, valvula, p...
# 3     disp, remplazar, pistola, manguera, opw, breckawey, hose, conv, surt, swivel
# 4  equipar, surtidor, cliente, aguar, bodega, revison, medidor, breackaway, ter...
# 5  dispensador, cambiar, venta, producto, detectar, reponer, encore, valvula, p...
# 6  equipar, surtidor, cliente, aguar, bodega, revison, medidor, breackaway, ter...
# 7  fallo, normal, operar, atender, ot, incidencia, eds, describir, cortar, enca...
# 8  fallo, normal, operar, atender, ot, incidencia, eds, describir, cortar, enca...
# 9  fallo, normal, operar, atender, ot, incidencia, eds, describir, cortar, enca...
#
#                                                                               Text
# 0  [fallo, ortirak, sol, directo, borrar, completar, permitir, corrrecto, usar,...
# 1  [dispensador, producto, detectar, union, manguera, pistola, suelto, filtraci...
# 2  [dispensador, detectar, reconecto, breakaways, desconectar, tiron, cliente, ...
# 3  [disp, gun, encargar, disp, recibio, reclamo, disp, entregar, real, coordina...
# 4  [fallo, surtidor, lento, fugar, reapriete, sellar, diesel, cambiar, filtro, ...
# 5  [dispensador, producto, detectar, reconecto, breakaways, desconectar, tirarl...
# 6  [fallo, fugar, teeminal, superior, reapriete, fallo, fugar, terminal, superi...
# 7  [disp, cheque, dispenzador, caida, diferencial, activar, palanca, partir, ga...
# 8                                                         [incidencia, cerrar, ot]
# 9                         [incidencia, corresponder, sgs, favor, ver, contratista]

# %%
# Distribución de los tópicos a través de los docs
pd.reset_option('^display.', silent=True)
df_topic_distribution = df_dominant_topic['Dominant_Topic'].value_counts().reset_index(name="Num Documents")
df_topic_distribution.columns = ['Topic Num', 'Num Documents']
df_topic_distribution.sort_values('Topic Num')
# Out:
#    Topic Num  Num Documents
# 3        0.0             62
# 2        1.0             70
# 4        2.0             55
# 5        3.0             36
# 1        4.0             91
# 0        5.0            102

# %%
# La oración más representativa por cada tópico
pd.options.display.max_colwidth = 92
#pd.reset_option('^display.', silent=True)
sent_topics_sorteddf_mallet = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, grp.sort_values(['Perc_Contribution'], ascending=False).head(1)], axis=0)
    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]
sent_topics_sorteddf_mallet
# Out:
#    Topic_Num  Topic_Perc_Contrib  \
# 0        0.0              0.6454
# 1        1.0              0.6527
# 2        2.0              0.5494
# 3        3.0              0.7037
# 4        4.0              0.5894
# 5        5.0              0.6070
#
#                                                                                       Keywords  \
# 0  dispensador, cambiar, venta, producto, detectar, reponer, encore, valvula, preset, filtr...
# 1                 disp, remplazar, pistola, manguera, opw, breckawey, hose, conv, surt, swivel
# 2     boca, lado, mantencion, preventivo, tapar, equipo, spill, descargar, calibrar, accesorio
# 3       gas, cambiar, fugar, detector, psi, diesel, revolución, estancar, normalmente, presion
# 4             fallo, normal, operar, atender, ot, incidencia, eds, describir, cortar, encargar
# 5   equipar, surtidor, cliente, aguar, bodega, revison, medidor, breackaway, terminal, display
#
#                                                                            Representative Text
# 0  [cambiar, valvula, proporcional, encore, producto, dispensador, entregar, pendiente, cam...
# 1  [inspeccion, visual, accesorio, disp, reclamar, cliente, partir, marcar, wipe, hose, bre...
# 2  [mantencion, preventivo, lado, verificacion, volumetrica, matraz, boca, interior, equipo...
# 3  [normalizacion, detector, fugar, tk, gas, detector, fugar, stpmldg, operacion, psi, pde,...
# 4  [eds, dispensador, estan, flujo, normal, valorar, voltage, corriente, suministrar, suger...
# 5  [surtidor, kerosenne, fallo, segmento, display, volumen, precio, soltar, terminal, detec...

# %%
# Distribución de la frecuencia de las palabras en los documentos 
doc_lens = [len(d) for d in df_dominant_topic.Text]
plot_freqdist(doc_lens)

# %%
# Nube de palabras
word_cloud(lda_model = optimal_model,figsize=(12,8))

# %% [markdown]
# ## 3. TÉCNICOS ASIGNADOS

# %%
from IPython.display import Image
Image(filename='OGC_Tecnicos.png',width=500, height=400)

# %% [markdown]
# #### 3.1. Importar Data Frame

# %%
pd.reset_option('^display.', silent=True)
df_tecnico_sentences = pd.read_pickle('df_tecnico_sentences.pkl')
df_tecnico_sentences.head()
# Out:
#                                                       Observación  \
# On Line         [cambio de graficas de equipos no esta contemp...
# No Asignado     [chequeo funcionamiento y verificacion volumet...
# Luis Carvajal   [se chequea falla se realiza cambio y verifica...
# Carlos Urzua    [surt 2d se realizo reinstalacion de calzo de ...
# Jonatan Castro  [trabajo lo debe realizar gilbarco ya que surt...
#
#                                                     Requerimiento
# On Line         [area de atencion combustible maria veronica g...
# No Asignado     [programacion mantencion preventiva, programac...
# Luis Carvajal   [area de atencion maquina alto octanaje no fun...
# Carlos Urzua    [area de atencion surtidores no entregan produ...
# Jonatan Castro  [area de atencion combustible estimados tecnic...

# %%
# Extracto obs tecnico
df_tecnico_sentences['Observación']['On Line'][:2]
# Out:
# ['cambio de graficas de equipos no esta contemplado en estaciones delegadas',
#  'remplazo de graficas no esta contemplado en estaciones delegadas']

# %%
len(df_tecnico_sentences['Observación']['On Line'])
# Out:
# 1302

# %% [markdown]
# #### 3.2. Ejecutar el algoritmo para un técnico asignado

# %%
# Asignar data
data = df_tecnico_sentences['Observación']['On Line']
texts,id2word,corpus = texts_id2word_corpus(data)

# %%
# %%time
# Conocer el mejor n_clusters (Puede tomar varios minutos)
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=texts)
plot_coherence(c_values = coherence_values)
# Out:
# Wall time: 4min 59s

# %%
for m, cv in zip(range(2,31,4), coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))
# Out:
# Num Topics = 2  has Coherence Value of 0.3465
# Num Topics = 6  has Coherence Value of 0.5463
# Num Topics = 10  has Coherence Value of 0.6271
# Num Topics = 14  has Coherence Value of 0.606
# Num Topics = 18  has Coherence Value of 0.6297
# Num Topics = 22  has Coherence Value of 0.6343
# Num Topics = 26  has Coherence Value of 0.6373
# Num Topics = 30  has Coherence Value of 0.6479

# %%
# Seleccionar el mejor model y mostrar los tópicos
optimal_model = model_list[2]
#model_topics = optimal_model.show_topics(formatted=False)
pprint(optimal_model.print_topics(num_words=10))
# Out:
# [(0,
#   '0.356*"mal" + 0.273*"ods" + 0.153*"emitir" + 0.047*"ingresar" + '
#   '0.047*"periodo" + 0.019*"pi" + 0.011*"horario" + 0.004*"crear" + '
#   '0.004*"adecuar" + 0.004*"operador"'),
#  (1,
#   '0.398*"incidencia" + 0.171*"contratar" + 0.152*"ot" + 0.046*"combustible" + '
#   '0.023*"derivar" + 0.017*"file" + 0.010*"gonzalez" + 0.010*"inicidencia" + '
#   '0.008*"retirar" + 0.008*"tecnico"'),
#  (2,
#   '0.367*"mal" + 0.311*"emitir" + 0.221*"ods" + 0.006*"liberar" + '
#   '0.006*"error" + 0.006*"administracion" + 0.004*"cortar" + 0.004*"trabajo" + '
#   '0.004*"vez" + 0.004*"detector"'),
#  (3,
#   '0.111*"mantencion" + 0.079*"eds" + 0.075*"preventivo" + 0.068*"informar" + '
#   '0.047*"contar" + 0.045*"vencer" + 0.041*"envia" + 0.038*"petrobras" + '
#   '0.032*"dar" + 0.028*"correar"'),
#  (4,
#   '0.201*"corresponder" + 0.116*"servicio" + 0.106*"cambiar" + 0.089*"sgs" + '
#   '0.061*"accesorio" + 0.061*"realizar" + 0.057*"delegar" + 0.040*"reemplazar" '
#   '+ 0.021*"filtro" + 0.013*"veeder"'),
#  (5,
#   '0.326*"emitir" + 0.303*"ods" + 0.258*"mal" + 0.012*"cocar" + 0.010*"tabla" '
#   '+ 0.008*"pintar" + 0.008*"hacer" + 0.006*"nuevo" + 0.004*"sump" + '
#   '0.004*"equivocacion"'),
#  (6,
#   '0.441*"incidencia" + 0.229*"atender" + 0.082*"contratista" + 0.030*"ot" + '
#   '0.022*"vestir" + 0.016*"gilbarco" + 0.010*"codo" + 0.010*"calibracion" + '
#   '0.010*"eess" + 0.010*"calibrar"'),
#  (7,
#   '0.255*"cerrar" + 0.132*"mp" + 0.108*"duplicar" + 0.071*"sistema" + '
#   '0.069*"csim" + 0.066*"sysqmr" + 0.066*"enlazar" + 0.066*"automaticas" + '
#   '0.064*"crear" + 0.009*"red"'),
#  (8,
#   '0.417*"ot" + 0.244*"atender" + 0.088*"sera" + 0.040*"dentro" + '
#   '0.032*"atendera" + 0.019*"rechazar" + 0.017*"esperar" + 0.011*"flavio" + '
#   '0.010*"partir" + 0.006*"emergencia"'),
#  (9,
#   '0.132*"asignar" + 0.116*"cliente" + 0.102*"reasignar" + 0.067*"orden" + '
#   '0.059*"error" + 0.059*"anular" + 0.059*"cargar" + 0.053*"requerimiento" + '
#   '0.049*"enex" + 0.031*"equipar"')]

# %% [markdown]
# #### 3.3. Visualización

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
LDAmallet_gensim = gensim.models.wrappers.ldamallet.malletmodel2ldamodel(optimal_model)
vis = pyLDAvis.gensim.prepare(LDAmallet_gensim, corpus, id2word)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 7      0.071984 -0.244317       1        1  10.570090
# 4      0.084630 -0.212221       2        1  10.366833
# 3      0.085816 -0.232352       3        1  10.319743
# 6      0.276517  0.237249       4        1   9.951192
# 9      0.055439 -0.210099       5        1   9.931454
# 1      0.266183  0.219854       6        1   9.915355
# 8      0.242161  0.169948       7        1   9.894448
# 5     -0.361515  0.094516       8        1   9.694918
# 0     -0.357700  0.089314       9        1   9.680667
# 2     -0.363515  0.088109      10        1   9.675299, topic_info=             Term        Freq       Total Category  logprob  loglift
# 25     incidencia  422.000000  422.000000  Default  30.0000  30.0000
# 61            mal  483.000000  483.000000  Default  29.0000  29.0000
# 60         emitir  387.000000  387.000000  Default  28.0000  28.0000
# 147           ods  391.000000  391.000000  Default  27.0000  27.0000
# 26             ot  300.000000  300.000000  Default  26.0000  26.0000
# ..            ...         ...         ...      ...      ...      ...
# 96        estimar    0.940603    2.989597  Topic10  -6.2558   1.1792
# 97        pistola    0.940603    4.918482  Topic10  -6.2558   0.6814
# 46   comunicacion    0.940603    3.169579  Topic10  -6.2558   1.1208
# 234      reportar    0.940603    1.965100  Topic10  -6.2558   1.5988
# 363      taendida    0.940603    2.953093  Topic10  -6.2558   1.1915
#
# [491 rows x 6 columns], token_table=      Topic      Freq        Term
# term
# 241       1  1.075881       abrir
# 82        2  1.005561   accesorio
# 187      10  1.063148   acesorios
# 443       7  1.047583     acordar
# 415       8  0.993794  actualizar
# ...     ...       ...         ...
# 448       8  0.993794         wes
# 475       7  1.047583       whipe
# 202       5  0.976089    wipehose
# 272       8  0.513651        zona
# 272      10  0.513651        zona
#
# [496 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[8, 5, 4, 7, 10, 2, 9, 6, 1, 3])

# %%
# Tópico dominante y su porcentaje de contribución en cada doc
pd.options.display.max_colwidth = 80
df_topic_sents_keywords = format_topics_sentences(ldamodel=LDAmallet_gensim, corpus=corpus, texts=texts)
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic.head(10)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0             4.0              0.1599
# 1            1             3.0              0.1273
# 2            2             3.0              0.1250
# 3            3             4.0              0.1273
# 4            4             1.0              0.1132
# 5            5             9.0              0.1379
# 6            6             9.0              0.1296
# 7            7             4.0              0.1111
# 8            8             1.0              0.1321
# 9            9             1.0              0.1250
#
#                                                                           Keywords  \
# 0  corresponder, servicio, cambiar, sgs, accesorio, realizar, delegar, reemplaz...
# 1  mantencion, eds, preventivo, informar, contar, vencer, envia, petrobras, dar...
# 2  mantencion, eds, preventivo, informar, contar, vencer, envia, petrobras, dar...
# 3  corresponder, servicio, cambiar, sgs, accesorio, realizar, delegar, reemplaz...
# 4  incidencia, contratar, ot, combustible, derivar, file, gonzalez, inicidencia...
# 5  asignar, cliente, reasignar, orden, error, anular, cargar, requerimiento, en...
# 6  asignar, cliente, reasignar, orden, error, anular, cargar, requerimiento, en...
# 7  corresponder, servicio, cambiar, sgs, accesorio, realizar, delegar, reemplaz...
# 8  incidencia, contratar, ot, combustible, derivar, file, gonzalez, inicidencia...
# 9  incidencia, contratar, ot, combustible, derivar, file, gonzalez, inicidencia...
#
#                                                                              Text
# 0                    [cambiar, graficas, equipo, contemplar, estacionar, delegar]
# 1                          [remplazar, graficas, contemplar, estacionar, delegar]
# 2               [remplazar, graficas, contemplar, contratar, estacionar, delegar]
# 3                                 [rechazar, orden, corresponder, contratar, sgs]
# 4                                                    [orden, rechazar, contratar]
# 5  [consola, integrar, opw, requerimiento, atender, sgs, corresponder, contratar]
# 6                                             [file, contratar, orden, reasignar]
# 7                                       [trabajo, realizar, empresa, contratista]
# 8                                                     [rechazar, file, contratar]
# 9                  [sustitucion, graficas, estan, contemplar, contratar, delegar]

# %%
# Distribución de los tópicos a través de los docs
pd.reset_option('^display.', silent=True)
df_topic_distribution = df_dominant_topic['Dominant_Topic'].value_counts().reset_index(name="Num Documents")
df_topic_distribution.columns = ['Topic Num', 'Num Documents']
df_topic_distribution.sort_values('Topic Num')
# Out:
#    Topic Num  Num Documents
# 9        0.0             43
# 7        1.0             65
# 5        2.0             99
# 6        3.0             87
# 4        4.0            114
# 0        5.0            301
# 8        6.0             57
# 3        7.0            118
# 1        8.0            228
# 2        9.0            190

# %%
# La oración más representativa por cada tópico
pd.options.display.max_colwidth = 92
#pd.reset_option('^display.', silent=True)
sent_topics_sorteddf_mallet = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, grp.sort_values(['Perc_Contribution'], ascending=False).head(1)], axis=0)
    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]
sent_topics_sorteddf_mallet
# Out:
#    Topic_Num  Topic_Perc_Contrib  \
# 0        0.0              0.1376
# 1        1.0              0.1546
# 2        2.0              0.1154
# 3        3.0              0.2243
# 4        4.0              0.2174
# 5        5.0              0.1306
# 6        6.0              0.1462
# 7        7.0              0.2370
# 8        8.0              0.1547
# 9        9.0              0.1724
#
#                                                                                       Keywords  \
# 0                   mal, ods, emitir, ingresar, periodo, pi, horario, crear, adecuar, operador
# 1  incidencia, contratar, ot, combustible, derivar, file, gonzalez, inicidencia, retirar, t...
# 2             mal, emitir, ods, liberar, error, administracion, cortar, trabajo, vez, detector
# 3        mantencion, eds, preventivo, informar, contar, vencer, envia, petrobras, dar, correar
# 4  corresponder, servicio, cambiar, sgs, accesorio, realizar, delegar, reemplazar, filtro, ...
# 5                     emitir, ods, mal, cocar, tabla, pintar, hacer, nuevo, sump, equivocacion
# 6    incidencia, atender, contratista, ot, vestir, gilbarco, codo, calibracion, eess, calibrar
# 7                cerrar, mp, duplicar, sistema, csim, sysqmr, enlazar, automaticas, crear, red
# 8           ot, atender, sera, dentro, atendera, rechazar, esperar, flavio, partir, emergencia
# 9      asignar, cliente, reasignar, orden, error, anular, cargar, requerimiento, enex, equipar
#
#                                                                            Representative Text
# 0                                                               [ods, aparecer, csim, periodo]
# 1  [alarmar, corresponder, tank, sump, diesel, aguar, traer, bombo, tambor, extraer, aguaco...
# 2                                                                              [eeror, cargar]
# 3  [dar, cerrar, online, deber, correar, electronico, indicar, alejandro, padilla, producir...
# 4  [conversar, don, rodrigar, delgado, envio, documentar, guia, cambiar, hora, equipar, vee...
# 5  [esperar, retirar, aguar, sump, camara, cabezal, boma, sumergir, sump, dispenser, reubic...
# 6        [cerrar, incidencia, cliente, alejar, padilla, informar, vera, garantia, contratista]
# 7                   [cerrar, enlazar, sistema, sysqmr, csim, crear, automaticas, duplicar, mp]
# 8                        [retirar, contaminar, dispenser, sump, incidencia, sera, atender, ot]
# 9                        [incidencia, mal, asignar, cliente, cerrar, orden, rodrigar, delgado]

# %%
# Distribución de la frecuencia de las palabras en los documentos 
doc_lens = [len(d) for d in df_dominant_topic.Text]
plot_freqdist(doc_lens)

# %%
# Nube de palabras
word_cloud(lda_model = optimal_model,figsize=(12,12))

# %% [markdown]
# ## 4. PRIORIDAD

# %%
from IPython.display import Image
Image(filename='OGC_Prioridad.png',width=500, height=400)

# %% [markdown]
# #### 4.1. Importar Data Frame

# %%
pd.reset_option('^display.', silent=True)
df_prioridad_sentences = pd.read_pickle('df_prioridad_sentences.pkl')
df_prioridad_sentences.head()
# Out:
#                                                              Observación  \
# Normal 24 Horas        [se visita eds para chequeo de dispensador el ...
# Mantención Preventiva  [sello de centrifuga o unidad de bombeo con fi...
# Normal (48 hrs)        [cambio de graficas de equipos no esta contemp...
# Urgencia (24 hrs)      [trabajo lo debe realizar gilbarco ya que surt...
# Normal 48 Horas        [se cambia placa de tk 2 gas95 por placa que i...
#
#                                                            Requerimiento
# Normal 24 Horas        [area de atencion surtidor no marca correctame...
# Mantención Preventiva  [area de atencion mantencion preventiva solici...
# Normal (48 hrs)        [area de atencion combustible tecnico para tom...
# Urgencia (24 hrs)      [area de atencion combustible filtros tapados ...
# Normal 48 Horas        [area de atencion habilitar estanque de combus...

# %%
# Extracto obs tecnico
df_prioridad_sentences['Observación']['Emergencia 4 Horas'][:1]
# Out:
# ['se realiza mantencion correctiva en surtidor lado 5 el cual presentaba problemas en pistola la cual no despachada combustible se procede a cambiar accsesorio quedando en optimas condiciones de funcionamiento se realiza mantencion correctiva en surtidor lado 5 el cual presentaba problemas en pistola la cual no despachada combustible se procede a cambiar accsesorio quedando en optimas condiciones de funcionamiento']

# %%
len(df_prioridad_sentences['Observación']['Emergencia 4 Horas'])
# Out:
# 632

# %% [markdown]
# #### 4.2. Ejecutar el algoritmo para una prioridad

# %%
# Asignar data
data = df_prioridad_sentences['Observación']['Emergencia 4 Horas']
texts,id2word,corpus = texts_id2word_corpus(data)

# %%
# %%time
# Conocer el mejor n_clusters (Puede tomar varios minutos)
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=texts)
plot_coherence(c_values = coherence_values)
# Out:
# Wall time: 5min 1s

# %%
for m, cv in zip(range(2,31,4), coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))
# Out:
# Num Topics = 2  has Coherence Value of 0.2722
# Num Topics = 6  has Coherence Value of 0.3734
# Num Topics = 10  has Coherence Value of 0.3314
# Num Topics = 14  has Coherence Value of 0.3545
# Num Topics = 18  has Coherence Value of 0.3917
# Num Topics = 22  has Coherence Value of 0.4361
# Num Topics = 26  has Coherence Value of 0.4284
# Num Topics = 30  has Coherence Value of 0.4364

# %%
# Seleccionar el mejor model y mostrar los tópicos
optimal_model = model_list[1]
#model_topics = optimal_model.show_topics(formatted=False)
pprint(optimal_model.print_topics(num_words=10))
# Out:
# [(0,
#   '0.178*"equipar" + 0.132*"cambiar" + 0.083*"pistola" + 0.034*"lado" + '
#   '0.029*"operar" + 0.026*"cargar" + 0.025*"manguera" + 0.018*"cano" + '
#   '0.018*"revison" + 0.016*"malo"'),
#  (1,
#   '0.091*"dispensador" + 0.055*"venta" + 0.042*"producto" + 0.034*"cambiar" + '
#   '0.030*"detectar" + 0.020*"servicio" + 0.018*"reparar" + 0.018*"recircula" + '
#   '0.017*"orpak" + 0.016*"pulser"'),
#  (2,
#   '0.082*"fallo" + 0.052*"disp" + 0.043*"filtrar" + 0.037*"remplazar" + '
#   '0.034*"chequeo" + 0.028*"alto" + 0.028*"cliente" + 0.024*"surt" + '
#   '0.023*"reparacion" + 0.020*"sacar"'),
#  (3,
#   '0.045*"normal" + 0.039*"tablero" + 0.036*"electrico" + 0.023*"encargar" + '
#   '0.022*"aguar" + 0.020*"realizar" + 0.019*"electrica" + 0.018*"informar" + '
#   '0.017*"observar" + 0.017*"eds"'),
#  (4,
#   '0.105*"surtidor" + 0.061*"cambiar" + 0.061*"boca" + 0.051*"medidor" + '
#   '0.046*"tapar" + 0.039*"diesel" + 0.034*"reponer" + 0.032*"filtro" + '
#   '0.025*"wayne" + 0.024*"filtracion"'),
#  (5,
#   '0.062*"diesel" + 0.053*"motor" + 0.038*"bombo" + 0.038*"valvula" + '
#   '0.033*"reemplazar" + 0.030*"producto" + 0.028*"linear" + 0.026*"estancar" + '
#   '0.026*"equipo" + 0.026*"funcionamiento"')]

# %% [markdown]
# #### 4.3. Visualización

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
LDAmallet_gensim = gensim.models.wrappers.ldamallet.malletmodel2ldamodel(optimal_model)
vis = pyLDAvis.gensim.prepare(LDAmallet_gensim, corpus, id2word)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 3      0.301513  0.206759       1        1  17.938938
# 5     -0.021972  0.260059       2        1  17.372614
# 1     -0.184375  0.041822       3        1  17.180309
# 4     -0.220275 -0.010175       4        1  17.120330
# 2      0.253056 -0.301661       5        1  15.383808
# 0     -0.127947 -0.196803       6        1  15.004001, topic_info=             Term        Freq       Total Category  logprob  loglift
# 57        equipar  315.000000  315.000000  Default  30.0000  30.0000
# 1         cambiar  427.000000  427.000000  Default  29.0000  29.0000
# 12       surtidor  214.000000  214.000000  Default  28.0000  28.0000
# 17    dispensador  184.000000  184.000000  Default  27.0000  27.0000
# 10        pistola  146.000000  146.000000  Default  26.0000  26.0000
# ..            ...         ...         ...      ...      ...      ...
# 388  detectandose   23.340654   26.342064   Topic6  -4.3313   1.7759
# 1         cambiar  234.340161  427.188080   Topic6  -2.0247   1.2964
# 191           mal   28.008784   39.013955   Topic6  -4.1489   1.5655
# 114         fallo   18.672523  167.077385   Topic6  -4.5544  -0.2946
# 569  recirculando   10.269888   20.250981   Topic6  -5.1522   1.2179
#
# [381 rows x 6 columns], token_table=      Topic      Freq            Term
# term
# 104       6  0.985405       accesorio
# 534       3  0.969857      activacion
# 591       1  0.999530         activar
# 363       2  1.007608          adblue
# 440       1  0.999530  administracion
# ...     ...       ...             ...
# 164       2  0.968886          voltio
# 164       3  0.031254          voltio
# 187       4  1.001894           wayne
# 127       3  1.026907             wip
# 551       5  0.977057            wipe
#
# [383 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[4, 6, 2, 5, 3, 1])

# %%
# Tópico dominante y su porcentaje de contribución en cada doc
pd.options.display.max_colwidth = 80
df_topic_sents_keywords = format_topics_sentences(ldamodel=LDAmallet_gensim, corpus=corpus, texts=texts)
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic.head(10)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0             0.0              0.2049
# 1            1             1.0              0.2844
# 2            2             2.0              0.3567
# 3            3             3.0              0.4744
# 4            4             5.0              0.2376
# 5            5             5.0              0.1927
# 6            6             1.0              0.2202
# 7            7             3.0              0.1987
# 8            8             3.0              0.2426
# 9            9             0.0              0.2655
#
#                                                                           Keywords  \
# 0   equipar, cambiar, pistola, lado, operar, cargar, manguera, cano, revison, malo
# 1  dispensador, venta, producto, cambiar, detectar, servicio, reparar, recircul...
# 2  fallo, disp, filtrar, remplazar, chequeo, alto, cliente, surt, reparacion, s...
# 3  normal, tablero, electrico, encargar, aguar, realizar, electrica, informar, ...
# 4  diesel, motor, bombo, valvula, reemplazar, producto, linear, estancar, equip...
# 5  diesel, motor, bombo, valvula, reemplazar, producto, linear, estancar, equip...
# 6  dispensador, venta, producto, cambiar, detectar, servicio, reparar, recircul...
# 7  normal, tablero, electrico, encargar, aguar, realizar, electrica, informar, ...
# 8  normal, tablero, electrico, encargar, aguar, realizar, electrica, informar, ...
# 9   equipar, cambiar, pistola, lado, operar, cargar, manguera, cano, revison, malo
#
#                                                                               Text
# 0  [mantencion, correctivo, surtidor, lado, presentar, pistola, despachar, comb...
# 1  [dispensador, detectar, cambiar, pistola, convencional, cano, quebrar, recir...
# 2  [disp, remplazar, breckawey, opw, reconectable, est, remplazar, tapar, opw, ...
# 3  [asistir, industrial, llamar, surtidor, administrador, comentar, display, co...
# 4  [flujo, irregular, ocasionar, escuchar, bombo, forzar, valvula, retencion, s...
# 5  [pos, detectar, filtro, saturar, xmin, app, cambiar, filtro, spin, on, pos, ...
# 6                         [servicio, repetir, servicio, repetir, atender, equipar]
# 7                                                                 [cerrar, cerrar]
# 8  [eds, llamar, turnar, emergencia, diesel, dispensador, despachar, diesel, ch...
# 9  [cambiar, accesorio, pistola, pulgada, rotar, cano, pistola, nuevo, cambiar,...

# %%
# Distribución de los tópicos a través de los docs
pd.reset_option('^display.', silent=True)
df_topic_distribution = df_dominant_topic['Dominant_Topic'].value_counts().reset_index(name="Num Documents")
df_topic_distribution.columns = ['Topic Num', 'Num Documents']
df_topic_distribution.sort_values('Topic Num')
# Out:
#    Topic Num  Num Documents
# 0        0.0            193
# 4        1.0             85
# 1        2.0            100
# 3        3.0             85
# 2        4.0             88
# 5        5.0             81

# %%
# La oración más representativa por cada tópico
pd.options.display.max_colwidth = 92
#pd.reset_option('^display.', silent=True)
sent_topics_sorteddf_mallet = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, grp.sort_values(['Perc_Contribution'], ascending=False).head(1)], axis=0)
    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]
sent_topics_sorteddf_mallet
# Out:
#    Topic_Num  Topic_Perc_Contrib  \
# 0        0.0              0.4607
# 1        1.0              0.6318
# 2        2.0              0.6287
# 3        3.0              0.6692
# 4        4.0              0.5655
# 5        5.0              0.6251
#
#                                                                                       Keywords  \
# 0               equipar, cambiar, pistola, lado, operar, cargar, manguera, cano, revison, malo
# 1  dispensador, venta, producto, cambiar, detectar, servicio, reparar, recircula, orpak, pu...
# 2             fallo, disp, filtrar, remplazar, chequeo, alto, cliente, surt, reparacion, sacar
# 3    normal, tablero, electrico, encargar, aguar, realizar, electrica, informar, observar, eds
# 4          surtidor, cambiar, boca, medidor, tapar, diesel, reponer, filtro, wayne, filtracion
# 5  diesel, motor, bombo, valvula, reemplazar, producto, linear, estancar, equipo, funcionam...
#
#                                                                            Representative Text
# 0  [permitir, ingresar, porteria, falto, autorizacion, comercial, agurto, ingresar, tecnico...
# 1  [dispensador, gilbarco, venta, kerosene, desconectar, orpak, dispensador, funcionar, pro...
# 2  [disp, dispenzador, cortar, activo, diferencial, general, cabezal, interior, cabezal, mo...
# 3  [eds, existir, diesel, kerosenne, tablero, electrico, fallo, fase, alimentar, eds, deber...
# 4  [asiiste, iti, encargar, comentar, contar, bien, llamar, hacer, ocaciones, diferencial, ...
# 5  [iniciar, hrs, registrar, iniciar, posterior, fallo, app, surtidor, gas, surtidor, desce...

# %%
# Distribución de la frecuencia de las palabras en los documentos 
doc_lens = [len(d) for d in df_dominant_topic.Text]
plot_freqdist(doc_lens)

# %%
# Nube de palabras
word_cloud(lda_model = optimal_model,figsize=(12,8))

# %% [markdown]
# ## 5. ESTADO OT

# %%
from IPython.display import Image
Image(filename='OGC_EstadoOT.png',width=500, height=400)

# %% [markdown]
# #### 5.1. Importar Data Frame

# %%
pd.reset_option('^display.', silent=True)
df_estadoot_sentences = pd.read_pickle('df_estadoot_sentences.pkl')
df_estadoot_sentences.head()
# Out:
#                                                  Observación  \
# CERRADA    [se cambia placa de tk 2 gas95 por placa que i...
# PENDIENTE  [kadshjadsjsakjlskjlsajkshshadsdeqwriqweuibuci...
# ABIERTA    [se coordino visita para el dia lunes 0209 a l...
# PRECIERRE  [se visita eds para chequeo de dispensador el ...
#
#                                                Requerimiento
# CERRADA    [area de atencion habilitar estanque de combus...
# PENDIENTE  [area de atencion surtidor no marca correctame...
# ABIERTA    [area de atencion pislota manquera cortada sol...
# PRECIERRE  [area de atencion surtidor de diesel a ratos c...

# %%
# Extracto de una obs pendiente
df_estadoot_sentences['Observación']['PENDIENTE'][1:4]
# Out:
# ['eds fuera de contrato',
#  'mantencion preventiva mes de agosto solo calibracion',
#  'mantencion preventiva mes de agosto solo calibracion']

# %%
len(df_estadoot_sentences['Observación']['PENDIENTE'])
# Out:
# 1128

# %% [markdown]
# #### 5.2. Ejecutar el algoritmo para una estado OT

# %%
# Asignar data
data = df_estadoot_sentences['Observación']['PENDIENTE']
texts,id2word,corpus = texts_id2word_corpus(data)

# %%
# %%time
# Conocer el mejor n_clusters (Puede tomar varios minutos)
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=texts)
plot_coherence(c_values = coherence_values)
# Out:
# Wall time: 5min 5s

# %%
for m, cv in zip(range(2,31,4), coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))
# Out:
# Num Topics = 2  has Coherence Value of 0.5403
# Num Topics = 6  has Coherence Value of 0.5779
# Num Topics = 10  has Coherence Value of 0.5963
# Num Topics = 14  has Coherence Value of 0.595
# Num Topics = 18  has Coherence Value of 0.5619
# Num Topics = 22  has Coherence Value of 0.5545
# Num Topics = 26  has Coherence Value of 0.5442
# Num Topics = 30  has Coherence Value of 0.5717

# %%
# Seleccionar el mejor model y mostrar los tópicos
optimal_model = model_list[2]
#model_topics = optimal_model.show_topics(formatted=False)
pprint(optimal_model.print_topics(num_words=10))
# Out:
# [(0,
#   '0.125*"cambiar" + 0.061*"boca" + 0.040*"diesel" + 0.038*"filtro" + '
#   '0.036*"tapar" + 0.032*"disp" + 0.031*"producto" + 0.027*"medidor" + '
#   '0.022*"dispensador" + 0.021*"filtracion"'),
#  (1,
#   '0.040*"boca" + 0.034*"tablero" + 0.030*"electrico" + 0.029*"enex" + '
#   '0.028*"mantenimiento" + 0.027*"calibracion" + 0.027*"retirar" + '
#   '0.026*"producto" + 0.024*"boton" + 0.023*"parar"'),
#  (2,
#   '0.090*"cambiar" + 0.086*"dispensador" + 0.075*"nro" + 0.062*"boca" + '
#   '0.054*"gas" + 0.049*"lpm" + 0.041*"funcionamiento" + 0.037*"verificacion" + '
#   '0.036*"volumetrica" + 0.035*"diesel"'),
#  (3,
#   '0.135*"preventivo" + 0.118*"mantencion" + 0.093*"descargar" + '
#   '0.077*"equipo" + 0.073*"lado" + 0.064*"spill" + 0.060*"matraz" + '
#   '0.055*"accesorio" + 0.043*"limpiar" + 0.042*"interior"'),
#  (4,
#   '0.072*"chequean" + 0.068*"interior" + 0.051*"sump" + 0.043*"contar" + '
#   '0.041*"aguar" + 0.039*"calibrar" + 0.038*"fugar" + 0.037*"total" + '
#   '0.036*"estancar" + 0.035*"tapar"'),
#  (5,
#   '0.169*"surtidor" + 0.086*"boca" + 0.082*"limpieza" + 0.049*"verificacion" + '
#   '0.049*"estancar" + 0.048*"volumetrica" + 0.044*"pintar" + 0.044*"servicio" '
#   '+ 0.029*"efectua" + 0.025*"colgante"'),
#  (6,
#   '0.164*"calibrar" + 0.092*"producto" + 0.079*"boca" + 0.079*"preventivo" + '
#   '0.057*"equipo" + 0.055*"equipar" + 0.049*"tdf" + 0.045*"mantenimiento" + '
#   '0.038*"devolver" + 0.037*"recirculado"'),
#  (7,
#   '0.131*"boca" + 0.067*"chequeo" + 0.067*"pistola" + 0.060*"limpieza" + '
#   '0.044*"calibracion" + 0.038*"pintura" + 0.034*"tapar" + 0.031*"spill" + '
#   '0.030*"fundir" + 0.030*"tk"'),
#  (8,
#   '0.199*"mantencion" + 0.187*"mal" + 0.138*"emitir" + 0.133*"preventivo" + '
#   '0.084*"ods" + 0.035*"mes" + 0.035*"solo" + 0.023*"reponer" + '
#   '0.020*"agostar" + 0.016*"actividad"'),
#  (9,
#   '0.098*"calibracion" + 0.071*"dispensador" + 0.061*"diesel" + 0.051*"gas" + '
#   '0.050*"calibrar" + 0.042*"limpio" + 0.030*"dentro" + 0.030*"mp" + '
#   '0.029*"ltr" + 0.029*"rango"')]

# %% [markdown]
# #### 5.3. Visualización

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
LDAmallet_gensim = gensim.models.wrappers.ldamallet.malletmodel2ldamodel(optimal_model)
vis = pyLDAvis.gensim.prepare(LDAmallet_gensim, corpus, id2word)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 1     -0.035320  0.236939       1        1  13.275283
# 2      0.264881 -0.150395       2        1  11.739678
# 0      0.237977 -0.105598       3        1  11.391315
# 7      0.168861  0.080874       4        1  10.834450
# 6     -0.123721  0.030532       5        1   9.692113
# 5      0.149639  0.077029       6        1   9.599211
# 4     -0.107380  0.281199       7        1   9.221427
# 9      0.016063 -0.179830       8        1   9.061051
# 3     -0.248305 -0.031670       9        1   8.873668
# 8     -0.322696 -0.239079      10        1   6.311805, topic_info=            Term        Freq       Total Category  logprob  loglift
# 4     mantencion  654.000000  654.000000  Default  30.0000  30.0000
# 6     preventivo  788.000000  788.000000  Default  29.0000  29.0000
# 20      surtidor  414.000000  414.000000  Default  28.0000  28.0000
# 48      calibrar  675.000000  675.000000  Default  27.0000  27.0000
# 149          mal  301.000000  301.000000  Default  26.0000  26.0000
# ...          ...         ...         ...      ...      ...      ...
# 4     mantencion  319.479082  654.012683  Topic10  -1.6164   2.0463
# 1162      holgar    1.708444    1.708444  Topic10  -6.8475   2.7627
# 6     preventivo  213.555536  788.647329  Topic10  -2.0192   1.4563
# 498     duplicar    3.416889    5.435779  Topic10  -6.1543   2.2985
# 597      control    3.416889    7.677770  Topic10  -6.1543   1.9531
#
# [686 rows x 6 columns], token_table=      Topic      Freq       Term
# term
# 568       7  0.990643      abril
# 958       3  0.989084      abrir
# 612       7  0.990643         ac
# 92        9  1.002083  accesorio
# 115       7  0.990643   accionar
# ...     ...       ...        ...
# 672       4  0.938773   wipenose
# 430       2  0.988054   wipihose
# 465       6  0.984359        wts
# 1257      1  0.986677     zarate
# 520       7  0.990643       zona
#
# [721 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 3, 1, 8, 7, 6, 5, 10, 4, 9])

# %%
# Tópico dominante y su porcentaje de contribución en cada doc
pd.options.display.max_colwidth = 80
df_topic_sents_keywords = format_topics_sentences(ldamodel=LDAmallet_gensim, corpus=corpus, texts=texts)
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic.head(10)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0             0.0              0.1000
# 1            1             6.0              0.1154
# 2            2             8.0              0.1643
# 3            3             8.0              0.1643
# 4            4             8.0              0.1643
# 5            5             8.0              0.1643
# 6            6             8.0              0.1643
# 7            7             8.0              0.1643
# 8            8             8.0              0.1643
# 9            9             8.0              0.1643
#
#                                                                           Keywords  \
# 0  cambiar, boca, diesel, filtro, tapar, disp, producto, medidor, dispensador, ...
# 1  calibrar, producto, boca, preventivo, equipo, equipar, tdf, mantenimiento, d...
# 2  mantencion, mal, emitir, preventivo, ods, mes, solo, reponer, agostar, activ...
# 3  mantencion, mal, emitir, preventivo, ods, mes, solo, reponer, agostar, activ...
# 4  mantencion, mal, emitir, preventivo, ods, mes, solo, reponer, agostar, activ...
# 5  mantencion, mal, emitir, preventivo, ods, mes, solo, reponer, agostar, activ...
# 6  mantencion, mal, emitir, preventivo, ods, mes, solo, reponer, agostar, activ...
# 7  mantencion, mal, emitir, preventivo, ods, mes, solo, reponer, agostar, activ...
# 8  mantencion, mal, emitir, preventivo, ods, mes, solo, reponer, agostar, activ...
# 9  mantencion, mal, emitir, preventivo, ods, mes, solo, reponer, agostar, activ...
#
#                                                         Text
# 0                                                         []
# 1                                           [eds, contratar]
# 2  [mantencion, preventivo, mes, agostar, solo, calibracion]
# 3  [mantencion, preventivo, mes, agostar, solo, calibracion]
# 4  [mantencion, preventivo, mes, agostar, solo, calibracion]
# 5  [mantencion, preventivo, mes, agostar, solo, calibracion]
# 6  [mantencion, preventivo, mes, agostar, solo, calibracion]
# 7  [mantencion, preventivo, mes, agostar, solo, calibracion]
# 8  [mantencion, preventivo, mes, agostar, solo, calibracion]
# 9  [mantencion, preventivo, mes, agostar, solo, calibracion]

# %%
# Distribución de los tópicos a través de los docs
pd.reset_option('^display.', silent=True)
df_topic_distribution = df_dominant_topic['Dominant_Topic'].value_counts().reset_index(name="Num Documents")
df_topic_distribution.columns = ['Topic Num', 'Num Documents']
df_topic_distribution.sort_values('Topic Num')
# Out:
#    Topic Num  Num Documents
# 8        0.0             36
# 6        1.0             53
# 7        2.0             44
# 4        3.0             66
# 2        4.0             95
# 5        5.0             65
# 1        6.0            184
# 9        7.0             33
# 0        8.0            474
# 3        9.0             78

# %%
# La oración más representativa por cada tópico
pd.options.display.max_colwidth = 92
#pd.reset_option('^display.', silent=True)
sent_topics_sorteddf_mallet = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, grp.sort_values(['Perc_Contribution'], ascending=False).head(1)], axis=0)
    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]
sent_topics_sorteddf_mallet
# Out:
#    Topic_Num  Topic_Perc_Contrib  \
# 0        0.0              0.5872
# 1        1.0              0.6788
# 2        2.0              0.6784
# 3        3.0              0.3925
# 4        4.0              0.6103
# 5        5.0              0.3802
# 6        6.0              0.5659
# 7        7.0              0.5535
# 8        8.0              0.4075
# 9        9.0              0.4412
#
#                                                                                       Keywords  \
# 0       cambiar, boca, diesel, filtro, tapar, disp, producto, medidor, dispensador, filtracion
# 1  boca, tablero, electrico, enex, mantenimiento, calibracion, retirar, producto, boton, parar
# 2  cambiar, dispensador, nro, boca, gas, lpm, funcionamiento, verificacion, volumetrica, di...
# 3  preventivo, mantencion, descargar, equipo, lado, spill, matraz, accesorio, limpiar, inte...
# 4             chequean, interior, sump, contar, aguar, calibrar, fugar, total, estancar, tapar
# 5  surtidor, boca, limpieza, verificacion, estancar, volumetrica, pintar, servicio, efectua...
# 6  calibrar, producto, boca, preventivo, equipo, equipar, tdf, mantenimiento, devolver, rec...
# 7             boca, chequeo, pistola, limpieza, calibracion, pintura, tapar, spill, fundir, tk
# 8             mantencion, mal, emitir, preventivo, ods, mes, solo, reponer, agostar, actividad
# 9              calibracion, dispensador, diesel, gas, calibrar, limpio, dentro, mp, ltr, rango
#
#                                                                            Representative Text
# 0  [servicio, ejecucion, mantencion, pendiente, coordinar, proximamente, fecho, ejecucion, ...
# 1  [mantenimiento, preventivo, calendario, mensual, enex, calibracion, boca, limpieza, inte...
# 2  [chequeo, funcionamiento, dispensador, verificacion, volumetrica, cambiar, filtro, dispe...
# 3  [mantencion, preventivo, calibrar, mantencion, preventivo, lado, verificacion, volumetri...
# 4  [eds, comenzar, trabajo, mantenimiento, calibrar, dispensador, chequean, dispenser, sump...
# 5  [efectua, procesar, mantencion, preventivo, estancar, surtidor, limpieza, verificacion, ...
# 6  [mantenimiento, preventivo, calibrar, boca, limpiar, equipo, producto, recirculado, devo...
# 7  [calibracion, boca, limpieza, equipar, chequeo, preset, chequeo, pistola, adhesivo, boca...
# 8  [actividad, mantencion, mantencion, equipar, presentar, fallo, quedandose, fuente, danad...
# 9  [calibracion, dispensador, trabajar, normalidad, dentro, rango, adecuar, calibracion, in...

# %%
# Distribución de la frecuencia de las palabras en los documentos 
doc_lens = [len(d) for d in df_dominant_topic.Text]
plot_freqdist(doc_lens)

# %%
# Nube de palabras
word_cloud(lda_model = optimal_model,figsize=(12,12))
