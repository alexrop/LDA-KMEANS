# %% [markdown]
# # APLICACIÓN KMEANS

# %% [markdown]
# **Contenido**
#
# 1. DiSEÑO DEL ALGORITMO
# 2. OBSERVACIONES
# 3. REQUERIMIENTOS
#
#
# El objetivo de este notebook es la implementación del algoritmo Kmeans con el fin de extraer patrones de comportamiento.

# %% [markdown]
# <div class="alert alert-info" style="margin: 20px">
# Se decide crear este algoritmo con el fin de obtener mayor grado de detales en las OT de las base de datos. En otras palabras, se busca identificar clusters específicos, conservando el sentido semantico de la oración, a diferencia del anterior estructura LDA que permitió tener una visión general. </div>

# %% [markdown]
# # I. DISEÑO DEL ALGORITMO

# %% [markdown]
# #### Importar paquetes

# %%
import collections
from sklearn.cluster import KMeans, SpectralClustering
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from pprint import pprint
import numpy as np
from string import punctuation
from time import time
import os
import pandas as pd
from IPython.display import Image
import matplotlib.pyplot as plt

# Stop Words
with open('../spanish4.0.txt','r') as f:
    stop_words = f.read().splitlines()

# %% [markdown]
# #### Estructura del algoritmo

# %%
# Tokenizar palabras
def word_tokenizer(text):    
    tokens = word_tokenize(text)   # tokenizes and stems the text
    # non_words = list(punctuation)  # removes punctuation 
    # text = ''.join([c for c in text if c not in non_words]) ---> Data ingresada ya está libre de puntuación
    stemmer = SnowballStemmer('spanish')
    tokens = [stemmer.stem(t) for t in tokens if t not in stop_words] # Posibilidad de extender stopwords
    return tokens

# Elbow Method
def elbow_method(sentences,figsize = (8,5),  namecol=None, nro_top=None, save = False,width_text = 0.83, height_text = 0.92):
    tfidf_vectorizer = TfidfVectorizer(tokenizer=word_tokenizer,stop_words=stop_words,lowercase=True)
    tfidf_matrix = tfidf_vectorizer.fit_transform(sentences)   #builds a tf-idf matrix for the sentences
    import warnings
    
    try:
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            if len(sentences)<= 30:
                list_k = list(range(1,len(sentences)+1))
                elbow = []
                for i in list_k:
                    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 101)
                    kmeans.fit(tfidf_matrix)
                    elbow.append(kmeans.inertia_)

            elif len(sentences)> 30 and len(sentences)<= 70:
                list_k = list(range(2,len(sentences)+1,2))
                elbow = []
                for i in list_k:
                    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 101)
                    kmeans.fit(tfidf_matrix)
                    elbow.append(kmeans.inertia_)     

            else:     
                list_k = list(range(2,71,4))
                elbow = []
                for i in list_k:
                    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 101)
                    kmeans.fit(tfidf_matrix)
                    elbow.append(kmeans.inertia_)

            from kneed import KneeLocator
            kn = KneeLocator(list_k, elbow, curve='convex', direction='decreasing')
            print(f'Número óptimo de clústers: {kn.knee}')

            plt.rcParams.update({'figure.figsize':figsize})
            plt.xlabel('Número de clusters k')
            plt.ylabel('Suma de distancias cuadradas')
            plt.plot(list_k, elbow, 'bo-')
            plt.title('Método del Elbow')
            plt.text(width_text, height_text, f'k óptimo: {kn.knee}', transform=plt.gca().transAxes)
            plt.vlines(kn.knee, plt.ylim()[0], plt.ylim()[1], linestyles='dashed')
            if save :
                plt.savefig(f'{namecol} {nro_top} - Método del elbow.jpg', dpi= 200, quality=95)
            plt.show()

    except ValueError:
        print('You must enter at least two sentences')

# %%
# Silhouette Analysis
def silhouette_plot(sentences, n_clusters, figsize=(9,5), width=1.02, height=0.96):
    fig, ax1 = plt.subplots()
    plt.rcParams.update({'figure.figsize':figsize})
    plt.rcParams.update({'figure.autolayout': True})
    tfidf_vectorizer = TfidfVectorizer(tokenizer=word_tokenizer,stop_words=stop_words,lowercase=True)
    X_std = tfidf_vectorizer.fit_transform(sentences)

    # Run the Kmeans algorithm
    km = KMeans(n_clusters = n_clusters, init = 'k-means++', random_state = 101)
    labels = km.fit_predict(X_std)
    centroids = km.cluster_centers_

    # Get silhouette samples
    silhouette_vals = silhouette_samples(X_std, labels)

    # Silhouette plot
    y_ticks = []
    y_lower, y_upper = 0, 0
    for i, cluster in enumerate(np.unique(labels)):
        cluster_silhouette_vals = silhouette_vals[labels == cluster]
        cluster_silhouette_vals.sort()
        y_upper += len(cluster_silhouette_vals)
        ax1.barh(range(y_lower, y_upper), cluster_silhouette_vals, edgecolor='none', height=1)
        ax1.text(-0.03, (y_lower + y_upper) / 2, str(i))
        y_lower += len(cluster_silhouette_vals)

    # Get the average silhouette score and plot it
    avg_score = np.mean(silhouette_vals)
    ax1.axvline(avg_score, linestyle='--', linewidth=2, color='green')
    ax1.set_yticks([])
    ax1.set_xlim([-0.1, 1])
    ax1.set_xlabel('Coeficientes de Silueta')
    ax1.set_ylabel('Clusters')
    ax1.set_title(f'Análisis de Silueta para k = {n_clusters}', y=1.02)
    plt.text(width, height, f'Silhouette Score: {round(avg_score,4)}', transform=plt.gca().transAxes);
    
def silhouette_analysis(sentences, n_clusters, save = True, name= None):
    for k in n_clusters:
        silhouette_plot(sentences,n_clusters=k)
        if save:
            plt.savefig(f'Silueta - {name} con k {k}.jpg', dpi= 200, quality=95)

# %%
# Algoritmo Kmeans
def cluster_sentences(sentences, nb_of_clusters):

    tfidf_vectorizer = TfidfVectorizer(tokenizer=word_tokenizer,stop_words=stop_words,lowercase=True)
    tfidf_matrix = tfidf_vectorizer.fit_transform(sentences)   #builds a tf-idf matrix for the sentences
    
    kmeans = KMeans(n_clusters = nb_of_clusters, init = 'k-means++', random_state = 101, max_iter=300)
    #kmeans.fit(tfidf_matrix)
    X_dist=kmeans.fit_transform(tfidf_matrix)**2  #Se calcula la distancia del cluster y se multiplica al cuadrado
    clusters = collections.defaultdict(list)
    for i, label in enumerate(kmeans.labels_):
        clusters[label].append(i)

    Distancia=X_dist.sum(axis=1)  #Se calcula la distancia por columna de la matriz

    distDict={}  #Se traspasa a un diccionario con las distancias por cluster
    for key,val in clusters.items():
        distDict[key]=Distancia[val]

    representativos=[]   # Se guarda en una lista los valores mínimos de cada cluster (Menor distancia al centro mejor es el representativo)
    
    #Verificacion de los numeros de clusters
    #Si se intenta obtener los representativos de un número mas grande de cluster que el permitido, se procesa el número de clusters
    if len(distDict)<nb_of_clusters:
        nb_of_clusters=len(distDict)
        
    #Verificacion de los números de clústers
    for i in range(nb_of_clusters):
        representativos.append(np.where(distDict[i]==min(distDict[i]))[0][0])

    return dict(clusters),representativos

# Plot cantidad de sentences por cluster
def len_clusters(dic, n, namecol=None, nro_top=None, save = False, width = 0.6, color = "royalblue", figsize = (8,5)):
    keys = list(range(0,n))
    len_values = [len(dic[i]) for i in keys]
    plt.rcParams.update({'figure.figsize': figsize})
    plt.bar(keys,len_values , align='center', color = color, width = width)
    plt.title('Cantidad de OT por cluster')
    plt.xlabel('Clusters')
    plt.ylabel('Orden de Trabajo (OT)')
    plt.xticks(np.arange(min(keys), max(keys)+1, 1.0))
    if save:
        plt.savefig(f'{namecol} {nro_top} - Distribucion clusters .jpg', dpi= 200, quality=95)
    plt.show()

# %% [markdown]
# <div class="alert alert-success" style="margin: 20px">En todos los data frames ya está implementada la función word_cleaner() que permitió limpiar la base de datos. Para más información de esta función ir al segundo notebook.</div>

# %% [markdown]
# #### Importar Data Frame

# %%
df_total = pd.read_pickle('../2. Topic Modeling - LDA 24 topics/BD_original_cleaned_TOPICO_DOMINANTE.pkl')
df_total.head()
# Out:
#   Region                                           Estacion  \
# 0    13°                                       Tingaro Spa.
# 1     8°                       Combustibles El Volcan Ltda.
# 2    10°           LLANOS Y WAMMES SOCIEDAD COMERCIAL LTDA.
# 3     1°     Soc. Imp. y Exp. Nuevo Amanecer Ltda. (SOCIEX)
# 4     3°  Inmobiliaria e Inversiones San José Ltda (Vall...
#
#                Tipo de Falla Prioridad Cliente  Estado OT Tecnico Asignado  \
# 0  Carrete RetractilOTROOTRO   Normal 48 Horas    CERRADA      Juan Aliaga
# 1  Carrete RetractilOTROOTRO   Normal (48 hrs)    CERRADA          On Line
# 2  Carrete RetractilOTROOTRO   Normal 24 Horas  PRECIERRE   Luis Almonacid
# 3  Carrete RetractilOTROOTRO   Normal (48 hrs)    CERRADA          On Line
# 4  Carrete RetractilOTROOTRO   Normal (48 hrs)    CERRADA          On Line
#
#        Dia  Nro Dia     Mes  Hora Rango Recep/Arribo Rango Arribo/Cierre  \
# 0  Viernes       30  AGO 19    16    Error en fechas        Más de 1 mes
# 1  Viernes       30  AGO 19    12    Error en fechas         Menos de 1h
# 2  Viernes       30  AGO 19    12       0 a 24 horas         Menos de 1h
# 3  Viernes       30  AGO 19    12       0 a 24 horas         Menos de 1h
# 4  Viernes       30  AGO 19    12    Error en fechas         Menos de 1h
#
#                                          Observación  \
# 0  se cambia placa de tk 2 gas95 por placa que in...
# 1  cambio de graficas de equipos no esta contempl...
# 2  se visita eds para chequeo de dispensador el c...
# 3  remplazo de graficas no esta contemplado en es...
# 4  remplazo de graficas no esta contemplado en co...
#
#                                        Requerimiento  Topico Dominante
# 0  area de atencion habilitar estanque de combust...                 2
# 1  area de atencion combustible maria veronica go...                23
# 2  area de atencion surtidor de diesel a ratos co...                 3
# 3  area de atencion combustible cambiar graficas ...                 4
# 4  area de atencion combustible solicita grafica ...                 4

# %% [markdown]
# # II. OBSERVACIONES

# %%
# SELECCIONANDO UNA COLUMNA Y UN ELEMENTO DE ESA COLUMNA (Escribir con comillas. Ej: 'Tecnico Asignado')

columna = 'Tecnico Asignado'
elemento = 'On Line'

# %%
df = df_total[df_total[columna] == elemento] 
sentences = [sent for sent in df['Observación']]
len(sentences)
# Out:
# 1302

# %%
# Extracto obs 
sentences[:2]
# Out:
# ['cambio de graficas de equipos no esta contemplado en estaciones delegadas',
#  'remplazo de graficas no esta contemplado en estaciones delegadas']

# %%
# %%time
# Identificando el número óptimo de clústers por medio del método del Elbow
elbow_method(sentences, save = False)
# Out:
# Número óptimo de clústers: 22
# Wall time: 11.9 s

# %%
# %%time
# Identificando el número óptimo de clústers por medio del Análisis de Silueta
silhouette_analysis(sentences, n_clusters=[6,10,22], name='Online', save=False)
# Out:
# Wall time: 4.47 s

# %%
# Ejecutando el algoritmo Kmeans para el número óptimo de clústers 
print('\033[1mCLUSTERS \n\033[0m')
start_time = time()

nclusters=22
clusters,representativos = cluster_sentences(sentences, nclusters)

for cluster in range(nclusters):
    print (f"\033[1mCluster {cluster} : {sentences[clusters[cluster][representativos[cluster]]]}\033[0m")
    for i,sentence in enumerate(clusters[cluster]):
        print ("\tsentence ",i,": ",sentences[sentence])

elapsed_time = time() - start_time
print("\033[1mElapsed time: %.10f seconds.\033[0m" % elapsed_time)
# Out:
# CLUSTERS
#
# Cluster 0 : duplicaron la ot incidencia sera atendida bajo la ot 19487
# 	sentence  0 :  incidencia sera vista mediante ot 28082
# 	sentence  1 :  incidencia debe ser atendida por estacion de servicio
# 	sentence  2 :  incidencia sera vista mediante ot 28082
# 	sentence  3 :  incidencia ha de ser atendida por personal de gilbarco
# 	sentence  4 :  incidencia debe ser atendida por estacion de servicio por ser mantencion delegada
# 	sentence  5 :  instlacion de brekaway debe ser realizada por estacion de servicio
# 	sentence  6 :  incidencia debe ser atendida por estacion de servicio por contar con mantencion delegada
# 	sentence  7 :  esta ot debe ser atendida por contratista a cargo de sistemas no combustible
# 	sentence  8 :  configuracion de horario de veeder r inicedencia debe ser derivada a gilbarco
# 	sentence  9 :  incidencia debe ser atendida por estacion de servicio
# 	sentence  10 :  incidencia debe ser atendida por estacion de servicio
# 	sentence  11 :  incidencia debe ser atendida por estacion de servicio
# 	sentence  12 :  incidencia sera atendida bajo ot 26664
# 	sentence  13 :  en espera de tablas de calibracion incidencia sera vista bajo ot 26542
# 	sentence  14 :  incidencia sera atendida dentro de ot 26016
# 	sentence  15 :  a la espera de tablas de calibracion incidencia sera vista en ot 26542
# 	sentence  16 :  incidencia debe ser derivada a mantendor correspondiente por garantia de instalacion
# 	sentence  17 :  a la espera de tablas de calibracion incidencia sera vista en ot 26292
# 	sentence  18 :  a la espera de tablas de calibracion incidencia sera atendida bajo ot 26547
# 	sentence  19 :  incidencia debe ser derivada a gilbarco no corresponde a sgs
# 	sentence  20 :  incidencia sera atendida bajo ot 24589
# 	sentence  21 :  incidencia falla pes debe ser atendida inicialmente por gilbarco
# 	sentence  22 :  a la espera de tablas de calibracion incidencia sera atendida bajo ot 25872
# 	sentence  23 :  incidencia debe ser atendida por estacion de servicio
# 	sentence  24 :  incidencia sera atendida con otra contratista
# 	sentence  25 :  eds se encuentra fuera de contrato por lo tanto no sera atendida
# 	sentence  26 :  mp sera ejecutada bajo la ot 7
# 	sentence  27 :  ot sera atendida bajo ot 21530
# 	sentence  28 :  requerimiento debe ser derivado a personal orpak
# 	sentence  29 :  incidencia sera atendida bajo ot 22353
# 	sentence  30 :  ot sera atendida bajo ot 21488
# 	sentence  31 :  incidencia fue atendida por personal de gilbarco
# 	sentence  32 :  duplicaron la ot incidencia sera atendida bajo la ot 19487
# 	sentence  33 :  en conversacion con rodrigo diez indico que fue una equivocacion incidencia sera derivada a contratista electricista
# 	sentence  34 :  la siguiente incidencia sera atendida bajo ot 7
# 	sentence  35 :  ot sera atendida por otro contratista
# 	sentence  36 :  incidencia sera atendida bajo la ot 14567
# 	sentence  37 :  se cierra la incidencia ya que tiene el mismo requerimiento de la ot 14287 por lo tanto sera atendida bajo la ot mencionada
# 	sentence  38 :  incidencia es cerrada por ser derivada a otro mantendor
# 	sentence  39 :  incidencia debe ser atendida por la misma estacion de servicio ya que corresponde a los decantadores
# 	sentence  40 :  incidencia debe ser atendida por la misma estacion de servicio ya que corresponde a los decantadores
# 	sentence  41 :  incidencia sera asistida bajo ot 6
# 	sentence  42 :  incidencia sera atendida bajo la ot 13746
# 	sentence  43 :  incidencia sera atendida bajo la ot 13732
# 	sentence  44 :  se cierra incidencia ya que la misma sera atendida bajo la ot 13075 la cual tiene el mismo requerimiento
# 	sentence  45 :  incidencia es cerrada ya que debe ser derivada a mantenedor correspondiente por encontarse fuera de alcance de contrato
# Cluster 1 : ods mal emitida
# 	sentence  0 :  ods mal emitida
# 	sentence  1 :  ods mal emitida
# 	sentence  2 :  ods mal emitida
# 	sentence  3 :  ods mal emitida
# 	sentence  4 :  ods mal emitida
# 	sentence  5 :  ods mal emitida
# 	sentence  6 :  ods mal emitida
# 	sentence  7 :  ods mal emitida
# 	sentence  8 :  ods mal emitida
# 	sentence  9 :  ods mal emitida
# 	sentence  10 :  ods mal emitida
# 	sentence  11 :  ods mal emitida
# 	sentence  12 :  ods mal emitida
# 	sentence  13 :  ods mal emitida
# 	sentence  14 :  ods mal emitida
# 	sentence  15 :  ods mal emitida
# 	sentence  16 :  ods mal emitida
# 	sentence  17 :  ods mal emitida
# 	sentence  18 :  ods mal emitida
# 	sentence  19 :  ods mal emitida
# 	sentence  20 :  ods mal emitido
# 	sentence  21 :  ods mal emitida
# 	sentence  22 :  ods mal emitida
# 	sentence  23 :  ods mal emitida
# 	sentence  24 :  ods mal emitida
# 	sentence  25 :  ods mal emitida
# 	sentence  26 :  ods mal emitida
# 	sentence  27 :  ods mal emitida
# 	sentence  28 :  ods mal emitida
# 	sentence  29 :  ods mal emitida
# 	sentence  30 :  ods mal emitida
# 	sentence  31 :  ods mal emitida
# 	sentence  32 :  ods mal emitida
# 	sentence  33 :  ods mal emitida
# 	sentence  34 :  ods mal emitida
# 	sentence  35 :  ods mal emitida
# 	sentence  36 :  ods mal emitida
# 	sentence  37 :  ods mal emitida
# 	sentence  38 :  ods mal emitida
# 	sentence  39 :  ods mal emitida
# 	sentence  40 :  ods mal emitida
# 	sentence  41 :  ods mal emitida
# 	sentence  42 :  ods mal emitida
# 	sentence  43 :  ods mal emitida
# 	sentence  44 :  ods mal emitida
# 	sentence  45 :  ods mal emitida
# 	sentence  46 :  ods mal emitida
# 	sentence  47 :  ods mal emitida
# 	sentence  48 :  ods mal emitida
# 	sentence  49 :  ods mal emitida
# 	sentence  50 :  ods mal emitida
# 	sentence  51 :  ods mal emitida
# 	sentence  52 :  ods mal emitida
# 	sentence  53 :  ods mal emitida
# 	sentence  54 :  ods mal emitida
# 	sentence  55 :  ods mal emitida
# 	sentence  56 :  ods mal emitida
# 	sentence  57 :  ods mal emitida
# 	sentence  58 :  ods mal emitida
# 	sentence  59 :  ods mal emitida
# 	sentence  60 :  ods mal emitida
# 	sentence  61 :  ods mal emitida
# 	sentence  62 :  ods mal emitida
# 	sentence  63 :  ods mal emitida
# 	sentence  64 :  ods mal emitida
# 	sentence  65 :  ods mal emitida
# 	sentence  66 :  ods mal emitida
# 	sentence  67 :  ods mal emitida
# 	sentence  68 :  ods mal emitida
# 	sentence  69 :  ods mal emitido
# 	sentence  70 :  ods mal emitida
# 	sentence  71 :  ods mal emitida
# 	sentence  72 :  ods mal emitido
# 	sentence  73 :  ods mal emitida
# 	sentence  74 :  ods mal emitida
# 	sentence  75 :  ods mal emitido
# 	sentence  76 :  ods mal emitida
# 	sentence  77 :  ods mal emitida
# 	sentence  78 :  ods mal emitida
# 	sentence  79 :  ods mal emitida
# 	sentence  80 :  ods mal emitida
# 	sentence  81 :  ods mal emitida
# 	sentence  82 :  ods mal emitida
# 	sentence  83 :  ods mal emitida
# 	sentence  84 :  ods mal emitida
# 	sentence  85 :  ods mal emitida
# 	sentence  86 :  ods mal emitida
# 	sentence  87 :  ods mal emitida
# 	sentence  88 :  ods mal emitida
# 	sentence  89 :  ods mal emitida
# 	sentence  90 :  ods mal emitido
# 	sentence  91 :  ods mal emitida
# 	sentence  92 :  ods mal emitido
# 	sentence  93 :  ods mal emitido
# 	sentence  94 :  ods mal emitida
# 	sentence  95 :  ods mal emitido
# 	sentence  96 :  ods mal emitida
# 	sentence  97 :  ods mal emitida
# 	sentence  98 :  ods mal emitido
# 	sentence  99 :  ods mal emitido
# 	sentence  100 :  ods mal emitida
# 	sentence  101 :  ods mal emitida
# 	sentence  102 :  ods mal emitida
# 	sentence  103 :  ods mal emitida
# 	sentence  104 :  ods mal emitida
# 	sentence  105 :  ods mal emitida
# 	sentence  106 :  ods mal emitida
# 	sentence  107 :  ods mal emitida
# 	sentence  108 :  ods mal emitida
# 	sentence  109 :  ods mal emitida
# 	sentence  110 :  ods mal emitida
# 	sentence  111 :  ods mal emitida
# 	sentence  112 :  ods mal emitida
# 	sentence  113 :  ods mal emitida
# 	sentence  114 :  ods mal emitida
# 	sentence  115 :  ods mal emitida
# 	sentence  116 :  ods mal emitida
# 	sentence  117 :  ods mal emitida
# 	sentence  118 :  ods mal emitida
# 	sentence  119 :  ods mal emitida
# 	sentence  120 :  ods mal emitida
# 	sentence  121 :  ods mal emitida
# 	sentence  122 :  ods mal emitida
# 	sentence  123 :  ods mal emitida
# 	sentence  124 :  ods mal emitida
# 	sentence  125 :  ods mal emitida
# 	sentence  126 :  ods mal emitida
# 	sentence  127 :  ods mal emitida
# 	sentence  128 :  ods mal emitida
# 	sentence  129 :  ods mal emitida
# 	sentence  130 :  ods mal emitida
# 	sentence  131 :  ods mal emitida
# 	sentence  132 :  ods mal emitida
# 	sentence  133 :  ods mal emitida
# 	sentence  134 :  ods mal emitida
# 	sentence  135 :  ods mal emitida
# 	sentence  136 :  ods mal emitida
# 	sentence  137 :  ods mal emitida
# 	sentence  138 :  ods mal emitida
# 	sentence  139 :  ods mal emitida
# 	sentence  140 :  ods mal emitida
# 	sentence  141 :  ods mal emitida
# 	sentence  142 :  ods mal emitida
# 	sentence  143 :  ods mal emitida
# 	sentence  144 :  ods mal emitida
# 	sentence  145 :  ods mal emitida
# 	sentence  146 :  ods mal emitida
# 	sentence  147 :  ods mal emitida
# 	sentence  148 :  ods mal emitida
# 	sentence  149 :  ods mal emitida
# 	sentence  150 :  ods mal emitida
# 	sentence  151 :  ods mal emitida
# 	sentence  152 :  ods mal emitida
# 	sentence  153 :  ods mal emitida
# 	sentence  154 :  ods mal emitida
# 	sentence  155 :  ods mal emitida
# 	sentence  156 :  ods mal emitido
# 	sentence  157 :  ods mal emitida
# 	sentence  158 :  ods mal emitida
# 	sentence  159 :  ods mal emitida
# 	sentence  160 :  ods mal emitida
# 	sentence  161 :  ods mal emitida
# 	sentence  162 :  ods mal emitida
# 	sentence  163 :  ods mal emitida
# 	sentence  164 :  ods mal emitida
# 	sentence  165 :  ods mal emitida
# 	sentence  166 :  ods mal emitida
# 	sentence  167 :  ods mal emitida
# 	sentence  168 :  ods mal emitida
# 	sentence  169 :  ods mal emitida
# 	sentence  170 :  ods mal emitida
# 	sentence  171 :  ods mal emitida
# 	sentence  172 :  ods mal emitida
# 	sentence  173 :  ods mal emitida
# 	sentence  174 :  ods mal emitida
# 	sentence  175 :  ods mal emitida
# 	sentence  176 :  ods mal emitida
# 	sentence  177 :  ods mal emitida
# 	sentence  178 :  ods mal emitida
# 	sentence  179 :  ods mal emitida
# 	sentence  180 :  ods mal emitida
# 	sentence  181 :  ods mal emitida
# 	sentence  182 :  ods mal emitida
# 	sentence  183 :  ods mal emitido
# 	sentence  184 :  ods mal emitida
# 	sentence  185 :  ods mal emitido
# 	sentence  186 :  ods mal emitido
# 	sentence  187 :  ods mal emitida
# 	sentence  188 :  ods mal emitida
# 	sentence  189 :  ods mal emitida
# 	sentence  190 :  ods mal emitida
# 	sentence  191 :  ods mal emitida
# 	sentence  192 :  ods mal emitida
# 	sentence  193 :  ods mal emitida
# 	sentence  194 :  ods mal emitida
# 	sentence  195 :  ods mal emitida
# 	sentence  196 :  ods mal emitida
# 	sentence  197 :  ods mal emitida
# 	sentence  198 :  ods mal emitida
# 	sentence  199 :  ods mal emitida
# 	sentence  200 :  ods mal emitida
# 	sentence  201 :  ods mal emitida
# 	sentence  202 :  ods mal emitida
# 	sentence  203 :  ods mal emitida
# 	sentence  204 :  ods mal emitida
# 	sentence  205 :  ods mal emitido
# 	sentence  206 :  ods mal emitida
# 	sentence  207 :  ods mal emitida
# 	sentence  208 :  ods mal emitida
# 	sentence  209 :  ods mal emitida
# 	sentence  210 :  ods mal emitida
# 	sentence  211 :  ods mal emitido
# 	sentence  212 :  ods mal emitido
# 	sentence  213 :  ods mal emitido
# 	sentence  214 :  ods mal emitido
# 	sentence  215 :  ods mal emitido
# 	sentence  216 :  ods mal emitido
# 	sentence  217 :  ods mal emitida
# 	sentence  218 :  ods mal emitida
# 	sentence  219 :  ods mal emitida
# 	sentence  220 :  ods mal emitida
# 	sentence  221 :  ods mal emitida
# 	sentence  222 :  ods mal emitida
# 	sentence  223 :  ods mal emitida
# 	sentence  224 :  ods mal emitida
# 	sentence  225 :  ods mal emitida
# 	sentence  226 :  ods mal emitida
# 	sentence  227 :  ods mal emitida
# 	sentence  228 :  ods mal emitida
# 	sentence  229 :  ods mal emitida
# 	sentence  230 :  ods mal emitida
# 	sentence  231 :  ods mal emitida
# 	sentence  232 :  ods mal emitida
# 	sentence  233 :  ods mal emitida
# 	sentence  234 :  ods mal emitida
# 	sentence  235 :  ods mal emitida
# 	sentence  236 :  ods mal emitida
# 	sentence  237 :  ods mal emitida
# 	sentence  238 :  ods mal emitida
# 	sentence  239 :  ods mal emitida
# 	sentence  240 :  ods mal emitida
# 	sentence  241 :  ods mal emitida
# 	sentence  242 :  ods mal emitida
# 	sentence  243 :  ods mal emitida
# 	sentence  244 :  ods mal emitida
# 	sentence  245 :  ods mal emitida
# 	sentence  246 :  ods mal emitida
# 	sentence  247 :  ods mal emitida
# 	sentence  248 :  ods mal emitida
# 	sentence  249 :  ods mal emitida
# 	sentence  250 :  ods mal emitida
# 	sentence  251 :  ods mal emitida
# 	sentence  252 :  ods mal emitida
# 	sentence  253 :  ods mal emitida
# 	sentence  254 :  ods mal emitida
# 	sentence  255 :  ods mal emitido
# 	sentence  256 :  ods mal emitido
# 	sentence  257 :  ods mal emitido
# 	sentence  258 :  ods mal emitido
# 	sentence  259 :  ods mal emitido
# 	sentence  260 :  ods mal emitida
# 	sentence  261 :  ods mal emitida
# 	sentence  262 :  ods mal emitida
# 	sentence  263 :  ods mal emitida
# 	sentence  264 :  ods mal emitida
# 	sentence  265 :  ods mal emitida
# 	sentence  266 :  ods mal emitida
# 	sentence  267 :  ods mal emitida
# 	sentence  268 :  ods mal emitida
# 	sentence  269 :  ods mal emitida
# 	sentence  270 :  ods mal emitida
# 	sentence  271 :  ods mal emitida
# 	sentence  272 :  ods mal emitida
# 	sentence  273 :  ods mal emitida
# 	sentence  274 :  ods mal emitida
# 	sentence  275 :  ods mal emitida
# 	sentence  276 :  ods mal emitida
# 	sentence  277 :  ods mal emitida
# 	sentence  278 :  ods mal emitida
# 	sentence  279 :  ods mal emitida
# 	sentence  280 :  ods mal emitida
# 	sentence  281 :  ods mal emitida
# 	sentence  282 :  ods mal emitida
# 	sentence  283 :  ods mal emitida
# 	sentence  284 :  ods mal emitida
# 	sentence  285 :  ods mal emitida
# 	sentence  286 :  ods mal emitida
# 	sentence  287 :  ods mal emitida
# 	sentence  288 :  ods mal emitida
# 	sentence  289 :  ods mal emitida
# 	sentence  290 :  ods mal emitida
# 	sentence  291 :  ods mal emitida
# 	sentence  292 :  ods mal emitida
# 	sentence  293 :  ods mal emitida
# Cluster 2 : incidencia mal asignada
# 	sentence  0 :  incidencia mal asignada
# 	sentence  1 :  ods mal asignada
# 	sentence  2 :  incidencia mal asignada
# 	sentence  3 :  ods mal asignada
# 	sentence  4 :  ods mal asignada
# 	sentence  5 :  ods mal asignada
# 	sentence  6 :  ods mal asignada
# 	sentence  7 :  incidencia mal asignada por cliente se cierra por orden de rodrigo delgado
# 	sentence  8 :  mal asignada
# 	sentence  9 :  mal asignada
# 	sentence  10 :  mal asignada
# 	sentence  11 :  mal asignada
# 	sentence  12 :  mal asignada
# 	sentence  13 :  mal asignada
# 	sentence  14 :  mal asignada
# 	sentence  15 :  mal asignada
# 	sentence  16 :  ods mal asignada
# 	sentence  17 :  ods mal asignada
# 	sentence  18 :  ods mal asignada
# 	sentence  19 :  mal asignada
# 	sentence  20 :  mal asignada
# 	sentence  21 :  mal asignada
# 	sentence  22 :  mal asignada
# 	sentence  23 :  ods asignada a otro contratista
# 	sentence  24 :  mal asignada
# 	sentence  25 :  mal asignada
# 	sentence  26 :  ods mal asignada
# 	sentence  27 :  ods mal asignada
# 	sentence  28 :  ods mal asignada
# 	sentence  29 :  ods mal asignada
# 	sentence  30 :  ods mal asignada
# 	sentence  31 :  mal asignada
# 	sentence  32 :  mal asignada
# 	sentence  33 :  mal asignada
# 	sentence  34 :  ods mal asignada
# 	sentence  35 :  ot mal asignada
# 	sentence  36 :  mal asignada
# 	sentence  37 :  mal asignada
# 	sentence  38 :  mal asignada
# 	sentence  39 :  mal asignada
# 	sentence  40 :  mal asignada
# 	sentence  41 :  mal asignada
# 	sentence  42 :  mal asignada
# 	sentence  43 :  mal asignada
# 	sentence  44 :  ot mal asignada por cliente
# 	sentence  45 :  mal asignada ot rechazada
# 	sentence  46 :  incidencia mal asignada
# 	sentence  47 :  mal asignada
# 	sentence  48 :  mal asignada
# 	sentence  49 :  mal asignada
# 	sentence  50 :  mal asignada
# 	sentence  51 :  mal asignada
# 	sentence  52 :  mal asignada
# 	sentence  53 :  mal asignada
# 	sentence  54 :  mal asignada
# 	sentence  55 :  mal asignada
# 	sentence  56 :  mal asignada
# 	sentence  57 :  mal asignada
# 	sentence  58 :  mal asignada
# Cluster 3 : incidencia se cierra ya que no corresponde a contrato combustibles
# 	sentence  0 :  incidencia no corresponde a contrato combustibles
# 	sentence  1 :  incidencia no corresponde a contrato combustibles
# 	sentence  2 :  incidencia no corresponde a contrato combustibles
# 	sentence  3 :  incidencia no corresponde a contrato combustible
# 	sentence  4 :  incidencia no corresponde a contrato combustibles
# 	sentence  5 :  incidencia no corresponde a contrato combustible
# 	sentence  6 :  incidencia no corresponde a contrato combustibles
# 	sentence  7 :  incidencia no corresponde a contrato de combustibles
# 	sentence  8 :  incidencia se cierra ya que no corresponde a contrato combustibles
# 	sentence  9 :  incidencia no corresponde a contrato combustibles
# 	sentence  10 :  incidencia no corresponde a contrato combustibles
# 	sentence  11 :  incidencia se cierra ya que no corresponde al contrato de combustibles
# 	sentence  12 :  incidencia no corresponde a contrato combustibles
# 	sentence  13 :  incidencia no corresponde a contrato combustibles
# 	sentence  14 :  incidencia no corresponde a contrato combustibles
# 	sentence  15 :  retiro de tanque de combustible incidencia no corresponde a esta estacion
# 	sentence  16 :  incidencia no corresponde a contrato combustible
# 	sentence  17 :  incidencia no corresponde a contrato combustibles
# 	sentence  18 :  incidencia no corresponde a contrato combustibles
# 	sentence  19 :  incidencia no corresponde a contrato combustible
# 	sentence  20 :  incidencia no corresponde al contrato combustibles
# Cluster 4 : incidencia atendida bajo la ot 2
# 	sentence  0 :  incidencia atendida bajo la ot 2
# 	sentence  1 :  incidencia atendida y cerrada bajo ot 2
# 	sentence  2 :  incidencia se cierra bajo ot 2
# 	sentence  3 :  mp realizada bajo ot 2
# 	sentence  4 :  mp se realizara bajo la ot 2
# 	sentence  5 :  incidencia es atendida bajo ot 2
# 	sentence  6 :  incidencia es taendida bajo ot 2
# 	sentence  7 :  ot duplicada pi atendido bajo ods 2
# 	sentence  8 :  incidencia es atendida bajo ot 2
# 	sentence  9 :  atendida bajo os 90058 ods 2
# 	sentence  10 :  incidencia sera atendida bajo ods 2
# 	sentence  11 :  ot siendo atendida bajo ot 2
# 	sentence  12 :  ot atendida bajo ot 2
# 	sentence  13 :  incidencia es atendida bajo ot 2
# 	sentence  14 :  incidencia es atendida bajo ot 2
# 	sentence  15 :  incidencia sera atendida bajo 2
# 	sentence  16 :  incidencia es atendida bajo ot 2
# 	sentence  17 :  la incidencia se genero 2 veces se atendera bajo la ot 12005
# 	sentence  18 :  se realiza el cambio de 2 breackaway 1 2 whipe hose 1 y 2 mangueras 1 quedando equipo operativo
# 	sentence  19 :  incidencia es atendida bajo ot 2
# Cluster 5 : mantencion preventiva sera atendida bajo ot 1
# 	sentence  0 :  incidencia sera vista mediante la mantencion preventiva del mes de septiembre
# 	sentence  1 :  pintado de tapas se realiza mediante la mantencion preventiva completa
# 	sentence  2 :  incidencia atendida dentro de mantencion preventiva ot 27362
# 	sentence  3 :  incidencia sera cerrada bajo mantencion preventiva
# 	sentence  4 :  incidencia sera vista mediante ot 27298 mantencion preventiva
# 	sentence  5 :  pintado de tapas se realizara en su proxima mantecion preventiva
# 	sentence  6 :  pintura de tapas se realizara en mantencion preventiva completa
# 	sentence  7 :  pintado de las tapas se realizara en la proxima mantencion preventiva del mes de agosto
# 	sentence  8 :  pintura de tapas de estanque se realizara en la mantencion preventiva del mes de agosto
# 	sentence  9 :  mantencion preventiva es en el mes de septiembre y cambio de pistola corresponde a estacion de servicio
# 	sentence  10 :  incidencia fue atendida dentro de mantencion preventiva ot 25534
# 	sentence  11 :  incidencia se cierra bajo mantencion preventiva ot 25474
# 	sentence  12 :  mantencion preventiva sera atendida bajo ot 1
# 	sentence  13 :  mantencion preventiva se realizara bajo la ot 1
# 	sentence  14 :  mantencion preventiva se realiza bajo la ot 5
# 	sentence  15 :  mantencion preventiva se realizara bajo ot 5
# 	sentence  16 :  mantencion preventiva fue realizada bajo la ot 1
# 	sentence  17 :  incidencia se cierra bajo mantencion preventiva ot 20563
# 	sentence  18 :  incidencia se atendera bajo ot 20577 mantencion preventiva
# 	sentence  19 :  ot preventiva duplicada ot correcta 20093
# 	sentence  20 :  incidencia se atendera bajo mantencion preventiva ot 20178
# 	sentence  21 :  mantencion preventiva no se realiza ya que eds se encuentra en remodelacion
# 	sentence  22 :  mantencion preventiva no se ejecuta ya que punto queda fuera de contrato
# 	sentence  23 :  mantencion preventiva no se realiza ya que punto queda fuera de contrato
# 	sentence  24 :  mantencion preventiva se calibran 26 de 26 mantencion no se realiza ya que punto queda fuera de contrato
# 	sentence  25 :  se realiza mantencion preventiva
# 	sentence  26 :  mantencion preventiva se calibran 1 de 1
# 	sentence  27 :  mantencion preventiva se calibran 1 de 1
# 	sentence  28 :  tapa faldon se reparo durante la mantencion preventiva bajo la ot 13483
# 	sentence  29 :  se realiza mantencion preventiva se calibran 18 bocas mp no se realiza ya que eds se encuentra fuera de contrato
# 	sentence  30 :  mantencion preventiva se calibran 18 de 18 mp no se realiza ya que eds queda fuera de contrato
# 	sentence  31 :  se realiza mantencion preventiva
# 	sentence  32 :  mantencion preventiva mp no se realiza ya que eds se encuentra en remodelacion
# Cluster 6 : incidencia sera atendida por estacion de servicio ya que corresponde a cambio de accesorio
# 	sentence  0 :  cambio de manguera fue realiza por estacion de servicio
# 	sentence  1 :  incidencia sera atendida por estacion de servicio ya que corresponde a cambio de accesorio
# 	sentence  2 :  incidencia debe ser atendida por estacion de servicio ya que cuenta con mantencion delegada
# 	sentence  3 :  estimados reemplazo de pistola debe ser realizado por estacion de servicio
# 	sentence  4 :  reemplazo de accesorio debe ser realizado por la estacion de servicio
# 	sentence  5 :  incidencia corresponde a estacion de servicio
# 	sentence  6 :  cambio de accesorios corresponde a estacion de servicio
# 	sentence  7 :  reemplazo de accesorios corresponde a estacion de servicio
# 	sentence  8 :  cambios de accesorios corresponden a estacion de servicio
# 	sentence  9 :  cambio de acesorios debe ser realizado por estacion de servicio
# 	sentence  10 :  reemplazo de accesorio mangueras corresponde a estacion de servicio
# 	sentence  11 :  cambio de accesorios corresonde a la estacion de servicio ot cerrada
# 	sentence  12 :  estacion de servicio con contrato codo incidencia sera cerrada ya que el cambio de accesorios corresponde a estacion de servicio
# 	sentence  13 :  cambio de accesorio corresponde a las estacion de servicio se procede a cerrar incidencia
# 	sentence  14 :  cambio de accesorios corresponde a ees
# 	sentence  15 :  cambio de filtros corresponde a ees
# 	sentence  16 :  cambio de accesorios corresponde a ees
# 	sentence  17 :  se procede al cierre ya que la estacion cuenta con mantencion delegada
# 	sentence  18 :  incidencia se rechaza cambio filtros corresponde a ees
# 	sentence  19 :  incidencia es cerrada ya cambio de accesorios corresponde a ees
# 	sentence  20 :  se cierra orden ya que reemplazo de accesorios corresponde a eds
# 	sentence  21 :  se cierra incidencia estacion de servicio cambia filtros todo queda operativo
# 	sentence  22 :  incidencia corresponde a reemplazo de accesorios deben ser cambiados por eess
# 	sentence  23 :  se cierra ods ya que eds se encuentra fuera de servicio
# 	sentence  24 :  cambio de accesorios corresponde a estacion de servicio
# 	sentence  25 :  incidencia se cierra ya que el reemplazo de accesorio es responsabilidad de estacion de servicio tema reportado a marcos perales quien autoriza el cierre de la orden
# 	sentence  26 :  incidencia se cierra ya que la eds debe proceder al reemplazo de los filtros
# 	sentence  27 :  reemplazo de accesorio corresponde a estacion de servicio por ser mantencion delegada
# 	sentence  28 :  se cierra incidencia ya que corresponde a eds realizar el reemplazo del accesorio
# 	sentence  29 :  incidencia se cierra ya que la estacion es delegada el reemplazo de accesorios corresponde a la estacion
# 	sentence  30 :  se cierra incidencia ya que estacion es delegada y el reemplazo de accesorio corresponde a eds
# 	sentence  31 :  se procede al cierre de la orden por ser una estacion con mantencion delegada el reemplazo de accesorios compete a la estacion de servicio
# 	sentence  32 :  reemplazo de filtros compete a la estacion por ser mantencion delegada dodo
# 	sentence  33 :  cambio de manguera compete a la estacion mantencion delegada dodo
# 	sentence  34 :  se procedera al cierre de la ods debido a que la estacion cuenta con mantencion delegada codo por lo que segun contrato no esta contemplado el reemplazo de graficas
# 	sentence  35 :  se procedera al cierre de la ot debido a que la estacion cuenta con contrato dodo por lo cual el reemplazo de los accesorios mencionados en el requerimiento compete a la estacion de servicio
# 	sentence  36 :  estacion de servicio contrato dodo cambio de filtros compete a estacion de servicio
# 	sentence  37 :  estacion cuenta con mantencion delegada el reemplazo de accesorios corre por cuenta de la eds
# 	sentence  38 :  el despacho lento corresponde al filtros los cuales deben ser cambiados por administracion ya que estacion de servicio cuenta con mantencion delegada
# 	sentence  39 :  el despacho lento corresponde al filtros los cuales deben ser cambiados por administracion ya que estacion de servicio cuenta con mantencion delegada al igual que los accesorios
# 	sentence  40 :  el sensor de la pistola se encuentra danado pero incidencia se cierra online ya que estacion de servicio cuenta con mantencion delegada por lo tanto el cambio del accesorio debe ser cambio por ellos
# 	sentence  41 :  se cierra incidencia ya que estacion de servicio cuenta como mantencion delegada por lo tanto el cambio de filtros y accesorios corren por su cuenta y en el mes de enero se hara mantencion preventiva en la estacion de servicio
# 	sentence  42 :  estacion de servicio es delegada por lo tanto se da cierre a la incidencia conversado con rodrigo diez
# 	sentence  43 :  estacion de servicio cuenta con mantencion delegada por lo cual se le da cierre a la incidencia
# 	sentence  44 :  estacion de servicio cuenta con mantencion delegada por lo cual lo hace responsable del cambio de los accesorios en cuestion
# 	sentence  45 :  estacion de servicio cuenta con mantencion delegada por lo cual el accesorio en cuestion debe ser repuesto por la estacion
# 	sentence  46 :  estacion de servicio con mantencion delegada de igual forma se llamo al administrador y el mismo indico que hicieron el cambio del accesorio
# 	sentence  47 :  estacion de servicio cuenta con mantencion delegada por lo cual se cierra incidencia
# 	sentence  48 :  la estacion de servicio cuenta con mantencion delegada por lo cual se cierra incidencia
# Cluster 7 : ot fue atendida por contratista de enex
# 	sentence  0 :  cambio de graficas de equipos no esta contemplado en estaciones delegadas
# 	sentence  1 :  remplazo de graficas no esta contemplado en estaciones delegadas
# 	sentence  2 :  remplazo de graficas no esta contemplado en contrato para estaciones delegadas
# 	sentence  3 :  trabajos fueron realizados por empresa contratista
# 	sentence  4 :  sustitucion de graficas no estan contempladas en contrato estacion delegada
# 	sentence  5 :  solicitud es atendida mediante ot 27822
# 	sentence  6 :  incidencia es vista en ot 27708
# 	sentence  7 :  incidencia se atendera dentro de ot 27918
# 	sentence  8 :  se informa a cliente que incidencia debe derivarse a personal oprak ya que bajo la ot 6 se informo que se han realizado varias reparaciones y revisiones por parte de sgs y fallas indica mala senal de comunicacion entre surtidores y consola
# 	sentence  9 :  incidencia se esta atendiendo dentro de la ot 24052 que esta a espera de aprobacion por presupuesto
# 	sentence  10 :  incidencia es vista mediante la ot 27951
# 	sentence  11 :  incidencia fue cerrada el ot 27218
# 	sentence  12 :  se enviara a petrobras que esta variacion debe resolverla gilbarco por intervencion en consola veeder root
# 	sentence  13 :  se visita eds para chequeo de dispensadores los cuales se encuentran con adhesivos de selectores de productos en mal estado por lo tanto se solicitan 6 adhesivos de selectores de diesel para surtidores b7c para su reemplazo debe ser realizado por estacion de servicio ya que es delegada
# 	sentence  14 :  incidencia es vista mediante la ot 27951
# 	sentence  15 :  pintado de tapas se realizara en su proxima mp completa
# 	sentence  16 :  hubo un problema en la direccion de eds
# 	sentence  17 :  a la espera de generar el sidrep por parte de petrobras la inicidencia es vista mediante ot 26231
# 	sentence  18 :  incidencia fue vista en ot 27162
# 	sentence  19 :  no se realizara mp debido a que cuenta queda inactiva a solicitud de cliente christian g a traves de correo electronico
# 	sentence  20 :  incidencia es vista mediante la ot 26192 se envio motro trisfasico para reemplazo
# 	sentence  21 :  se solicitan graficas con botones para dispensador encore 500 31 para ser cambiados por dano de sol cambio de graficas no esta contemplada en estaciones delegadas
# 	sentence  22 :  estimados agradecere gestionar visita del instalador por garantia para la atencion de consola atg tls450 plus dado que esta instalacion fue recientemente remodelada atte mario castro campos
# 	sentence  23 :  incidencia se cierra en mp ot 26867
# 	sentence  24 :  tecnico para toma de numerales por cambio de operador el a las 1500 insidencia mal asignada
# 	sentence  25 :  tecnico para toma de numerales en cambio de operacion no se realiza cambio de operador fecha a definir nuevamente
# 	sentence  26 :  a traves de correo electronico christian g se informa que la cuenta se encuentra inactiva
# 	sentence  27 :  incidencia es anulada a peticion de jjzz informacion es entregada via mail por christian gonzalez
# 	sentence  28 :  se deja sin efecto la orden 3 sera visto por otro mantenedor
# 	sentence  29 :  incidencia fue cerrada bajo emergencia fuera de horario ot 26705
# 	sentence  30 :  incidencia fue cerrada bajo emergencia fuera de horario ot 26705
# 	sentence  31 :  incidencia es vista mediante la ot 27957
# 	sentence  32 :  ot no corresponde a nignun requerimiento
# 	sentence  33 :  a la espera de retiro de 5000 litros de agua desde sump en camara cabezal boma sumergida y sump de dispenser para poder reubicar sensores discriminador incidencia se esta viendo bajo ot 26231
# 	sentence  34 :  incidencia es cerrada ya que no pertenece a red enex
# 	sentence  35 :  se conversa telefonicamente con encargada jenni negue quien nos informa que la estacion de servicio se encuentra operativa ya que personal orpak asistio y soluciono la falla presentada
# 	sentence  36 :  se observa fuga en sello por codo giratorio p13736 ademas ausencia de wipehose 34 p16323 y breakaway 34 p13430 y filtracion por destorcedor 34 p19587 se requiere cambio de accesorios para surt 7 diesel se deja observacion de que se realizo cambio de concesionario en el cual se hizo levantamiento por accesorios en mal estadoincidencia se cierra bajo ot 25566
# 	sentence  37 :  se informa a petrobras que la incidencia es un error en el procedimiento de medicion se procede al cierre de la orden de servicio
# 	sentence  38 :  se cierra orden requerimiento no tiene nada que ver con solicitudes corresctivas ni preventivas y no existe en sgme
# 	sentence  39 :  cliente reasgino ot a otro contratista
# 	sentence  40 :  eds se encuentra en remodelacion
# 	sentence  41 :  incidencia se atiende dentro de ot 25533
# 	sentence  42 :  incidencia ya fue atendida con el reemplazo de detectores en ot 23228
# 	sentence  43 :  supervisor fernando huenupan informa via correo que equipo 2v debe ser cambiado
# 	sentence  44 :  incidencia se atendera dentro de ot 25717
# 	sentence  45 :  trabajos fueron realizados y registrados bajo la ot 6
# 	sentence  46 :  incidencia se atendera dentro de ot 26027
# 	sentence  47 :  incidencia se atendera dentro de ot 24490
# 	sentence  48 :  incidencia se atendera dentro de ot 25056
# 	sentence  49 :  se toma contacto con personal encargado del punto y se coordina visita para el lunes 0107 en jornada am incidencia se ejecutara todo en la mp el lunes 01 de julio
# 	sentence  50 :  incidencia se atendera dentro de ot 25715
# 	sentence  51 :  incidencia se atiende dentro de 25998
# 	sentence  52 :  incidencia se cierra ya que es un equipo pes con pistolas de tipo nuevas a solicitud de petrobras se re abre la orden de servicio y se realiza cambio de pistola y filtro
# 	sentence  53 :  incidencia es cerrada ya que cliente solicta el cambio de equipo modelo wayne dl1 se informa a cliente via mail
# 	sentence  54 :  cliente reasgina incidencia
# 	sentence  55 :  os reasginado por cliente
# 	sentence  56 :  incidencia dupliacada
# 	sentence  57 :  incidencia debe serivarse a orpak se informo por correo bajo la ot 4
# 	sentence  58 :  ods reasinada por el cliente
# 	sentence  59 :  ods mal asignada el dia 25 no se atendio emergencia en esta estacion
# 	sentence  60 :  se toma contacto telefonico con jefe de plaza antonio el cual nos informa que la estacion se encuentra se encuentra operativa estan trabajando con generador elcetrico ya que en la zona hay problemas de corte de energia
# 	sentence  61 :  ot cerrada dentro de ot 20642
# 	sentence  62 :  incidencia se atendera dentro de ot 24423
# 	sentence  63 :  estacion sin venta ninguna bomba funciona se comunica telefonicamente con eds quien indica estar con ventas normales y que el problema fue resuelto por personal de gilbarco
# 	sentence  64 :  incidencia se atendera dentro de ot 26163
# 	sentence  65 :  incidencia se cierra por que estacion es contrato codo y no aplica el reemplazo de graficas
# 	sentence  66 :  se cierra incidencia por no contener ningun tipo de requerimiento
# 	sentence  67 :  supervisor heraldo hinostroza tomo contacto telefonico con estacion de serivicio quienes comunican que la eds se encuentra operativa
# 	sentence  68 :  supervisor victor marticorena asistio al file y en conversacion con administrador le comenta que la incidencia es muy antigua y que ya habia sido atendida anteriormente todo esta ok en eds
# 	sentence  69 :  se envia informe a petrobras por variaciones presentadas
# 	sentence  70 :  se envia informe a petrobras por variaciones en eds
# 	sentence  71 :  se envia informe a petrobras por resultado de variaciones en eess
# 	sentence  72 :  incidencia se atendera dentro de ot 24968
# 	sentence  73 :  revisa variacion de mediciones se envia informe a petrobras por variaciones en eds
# 	sentence  74 :  faltan letreros de advertencia en zona de descarga de los tanques incidencia no corresponde a contrato combustibles
# 	sentence  75 :  estimados dejar sin efecto os favor no considerar la siguiente mantencion 20818dejar sin efecto la ot n 22385
# 	sentence  76 :  por orden christian gonzalez se cierra orden de servicio
# 	sentence  77 :  se envia informe a petrobras por variaciones en eds
# 	sentence  78 :  se envia informacion a petrobras por variaciones en eds
# 	sentence  79 :  se cierra incidencia ya que el cliente alejando padilla me informa que se vera por garantia con contratista
# 	sentence  80 :  se reasgino ot a otro contratista
# 	sentence  81 :  se envia informe a petrobras por variaciones en eds
# 	sentence  82 :  incidencia fue solicionada bajo ot35
# 	sentence  83 :  mp se realizara ot 7
# 	sentence  84 :  segun correo de christian gonzalez el file queda fuera de contrato a partir del 2908
# 	sentence  85 :  eds ya no existe
# 	sentence  86 :  mp fue ejecutada en agosto bajo la ot 7
# 	sentence  87 :  incidencia por estacion delegada se da cierre a ods codo validado por marcos perales
# 	sentence  88 :  trabajo no se realiza por no disponibilidad de electrico de turno para bloqueo de energia electrica
# 	sentence  89 :  ods para regularizar cobro
# 	sentence  90 :  se envia informe a petrobras con resultado de variacion
# 	sentence  91 :  la orden numero 1 a sido reasignada a otro contratista por tal motivo se cierra incidencia
# 	sentence  92 :  incidencia esta siendo revisada por analisis de variaciones interno se cierra orden una vez sea enviada informacion al cliente
# 	sentence  93 :  se envia informe a petrobras por variaciones presentadas
# 	sentence  94 :  se envia informe a petrobras por variacion en eds
# 	sentence  95 :  incidencia cerrada a solicitud de alejando padilla
# 	sentence  96 :  incidencia mal asignada la estacion correcta es la ees045 ya conversado con marcos perales
# 	sentence  97 :  se envia informe a petrobras por variaciones presentadas
# 	sentence  98 :  se envia informe a petrobras sobre variaciones en eds
# 	sentence  99 :  se envia informe a petrobras por variaciones presentadas
# 	sentence  100 :  incidencia es cerrada ya que se encuentra bajo cotizacion
# 	sentence  101 :  prueba de presion revision de camara de diesel verificacion volumetrica todas las bocas de diesel incidencia se atiende dentro de ot 25056
# 	sentence  102 :  ods mal emitida la instalcion fue realizada bajo la os 94417
# 	sentence  103 :  ot cerrada por eess fuera de servicio
# 	sentence  104 :  favor ingresar incidencia urgente estacion ees 227 ya que caneria galvanizada producto de los anos y sal marina se desgasto y esta con filtracion se requiere cotizacion urgente para reparar manana a la brevedad incidencia no corresponde a sgs
# 	sentence  105 :  incidencia ya fue resuleta es informada via mail
# 	sentence  106 :  se cierra incidencia debido a que mediante correo electronico de marcos perales informo que los tambores ya habian sido retirados
# 	sentence  107 :  se da cierre online a ot ya que ingeniero rodrigo delgado envia correo indicanco que no consideremos la ot asignada
# 	sentence  108 :  presupuesto desestimado por cliente
# 	sentence  109 :  incidencia fue asistida en la mp ejecutada el 07 de febrero por tecnico rene devia
# 	sentence  110 :  se realiza revison de detectores encontrandose ok
# 	sentence  111 :  incidencia es anulada via mail por christian gonzalez indicando equipo operan normal
# 	sentence  112 :  no se realiza visita mp no se ejecutara hasta nuevo aviso por parte de enex christian gonzalez
# 	sentence  113 :  eds mal generada
# 	sentence  114 :  os de prueba
# 	sentence  115 :  error en fecha de arribo
# 	sentence  116 :  incidencia es cerrada ya que punto queda inactivo de red enex
# 	sentence  117 :  mp no se realiza ya que pi queda inactivo de red enex
# 	sentence  118 :  se realiza vis telefono levantamiento de presion en linea hidraulica por veeder root quedando equipos con despacho
# 	sentence  119 :  tomada por error eds no entra dentro de contrato
# 	sentence  120 :  eds atendida por otro contratista confirmado por flavio cocas
# 	sentence  121 :  estacion es atendida por otro contratista confirmado por flavio cocas
# 	sentence  122 :  os mal creada
# 	sentence  123 :  se adjunta cotizacion en plataforma 2611 a la espera de aprobacion se procede a dar cierre a ot ya que no fue aprobada por csim
# 	sentence  124 :  se realiza comunicacion telefonica con administrador quien comenta que el brazo de carga cuenta con funcionalidad sin problema a nivel mecanico se confirma que el problema se da con la comunicacion del sistema por lo cual el tema debe ser derivado a otro contratista genaro nunez informa al cliente y se da cierre online de ods
# 	sentence  125 :  mal asiganda
# 	sentence  126 :  incidencia es cerrada ya que punto queda inactivo de red enex
# 	sentence  127 :  se realiza cambio de tapa adptador de vapores
# 	sentence  128 :  se envia informacion a enex de levantamiento actualizado via correo electronico se procede a cierre de ods
# 	sentence  129 :  se toma contacto con administrador se regulariza venta via telefonica
# 	sentence  130 :  se converso via telefonica con administradora la cual menciona que estacion ya se encuentra operativa hubo un corte de luz y la misma volvio a las 20min operando estacion de forma normal
# 	sentence  131 :  se cierra ods ya que la instalacion de los equipos fue hace un mes y se derivara a mantenedor que hizo la instalacion se notifica a enex
# 	sentence  132 :  atendido por otro mantenedor
# 	sentence  133 :  se da cierre a ot ya que las cotizaciones enviadas via correo a rodrigo delgado no fueron aprobadas y se vencieron los plazos de las cotizaciones
# 	sentence  134 :  queda pendiente confeccion de regla se realiza confeccion de 2 reglas e instalacion en tk diesel y gas 95
# 	sentence  135 :  se realiza el cambio de 4 filtros spin on quedando equipo operativo
# 	sentence  136 :  se realiza la confeccion e instalacion de 2 reglas quedando ok
# 	sentence  137 :  se envia informe de levantamiento a flavio cocas enex se cierra ods
# 	sentence  138 :  se envia informe a enex sobre levantamiento se da cierre ya que el informe fue enviado por correo a flavio cocas
# 	sentence  139 :  incidencia no se atendio ya que rodrigo diez no informo que no se requeria la toma de muestra
# 	sentence  140 :  incidencia es cerrada ya que hay que generar informe desde la instalacion de equipo
# 	sentence  141 :  se realiza revison de valvula de sobrellenado encontrandose ok se cambia 1 tapa adapatador descarga 4
# 	sentence  142 :  se realiza el cambio de 2 tapa caja vereda quedando ok
# 	sentence  143 :  incidencia atendida por administrador de la estacion
# 	sentence  144 :  accesorios entregados a sercon
# 	sentence  145 :  incidencia se cierra online debido a que el problema se genero por una mala descarga de acuerdo a lo indicado por petrobras
# 	sentence  146 :  se realiza la confeccion e instalacion de 3 reglas quedando ok
# 	sentence  147 :  ot fue atendida por contratista de enex
# 	sentence  148 :  se da cierre ya que luminarias reparadas por contratista externo designado por enex
# 	sentence  149 :  se da cierre ya que ha sido asignada a otro contratista
# 	sentence  150 :  se realiza el cambio de 1 regla tk 1 diesel 15m3 quedando ok
# 	sentence  151 :  se cierra ods ya que estacion no corresponde atender por sgs correo confirmado por flavio cocas enex
# 	sentence  152 :  se realiza el cambio de 1 tapa caja vereda p15211 quedando ok
# 	sentence  153 :  incidencia fue asistida en la ejecucion de mp
# 	sentence  154 :  incidencia dupliacada
# 	sentence  155 :  eeror de carga
# 	sentence  156 :  incidencia es cerrada ya que en pi se esta realizando cambio de equipo por otro mantenedor
# 	sentence  157 :  se realiza el cambio de 1 filtro baja capacidad quedando equipo operativo
# 	sentence  158 :  se realiza el cambio de 1 teclado predeterminador equipo 2v p14911 quedando equipo operativo
# 	sentence  159 :  por solicitud de rodrigo delgado se descarta la orden de trabajo
# 	sentence  160 :  por solicitud de rodrigo delgado se descarta la orden de trabajo
# 	sentence  161 :  se envia guia informativa para cambio de hora en veeder root a
# 	sentence  162 :  se envia documento guia para cambio de hora en veeder root para que la administracion de estacion de servicio pueda realizar el cambio de horario sin dificultad
# 	sentence  163 :  segun lo conversado con don rodrigo delgado se envio documento guia para cambio de hora en equipo veeder root tls350 para que la estacion de servicio pueda realizar el cambio de horario en el veeder root
# 	sentence  164 :  se realiza el cambio de 1 tapa caja vereda quedando ok
# 	sentence  165 :  se da cierre online debido a que en correo electronico se le indico a alejandro padilla la cual se produce debido a que la anterior regla estaba desgastada por lo cual al instalar la nueva regla presenta diferencia la cual fue reportada en la orden de servicio 8
# 	sentence  166 :  se realiza el cambio de 1 pulser quedando equipo operativo
# 	sentence  167 :  queda pendiente la confeccion e instalacion de reglas se realiza confeccion e instalacion de 2 reglas en pi quedando operativo
# 	sentence  168 :  no ser realiza mp pi fuera de red de atencion enex
# 	sentence  169 :  se da cierre ya que la eess no forma parte de las eess que atiende sgs
# 	sentence  170 :  incidencia es anulada ya que el viernes 27 se ejecutara mp en pi
# 	sentence  171 :  se solicita reasignacion a enex
# 	sentence  172 :  incidencia fue asistida bajo ot 9 en donde cliente se comunico dorecto con mantenedor externo para que reparar controlador de flota
# 	sentence  173 :  se toma contacto con personal de eds en donde nos informa que equipos operan ok
# 	sentence  174 :  alarma l3 corresponde tank sump n3 diesel con agua se requiere traer bomba y 05 tambores para extraer el aguacon respecto a la alarma de detector de fuga la bomba n2 de 97 esta operativa ods periodo vencido 2018
# 	sentence  175 :  os mal eimitida
# 	sentence  176 :  os mal eimitida
# 	sentence  177 :  os mal eimitida
# 	sentence  178 :  os mal eimitida
# 	sentence  179 :  os mal emitiada
# 	sentence  180 :  se realiza el cambio de 1 tapa caja vereda quedando ok
# Cluster 8 : cliente reasigno incidencia ya que corresponde a otro contratista
# 	sentence  0 :  file fuera de contrato orden fue reasignada
# 	sentence  1 :  orden reasignada
# 	sentence  2 :  orden reasignada por cliente
# 	sentence  3 :  orden de servicio reasignada por cliente
# 	sentence  4 :  orden reasignada por cliente
# 	sentence  5 :  cliente reasigno incidencia ya que corresponde a otro contratista
# 	sentence  6 :  se le informa a cliente que ods debe ser reasignada ya que esta fuera de contrato
# 	sentence  7 :  ods sera reasignada por cliente a otro contratista
# 	sentence  8 :  ods reasignada
# 	sentence  9 :  ods reasignada por cliente
# 	sentence  10 :  ods reasignada
# 	sentence  11 :  requerimiento sera reasignado a otra contratista
# 	sentence  12 :  ordenes seran reasignadas a otra contratista
# 	sentence  13 :  ods reasignada por cliente
# 	sentence  14 :  requerimiento sera reasignada a otra contratista
# 	sentence  15 :  incidencia reasignada por cliente
# 	sentence  16 :  incidencia reasignada por cliente
# 	sentence  17 :  incidencia reasignada a otro contratista
# 	sentence  18 :  incidencia reasignada por cliente enex
# 	sentence  19 :  incidencia fue reasignada a otro contratista
# 	sentence  20 :  incidencia fue reasignada a otra contratista
# 	sentence  21 :  incidencia fue reasignada a otro contratista
# 	sentence  22 :  incidencia fue reasignada por cliente
# 	sentence  23 :  incidencia es reasignada a otro mantenedor
# 	sentence  24 :  incidencia sera reasignada a otro mantenedor
# 	sentence  25 :  ods reasignada por cliente a otro contratista
# 	sentence  26 :  ods reasignada por cliente
# 	sentence  27 :  ods reasignada por cliente
# 	sentence  28 :  ods reasignada por cliente
# 	sentence  29 :  ods reasignada por cliente
# 	sentence  30 :  ot reasignada a otro contratista
# 	sentence  31 :  ot reasignada por cliente
# 	sentence  32 :  ot reasignada por cliente
# 	sentence  33 :  ot reasignada por cliente
# 	sentence  34 :  ot reasignada por cliente
# 	sentence  35 :  ot reasignada por cliente
# 	sentence  36 :  ot reasignada a otro contratista
# 	sentence  37 :  ot reasignada por cliente
# 	sentence  38 :  ot reasignada por cliente
# 	sentence  39 :  ot reasignada por cliente
# 	sentence  40 :  ot reasignada por cliente
# 	sentence  41 :  ot reasignada por cliente
# 	sentence  42 :  ot reasignada a cliente
# 	sentence  43 :  ot reasignada por cliente
# 	sentence  44 :  incidencia reasignada por enex
# 	sentence  45 :  reasignada por enex a otro contratista
# 	sentence  46 :  incidencia reasignada por enex
# 	sentence  47 :  ods reasignada a otro contratista
# Cluster 9 : incidencia mal emitida
# 	sentence  0 :  incidencia mal emitida
# 	sentence  1 :  orden mal emitida
# 	sentence  2 :  os mal emitida
# 	sentence  3 :  os mal emitida
# 	sentence  4 :  os mal emitida
# 	sentence  5 :  os mal emitida
# 	sentence  6 :  os mal emitida
# 	sentence  7 :  os mal emitida
# 	sentence  8 :  os mal emitida
# 	sentence  9 :  os mal emitida
# 	sentence  10 :  os mal emitida
# 	sentence  11 :  os mal emitida
# 	sentence  12 :  os mal emitida
# 	sentence  13 :  os mal emitida
# 	sentence  14 :  os mal emitida
# 	sentence  15 :  os mal emitida
# 	sentence  16 :  os mal emitida
# 	sentence  17 :  os mal emitida
# 	sentence  18 :  os mal emitida
# 	sentence  19 :  os mal emitida
# 	sentence  20 :  os mal emitida
# 	sentence  21 :  os mal emitida
# 	sentence  22 :  os mal emitida
# 	sentence  23 :  os mal emitida
# 	sentence  24 :  os mal emitida
# 	sentence  25 :  os mal emitida
# 	sentence  26 :  os mal emitida
# 	sentence  27 :  os mal emitida
# 	sentence  28 :  os mal emitida
# 	sentence  29 :  os mal emitida
# 	sentence  30 :  os mal emitida
# 	sentence  31 :  os mal emitida
# 	sentence  32 :  os mal emitida
# 	sentence  33 :  os mal emitida
# ...
# 	sentence  58 :  incidencia no corresponde a sgs
# 	sentence  59 :  eds fuera de contrato
# 	sentence  60 :  incidencia se encuentra fuera de contrato
# 	sentence  61 :  eds fuera de contrato
# 	sentence  62 :  eds fuera de contrato
# 	sentence  63 :  incidencia se encuentra fuera de contrato
# 	sentence  64 :  incidencia se encuentra fuera de contrato
# 	sentence  65 :  incidencia se encuentra fuera de contrato
# 	sentence  66 :  ods sera derivada a contratista correspondiente ya que corresponde a imagen del equipo no entra dentro de los alcances del contrato
# 	sentence  67 :  incidencia no corresponde
# 	sentence  68 :  ods no corresponde a adhesivos que instale sgs
# 	sentence  69 :  incidencia no corresponde a sgs debe ser derivada a contratista correspondiente
# 	sentence  70 :  incidencia no corresponde a sgs por lo tanto se cierra ot
# 	sentence  71 :  se da cierre a ods ya que el file corresponde a estacion de mineria no corresponde a sgs correo confirmado por flavio cocas enex
# 	sentence  72 :  incidencia no corresponde a sgs
# 	sentence  73 :  incidencia no corresponde a sgs
# Cluster 14 : ods mal ingresado
# 	sentence  0 :  os mal ingresada
# 	sentence  1 :  os mal ingresada
# 	sentence  2 :  mal ingresada
# 	sentence  3 :  ods mal ingresado
# 	sentence  4 :  os mal ingresada
# 	sentence  5 :  ods mal ingresada
# 	sentence  6 :  ods mal ingresada
# 	sentence  7 :  mal ingresada
# 	sentence  8 :  ods mal ingresada
# 	sentence  9 :  ods mal ingresada
# 	sentence  10 :  mal ingresada
# 	sentence  11 :  mal ingresada
# 	sentence  12 :  ods mal ingresada
# 	sentence  13 :  mal ingresada
# 	sentence  14 :  mal ingresada
# 	sentence  15 :  ods mal ingresada
# 	sentence  16 :  mal ingresada
# 	sentence  17 :  ods mal ingresada
# 	sentence  18 :  ods mal ingresada
# 	sentence  19 :  mal ingresada
# 	sentence  20 :  ods mal ingresada
# Cluster 15 : ot anulada por el cliente para ser atendida bajo ot 4
# 	sentence  0 :  incidencia anulada por enex
# 	sentence  1 :  orden anulada por cliente requerimiento se atender en mp de junio
# 	sentence  2 :  orden anulada por enex
# 	sentence  3 :  fuera de contrato se anula
# 	sentence  4 :  orden de trabajo fue anulada por cliente
# 	sentence  5 :  incidencia es anulada ya que anomalia corresponde a orpack
# 	sentence  6 :  incidencia es anulada
# 	sentence  7 :  ods anulada por cliente
# 	sentence  8 :  ods anulada por cliente
# 	sentence  9 :  ods anulada por cliente
# 	sentence  10 :  ods es anulada por encontrarse repetida
# 	sentence  11 :  ods anulada por cliente
# 	sentence  12 :  ods fue eliminada ya que eds atendio por su cuenta la ods se libero la ot 0 para anular esta
# 	sentence  13 :  ods fue eliminada ya que eds atendio por su cuenta la ods se libero la ot 0 para anular esta
# 	sentence  14 :  ods fue eliminada ya que eds atendio por su cuenta la ods se libero la ot 0 para anular esta
# 	sentence  15 :  anulada por enex
# 	sentence  16 :  ot anulada por cliente
# 	sentence  17 :  ot anulada por cliente
# 	sentence  18 :  ot anulada por cliente
# 	sentence  19 :  ot anulada por cliente bajo ot 8
# 	sentence  20 :  ods anulada por enex
# 	sentence  21 :  ot anulada por el cliente para ser atendida bajo ot 4
# 	sentence  22 :  anulada por cliente
# 	sentence  23 :  ot anulada por cliente
# 	sentence  24 :  orden anulada por enex
# 	sentence  25 :  ot anulada por el cliente
# Cluster 16 : incidencia es atendida bajo ot 1
# 	sentence  0 :  incidencia se cierra bajo ot 27406
# 	sentence  1 :  incidencia se cierra bajo ot 27113
# 	sentence  2 :  incidencia es vista bajo la ot 26837
# 	sentence  3 :  incidencia fue resuelta bajo ot 4 quedando ok
# 	sentence  4 :  incidencia se cierra bajo ot 26801
# 	sentence  5 :  incidencia cerrada bajo la ot 1
# 	sentence  6 :  incidencia se cierra bajo mp ot 25474
# 	sentence  7 :  incidencia cerrada bajo la ot 26440
# 	sentence  8 :  os se atiende bajo ot 26392
# 	sentence  9 :  incidencia es cerrada bajo ot 26505
# 	sentence  10 :  indencia fue atendida bajo ot 26094
# 	sentence  11 :  incidencia es atendida bajo ot 25185
# 	sentence  12 :  incidencia es atendida bajo ot 25765
# 	sentence  13 :  incidencia se atiende bajo ot 20892
# 	sentence  14 :  incidencia es atendida bajo ot 8
# 	sentence  15 :  incidencia esta siendo atendida bajo ot 25214
# 	sentence  16 :  incidencia se cierra segun lo solicitado bajo la ot 8
# 	sentence  17 :  incidencia es atendida bajo ot 26663
# 	sentence  18 :  incidencia se atiende bajo ot 20892
# 	sentence  19 :  incidencia se atiende bajo ot 24496
# 	sentence  20 :  incidencia siendo atendida bajo ot 24473
# 	sentence  21 :  requerimiento atendido bajo la ot 1
# 	sentence  22 :  incidencia fue atendida y cerrada bajo ot 8
# 	sentence  23 :  incidencia siendo atendida bajo ot 24345
# 	sentence  24 :  incidencia atendida y cerrada bajo la ot 8
# 	sentence  25 :  incidencia fue atendida bajo la ot 6
# 	sentence  26 :  incidencia atendida bajo ot 22916
# 	sentence  27 :  incidencia se atiende bajo ot 21912
# 	sentence  28 :  incidencia se atiende bajo ot 21912
# 	sentence  29 :  incidencia atendida bajo ot 20892
# 	sentence  30 :  incidencia atendida dentro de ot 22916
# 	sentence  31 :  falla atendida y solucionada bajo la ot 4
# 	sentence  32 :  requerimiento atendido bajo ot 6
# 	sentence  33 :  incidencia siendo atendida bajo ot 24345
# 	sentence  34 :  incidencia fue atendida bajo ot 22916
# 	sentence  35 :  incidencia siendo atendida bajo ot 24345
# 	sentence  36 :  mp se realizara bajo la ot 8
# 	sentence  37 :  mp se realiza bajo ot 4
# 	sentence  91 :  se esta atendiendo bajo ods 1
# 	sentence  92 :  incidencia es atendida bajo ot 8
# 	sentence  93 :  incidencia atendida bajo ods 8
# 	sentence  94 :  incidencia es atendida bajo ot 8
# 	sentence  95 :  se cierra bajo ods 4
# 	sentence  96 :  incidencia es atendida bajo ot 1
# 	sentence  97 :  incidencia es atendida bajo ot 4
# 	sentence  98 :  ot esta siendo atendida bajo ods 4
# 	sentence  99 :  incidencia es atendida bajo ot 6
# 	sentence  100 :  incidencia es atendida bajo ot 6
# 	sentence  101 :  incidencia es atendida bajo ot 6
# 	sentence  102 :  incidencia es atendida bajo ot 6
# 	sentence  103 :  incidencia es atendida bajo ot 1
# 	sentence  104 :  incidencia es atendida bajo ot 4
# 	sentence  105 :  incidencia es atendida en la mp
# 	sentence  106 :  incidencia es atendida bajo ot 4
# 	sentence  107 :  incidencia es atendida bajo ot 7
# 	sentence  108 :  incidencia es atendida bajo ot 7
# 	sentence  109 :  incidencia es atendida bajo ot 4
# 	sentence  110 :  incidencia es atendida bajo ot 4
# 	sentence  111 :  se cierra bajo ot 8
# 	sentence  112 :  incidencia es atendida bajo ot 4
# 	sentence  113 :  incidencia es atendida bajo ot 4
# 	sentence  114 :  incidencia es atendida bajo ot 4
# 	sentence  115 :  incidencia es atendida bajo ot 7
# 	sentence  116 :  inicidencia es atendida bajo ot 4
# 	sentence  117 :  inicidencia es atendida bajo ot 4
# 	sentence  118 :  incidencia es atendida bajo ot 8
# 	sentence  119 :  incidencia es atendida bajo ot 8
# 	sentence  120 :  se cierra bajo ot 8
# 	sentence  121 :  incidencia fue atendida bajo la ot 15960
# 	sentence  122 :  incidencia es atendida bajo ot 1
# 	sentence  123 :  se da cierre bajo la ot 6
# 	sentence  124 :  incidencia es atendida bajo ot 1
# 	sentence  125 :  incidencia atendida bajo ods 6
# 	sentence  126 :  incidencia es atendida bajo ot 1
# 	sentence  127 :  incidencia es atendida bajo ot 8
# 	sentence  128 :  incidencia es atendida bajo ot 1
# 	sentence  129 :  incidencia es atendida bajo ot 1
# 	sentence  130 :  incidencia es atendida bajo ot 1
# 	sentence  131 :  incidencia es atendida bajo ot 6
# 	sentence  132 :  incidencia es atendida bajo ot 1
# 	sentence  133 :  incidencia es atendida bajo ot 1
# 	sentence  134 :  incidencia es atendida bajo ot 6
# 	sentence  135 :  incidencia es atendida bajo ot 1
# 	sentence  136 :  incidencia es atendida bajo ot 8
# 	sentence  137 :  incidencia es atendida bajo ot 8
# Cluster 17 : incidencia atendida bajo ot 3
# 	sentence  0 :  incidencia atendida dentro de ot 3
# 	sentence  1 :  requerimiento fue atendida bajo la ot 3
# 	sentence  2 :  mp sera ejecutada bajo la ot 3
# 	sentence  3 :  mp se realiza bajo la ot 3 en mes de agosto
# 	sentence  4 :  mp se realiza en agosto bajo la ot 3
# 	sentence  5 :  incidencia atendida bajo ot 3
# 	sentence  6 :  incidencia es atendida bajo ot 3
# 	sentence  7 :  incidencia atendida bajo ods 3
# 	sentence  8 :  incidencia atendida bajo ods 3
# 	sentence  9 :  incidencia es atendida bajo ot 3
# 	sentence  10 :  ot se cierra bajo ot 3
# 	sentence  11 :  incidencia es atendida bajo ot 3
# 	sentence  12 :  incidencia es atendida bajo ot 3
# 	sentence  13 :  incidencia es atendida bajo ot 3
# 	sentence  14 :  incidencia es atendida bajo ot 3
# 	sentence  15 :  incidencia es atendida bajo ot 3
# 	sentence  16 :  incidencia es atendida bajo ot 3
# 	sentence  17 :  incidencia es atendida bajo ot 3
# 	sentence  18 :  incidencia es atendida bajo ot 3
# 	sentence  19 :  incidencia es atendida bajo ot 3
# 	sentence  20 :  incidencia es atendida bajo ot 3
# 	sentence  21 :  incidencia es atendida bajo ot 3
# 	sentence  22 :  incidencia es atendida bajo ot 3
# 	sentence  23 :  incidencia es atendida bajo os 83239 y ot 3
# 	sentence  24 :  incidencia es atendida bajo ot 3
# Cluster 18 : incidencia duplicada
# 	sentence  0 :  ods duplicada
# 	sentence  1 :  incidencia duplicada con ot 25540
# 	sentence  2 :  orden duplicada
# 	sentence  3 :  se cierra por duplicado de os
# 	sentence  4 :  orden duplicada
# 	sentence  5 :  cerrada por estar duplicada
# 	sentence  6 :  orden duplicada
# 	sentence  7 :  orden duplicada no se atendio ya que se encuentra fuera de contrato ot 6
# 	sentence  8 :  incidencia duplicada
# 	sentence  9 :  incidencia duplicada el requerimiento se atendera bajo la ot 18048
# 	sentence  10 :  os duplicada
# 	sentence  11 :  os duplicada
# 	sentence  12 :  incidencia duplicada
# 	sentence  13 :  incidencia duplicada
# 	sentence  14 :  incidencia duplicada
# 	sentence  15 :  incidencia duplicada
# 	sentence  16 :  incidencia duplicada
# 	sentence  17 :  incidencia duplicada
# 	sentence  18 :  duplicado
# 	sentence  19 :  duplicado
# 	sentence  20 :  incidencia duplicada
# Cluster 19 : incidencia es atendida bajo ot 0
# 	sentence  0 :  incidencia fue ejecutada bajo os 102588 y ot 0
# 	sentence  1 :  mp se realizo bajo la ot 0
# 	sentence  2 :  incidencia se atendio bajo la ot 0
# 	sentence  3 :  mp se realizara bajo ot 0
# 	sentence  4 :  incidencia es atendida bajo ot 0
# 	sentence  5 :  incidencia atendida bajo ods 0
# 	sentence  6 :  ot se atendera bajo ot 0
# 	sentence  7 :  incidencia es atendida bajo ot 0
# 	sentence  8 :  incidencia es atendida bajo ot 0
# 	sentence  9 :  incidencia fue asistida bajo ot 0
# 	sentence  10 :  incidencia es atendida bajo ot 0
# 	sentence  11 :  incidencia es atendida bajo ot 0
# 	sentence  12 :  incidencia es atendida bajo ot 0
# 	sentence  13 :  incidencia es atendida bajo ot 0
# 	sentence  14 :  incidencia es atendida bajo ot 0
# 	sentence  15 :  incidencia es atendida bajo ot 0
# 	sentence  16 :  incidencia es atendida bajo ot 0
# 	sentence  17 :  incidencia es atendida bajo ot 0
# 	sentence  18 :  incidencia es atendida bajo ot 0
# 	sentence  19 :  incidencia es atendida bajo ot 0
# 	sentence  20 :  incidencia es atendida bajo ot 0
# 	sentence  21 :  incidencia es atendida bajo ot 0
# Cluster 20 : incidencia es atendida bajo ot 5
# 	sentence  0 :  requerimiento atendido bajo ot 5
# 	sentence  1 :  incidencia atendida y solucionada bajo la ot 5
# 	sentence  2 :  mp se realizara bajo la ot 5
# 	sentence  3 :  relacionada con la ot 5
# 	sentence  4 :  incidencia atendida bajo la mp ot 5
# 	sentence  5 :  incidencia atendida bajo ods 5
# 	sentence  6 :  incidencia atendida bajo ods 5
# 	sentence  7 :  incidencia es atendida bajo ot 5
# 	sentence  8 :  inciencia atendida bajo ods 5
# 	sentence  9 :  incidencia es atendida bajo ot 5
# 	sentence  10 :  incidencia es atendida bajo ot 5
# 	sentence  11 :  incidencia es atendida bajo ot 5
# 	sentence  12 :  incidencia es atendida bajo ot 5
# 	sentence  13 :  incidencia es atendida bajo ot 5
# 	sentence  14 :  incidencia es atendida bajo ot 5
# 	sentence  15 :  incidencia es atendida bajo ot 5
# 	sentence  16 :  incidencia es atendida bajo ot 5
# 	sentence  17 :  incidencia es atendida bajo ot 5
# 	sentence  18 :  se cierra bajo ot 5
# Cluster 21 : incidencia atendida bajo la ot 9
# 	sentence  0 :  incidencia sera atendida bajo ot 9
# 	sentence  1 :  incidencia atendida bajo la ot 9
# 	sentence  2 :  mp se realizara bajo la ot 9
# 	sentence  3 :  mp sera realizada bajo la ot 9
# 	sentence  4 :  mp se realizara bajo ot 9
# 	sentence  5 :  mp se realizo en agosto bajo ot 9
# 	sentence  6 :  ods atendida bajo ot 9
# 	sentence  7 :  incidencia atendida bajo ods 9
# 	sentence  8 :  se cierra incidencia bajo ot 9
# 	sentence  9 :  incidencia es atendida bajo ot 9
# 	sentence  10 :  incidencia es atendida bajo ot 9
# 	sentence  11 :  incidencia atendida bajo ods 9
# 	sentence  12 :  incidencia es atendida bajo ot 9
# 	sentence  13 :  incidencia es atendida bajo ot 9
# 	sentence  14 :  incidencia es atendida bajo ot 9
# 	sentence  15 :  incidencia es atendida bajo ot 9
# 	sentence  16 :  incidencia es atendida bajo ot 9
# 	sentence  17 :  incidencia es atendida bajo ot 9
# 	sentence  18 :  incidencia es atendida bajo ot 9
# Elapsed time: 1.2172858715 seconds.

# %%
# Clusters representativos (con n = 22)
for cluster in range(nclusters):
    print ("\033[1mCluster ",cluster,":\033[0m",sentences[clusters[cluster][representativos[cluster]]])
# Out:
# Cluster  0 : duplicaron la ot incidencia sera atendida bajo la ot 19487
# Cluster  1 : ods mal emitida
# Cluster  2 : incidencia mal asignada
# Cluster  3 : incidencia se cierra ya que no corresponde a contrato combustibles
# Cluster  4 : incidencia atendida bajo la ot 2
# Cluster  5 : mantencion preventiva sera atendida bajo ot 1
# Cluster  6 : incidencia sera atendida por estacion de servicio ya que corresponde a cambio de accesorio
# Cluster  7 : ot fue atendida por contratista de enex
# Cluster  8 : cliente reasigno incidencia ya que corresponde a otro contratista
# Cluster  9 : incidencia mal emitida
# Cluster  10 : ot periodo vencido incidencia atendida bajo ot 20175
# Cluster  11 : se cierra por error de carga incidencia ya tenia ot
# Cluster  12 : se cierra os ya que a partir de que se enlazaron los sistemas de sysqmr y csim se crearon os y ot automaticas duplicando las os de mp
# Cluster  13 : incidencia no corresponde a sgs por lo tanto se cierra ot
# Cluster  14 : ods mal ingresado
# Cluster  15 : ot anulada por el cliente para ser atendida bajo ot 4
# Cluster  16 : incidencia es atendida bajo ot 1
# Cluster  17 : incidencia atendida bajo ot 3
# Cluster  18 : incidencia duplicada
# Cluster  19 : incidencia es atendida bajo ot 0
# Cluster  20 : incidencia es atendida bajo ot 5
# Cluster  21 : incidencia atendida bajo la ot 9

# %%
# Plot - Cantidad de sentences por cluster
len_clusters(dic=clusters,n = nclusters, save = False)

# %% [markdown]
# # III. REQUERIMIENTOS

# %%
# SELECCIONANDO UN ESTADO OT ('PENDIENTE')
df = df_total[df_total[columna] == elemento] 
sentences = [sent for sent in df['Requerimiento']]
len(sentences)
# Out:
# 1302

# %%
# Extracto req 
sentences[:2]
# Out:
# ['area de atencion combustible maria veronica godoy estimados favor generar incidencia por lo siguiente se solicita adhesivos botoneras selector de producto adhesivo 93 cantidad 6 adhesivo 95 cantidad 6 adhesivo diesel cantidad 4 codigo de ubicacion tecnica ees246 saludos cordiales maria veronica godoy administradora eds petrobras',
#  'area de atencion combustible cambiar graficas de surtidores ya que estan un poco deterioradas y la ultima inspeccion se mandaron a cambiar jose antonio martinez']

# %%
# %%time
# Identificando el número óptimo de clústers por medio del método del Elbow
elbow_method(sentences, save = False)
# Out:
# Número óptimo de clústers: 14
# Wall time: 15 s

# %%
# %%time
# Identificando el número óptimo de clústers por medio del Análisis de Silueta
silhouette_analysis(sentences, n_clusters=[10,14,18], name='OnlineREQ', save=False)
# Out:
# Wall time: 5.3 s

# %%
# Ejecutando el algoritmo Kmeans para el número óptimo de clústers 
print('\033[1mCLUSTERS \n\033[0m')
start_time = time()

nclusters= 10
clusters,representativos = cluster_sentences(sentences, nclusters)

for cluster in range(nclusters):
    print (f"\033[1mCluster {cluster} : {sentences[clusters[cluster][representativos[cluster]]]}\033[0m")
    for i,sentence in enumerate(clusters[cluster]):
        print ("\tsentence ",i,": ",sentences[sentence])

elapsed_time = time() - start_time
print("\033[1mElapsed time: %.10f seconds.\033[0m" % elapsed_time)
# Out:
# CLUSTERS
#
# Cluster 0 : programacion mantencion preventiva
# 	sentence  0 :  programacion mantencion preventiva
# 	sentence  1 :  programacion mantencion preventiva
# 	sentence  2 :  programacion mantencion preventiva
# 	sentence  3 :  programacion mantencion preventiva
# 	sentence  4 :  programacion mantencion preventiva
# 	sentence  5 :  programacion mantencion preventiva
# 	sentence  6 :  programacion mantencion preventiva
# 	sentence  7 :  programacion mantencion preventiva
# 	sentence  8 :  programacion mantencion preventiva
# 	sentence  9 :  programacion mantencion preventiva
# 	sentence  10 :  programacion mantencion preventiva
# 	sentence  11 :  programacion mantencion preventiva
# 	sentence  12 :  programacion mantencion preventiva
# 	sentence  13 :  programacion mantencion preventiva
# 	sentence  14 :  programacion mantencion preventiva
# 	sentence  15 :  programacion mantencion preventiva
# 	sentence  16 :  programacion mantencion preventiva
# 	sentence  17 :  programacion mantencion preventiva
# 	sentence  74 :  area de atencion combustible la parte donde se cuelga la manguera se desprendio del dispensador n 7 de petroleo el problema causo que estacion se encuentre con una isla menos
# 	sentence  75 :  area de atencion combustible don rodrigo indica que le falta funda de pistola en surtidor 8 de diesel de alto octanage
# 	sentence  76 :  area de atencion brazo de carga con fuga de combustible solicitado por claudio gomez fono
# 	sentence  77 :  area de atencion surtidor 2 no funciona aparece en pantalla surtidor malo se reporto a orpak con el numero 7 y dicen que debe verlo mantencion solicitado por jaime martinez fono
# 	sentence  78 :  area de atencion combustible surtidor 12 pes no despacha roxana mera loyola 8
# 	sentence  79 :  area de atencion combustible solicita cambio de filtros 4 de gasolina y 2 de diesel eustolio munoz
# 	sentence  80 :  area de atencion combustible solicita cambio de manguera para surtidor 6 de gasolina eustolio munoz
# 	sentence  81 :  area de atencion surtidor no corta solicitado por jorge charad fono
# 	sentence  82 :  area de atencion combustible favor programar cambio de filtro por surtidores lentos diesel gasolina 93 saludos
# 	sentence  83 :  area de atencion combustible surtidor 3 gasolina manguera se solto del breakaway
# 	sentence  84 :  area de atencion combustible se solicita el retiro de 2 tambores con agua contaminada
# 	sentence  85 :  area de atencion problemas con bomba y fuga de combustible solicitado por nicolas munoz fono
# 	sentence  86 :  area de atencion problemas con manguera y bombas del surtidor solicitado por nicolas munoz fono
# 	sentence  87 :  area de atencion manguera danada con filtracion de combustible solicitado por rodrigo jelves fono
# 	sentence  88 :  area de atencion combustible se solicita calibracion de las gasolinas ya que hay un sobrante en gas 93 y faltante en gas 97
# 	sentence  89 :  problemas en surtidor
# 	sentence  90 :  area de atencion los surtidores despachan lento solicitado por carol plazas fono
# 	sentence  91 :  cambio del manguerote del surtidor combustible de cma
# 	sentence  92 :  area de atencion combustible se solicita revision de presion de linea para el producto 93
# 	sentence  93 :  mantencion preventiva cambio de filtros y surtidor
# 	sentence  94 :  choque a surtidor
# 	sentence  95 :  area de atencion combustible cambio de mangueras del surtidor del diesel y gas 93 2 magueras de diesel y gas 93 alonso ojeda
# 	sentence  96 :  no se puede despachar combustible de 95 en toda la estacion
# 	sentence  97 :  area de atencion combustible surtidores 1 2 3 y 4 con problemas graves de despacho de combustible solicita urgentemente servicio tecnico juan ignacio marcoleta
# 	sentence  98 :  se chequea surtidor 910 por no expender
# 	sentence  99 :  cliente llama por segunda vez por problema de surtidor favor asistir de manera urgente surtidor despacha lento
# 	sentence  100 :  area de atencion combustible surtidor 4 con filtracion en pistola bencina
# 	sentence  101 :  area de atencion combustible surtidor 9 y 10 no estan operativos moises varas
# 	sentence  102 :  area de atencion combustible se requiere cambio de valvula del surtidor del aire para neumaticos
# 	sentence  103 :  surtidor malo
# 	sentence  104 :  area de atencion combustible surtidor de diesel n 1 y 2 senala que estan muy lentos al momento de cargar combustible
# 	sentence  105 :  sin despacho de 97 y 95
# 	sentence  106 :  area de atencion combustible en sump de dispensadores 5 6 7 y 8 se encuentran entre 160200 litros de agua con producto contaminado
# 	sentence  107 :  surtidor no entrega combustible de 93 y 95 octanos favor reparar urgente
# 	sentence  108 :  todas las bocas de gasolina 95 no expenden la gasolina surtidores encienden y dicen despacahndo pero no sale combustible
# 	sentence  109 :  buenas tardes tenemos problemas con maquinas las cuales no despachan combutibles en gasolinas al momento de accionar estas no sale combustible
# 	sentence  110 :  area de atencion combustible surtidor 5 gasolina 93 95 y 97 despachan gasolina de manera lenta se revisaron filtros incidencia continua jose acuna
# 	sentence  111 :  surtidores lados 4 y 7 despachan lento
# 	sentence  112 :  surtidor se detiene en 200 y no termina carga de combustible gas 95 gas97
# 	sentence  113 :  termina el despacho de producto antes de lo programado
# 	sentence  114 :  surtidores de petroleo no marca numeros y no funciona
# 	sentence  115 :  surtidor 6 corta combustible antes de lo programado
# 	sentence  116 :  surtidor al despachar combustible se apaga se re programa y se vuelve apagar haya un evidente problema con el surtidor
# 	sentence  117 :  area de atencion combustible problema surtidor de 93 se pasa de lo programado victor
# 	sentence  118 :  fuga de combustible diesel por manguera
# 	sentence  119 :  area de atencion combustible surtidor numero 1 pistola despacha mas de lo programado y derrama luis palacios
# 	sentence  120 :  se solicita calibracion por perdida de combustible gasolina 93 de manera constante durante el mes de diciembre y lo que va de enero
# 	sentence  121 :  se solcita calibracion de surtidores por peridida constante de combustible en gasolinas 93 y 97
# 	sentence  122 :  fuga de diesel por manguera
# 	sentence  123 :  surtidor n 3 se corta antes de terminar la carga
# 	sentence  124 :  surtidor no corta cuano termna la programacion
# 	sentence  125 :  area de atencion combustible surtidor n 9 de petroleo diesel esta rota la manguera de alto flujo y se produce derrame de petroleo boris pastorini
# 	sentence  126 :  se solicita visita urgente de tecnico debido a que se rompio un filtro de surtidor tk 3
# 	sentence  127 :  surtidor no despacha
# 	sentence  128 :  area de atencion combustible manguera de dispensador de 93 fue arrancada por vehiculo se solicita reparacion inmediata
# 	sentence  129 :  se solicita calibracion a todos los surtidores
# 	sentence  130 :  surtidor no corta en lo programado
# 	sentence  131 :  surtidores de combustible gas 93 despachan lento y cortan la carga
# 	sentence  132 :  se solicita tecnicos con urgencia ya que tenemos el surtidor de gas 93 por calibracion ya que entrega mas de lo que cobra
# 	sentence  133 :  bomba n 4 dejo de funcionar al activar el surtidor 4 funciona pero no tira el combustible por la pistola y se para en segundos y deja de funcionar por lo tanto quedo fuera de servicio
# 	sentence  134 :  surtidor 93 y 95 oct no corta en la cantidad de lts solicitado sigue despachando
# 	sentence  135 :  surtidor de diesel comienza la carga y se para cerca de los 5 mil pesos de ambos lados
# 	sentence  136 :  sin despacho en 93
# 	sentence  137 :  area de atencion combustible
# 	sentence  138 :  area de atencion combustible
# 	sentence  139 :  area de atencion combustible
# 	sentence  140 :  area de atencion combustible
# 	sentence  141 :  surtidor y pistola
# 	sentence  142 :  area de atencion combustible
# 	sentence  143 :  area de atencion combustible
# 	sentence  144 :  area de atencion combustible
# 	sentence  145 :  area de atencion combustible
# 	sentence  146 :  area de atencion combustible
# 	sentence  147 :  surtidor n 8 se corta al programar en la mitad del despacho se reinicia y se vuelve a cortar afecta todo el combustible carlos saravia
# 	sentence  148 :  se cayo la electricidad y bomba no estan despachado combustibles favor ver urgente ya que se esta sin atencion alejandro
# 	sentence  149 :  debido a la alta cantidad de reclamos de que el combustible no es despachado el total correcto se requiere de forma urgente la calibracion de surtidores santa luz ltda
# 	sentence  150 :  fuga de combustible
# 	sentence  151 :  surtiores de gasolina 97 despachan muy lento en las dos islas no se puede cargar en los dos lados del surtidor al mismo tiempo gasolina de 97 y o gasolina de 95
# 	sentence  152 :  dispensador con codigo de error y despacho lento diesel
# 	sentence  153 :  surtidor de gasolina no tiene presion no funciona
# 	sentence  154 :  buenas noches requerimos apoyo para la revision del surtidor 7 de combustible ya que se encuentra cortando el despacho de combustible antes del total requerido esperamos su pronta colaboracion
# 	sentence  155 :  tenemos problemas con el surtidor 3 y 7 comb 97 no tira
# 	sentence  156 :  surtidor 2 de gasolina se corta antes de cargar el total programado al querer seguir despachando la maquina no responde patricia acevedo
# 	sentence  157 :  fuga por la manguera gas 95 posicion 8 que no se detiene con el surtidor cortado
# 	sentence  158 :  surtidor n 7 diesel no entrega producto
# 	sentence  159 :  surtidor arranca pero no entrega producto este surtidor fue revisado el dia 11 092018 no ot 0 os 86409
# 	sentence  160 :  falla en surtidor despacha lento
# 	sentence  161 :  el autohadesivo que se encuentra en la parte inferior del surtidor se encuentra hinchado porque hay un derrame por dentro ademas el surtidor de la gas 95 comienza a funcionar y correr el surtidor y no sale producto
# 	sentence  162 :  surtidor filtra combustible por la parte inferior
# 	sentence  163 :  surtidor cobra mas de lo que despacha urgente por favor
# 	sentence  164 :  surtidor n 1 no despacha combustible de d
# 	sentence  165 :  surtidor 7 se corta antes de terminar la carga
# 	sentence  166 :  perdida de combustible por el codo de torcion
# 	sentence  167 :  surtidor 3 y 4 muy lentos al despachar combustible
# 	sentence  168 :  surtidor de gas 95 sigue despachande despues de terminada la carga programada
# 	sentence  169 :  presenta fuga por la manguera
# 	sentence  170 :  se realiza servicio de mantenimiento preventivo a surtidor de combustible n os 84456 se indica en cuadro de observaciones que regla se encuentra en malas condiciones debido a que comienza desde los 600 lts provocando variaciones de control a encargado de surtidor
# 	sentence  171 :  pistola derrama combustible
# 	sentence  172 :  pistola surtidor 6 de petroleo no corta
# 	sentence  173 :  el surtidor de diesel se reinicia
# 	sentence  174 :  surtidor grupo 2 boca 3 no despacha ningun combustible
# 	sentence  175 :  surtidor 7 y 8 se broquea sin poder vender
# 	sentence  176 :  surtidor sigue despachando solo
# 	sentence  177 :  surtidor 11 y 12 de diesel no funciona
# 	sentence  178 :  se solicita cambio de fundas de pistolas rotas danadas surtidor 7 y 8 diesel 3 5 y 6 bencina
# 	sentence  179 :  breakaway de manguera diesel surtidor 5 con filtracion
# 	sentence  180 :  surtidor de gas95 no comienza en 0
# 	sentence  181 :  los surtidores estan muy lentos necesitan una mantencion urgente
# 	sentence  182 :  cliente solicita mantencion al surtidor de diesel para saber si esta descargando lento
# 	sentence  183 :  surtidor no despacha diesel por ambos lados
# 	sentence  184 :  los surtidores de isla 5 y 6 por ambos lados al momento de despachar el combustible despacha una cierta cantidad y se para el surtidor segundo jeres
# 	sentence  364 :  solicita las pinturas de las tapas de los estanques se encuentran desgastados la identificacion
# 	sentence  365 :  ot para trazabilidad de servicios ejecutados por problema de flujo lento y pendiente placa de equipo
# 	sentence  366 :  fuga en el tubo donde llega el producto estan haciendo la prueba de hermeticidad de los estanques y ahi lo detectaron
# 	sentence  367 :  manguera suelta por cliente arranaca sin pagar
# 	sentence  368 :  brekawei danado por un perro muerto
# 	sentence  369 :  manguera gotea en union
# 	sentence  370 :  surtidor 93 al momento de levantar la palanca comienza a marcar
# 	sentence  371 :  expende 250 y se detiene
# 	sentence  372 :  pistola con fuga
# 	sentence  373 :  retiro de balde arena contaminada rene acevedo
# 	sentence  374 :  maquinas de alto galonaje la n 12 una salida de brekaway la otra perdida de petroleo visita ugente
# 	sentence  375 :  problema en bomba sumergida corte frecuente y 90 de estacion detenida
# 	sentence  376 :  calibracion extraordinaria bocas de pd asociados a tk3 por dif negativas
# 	sentence  377 :  se produce corte de luz y maquina queda con el problema ya reportado anteriormente
# 	sentence  378 :  toma de numerales de todos los equipos a solicitud de area de ventas
# 	sentence  379 :  toma de numerales de todos los equipos a solicitud de area de ventas
# 	sentence  380 :  regularizacion emergencia despacho lento cl
# 	sentence  381 :  bloqueo surtidor regularizacion emergencia
# 	sentence  382 :  surtidor sigue marcando dinero despues de colgada la pistola
# 	sentence  383 :  sustidor en mal estado
# 	sentence  384 :  cliente llama para que le puedan ayudar con el cambio de hora en el veeder root nos informan que llamaron a gilbarco e hicieron las gestion desde su sistema pero no se ha reflejado en el veeder root por lo cual gilbarco les comunica que cgs tienen que hacer el resto el necesita que le puedan dar solucion al problema lo antes posible ya que necesita que los turnos cuadren para hacer el cierre del consignado cod estacion platino 9120
# 	sentence  385 :  maquina desprogramada
# 	sentence  386 :  breakaway danado
# 	sentence  387 :  en la isla 3 cara 6 la pistola de la bencina corta reiteradamente y no deja cargar los vehiculos como corresponde trayendo molestias a los clientes
# 	sentence  388 :  pistola mal estado no corta
# 	sentence  389 :  veede rut electronico desfasado de hora
# 	sentence  390 :  cambiar la hora del veederroot
# 	sentence  391 :  producto sale de la pistola sin apretar gatillo pistola mala
# 	sentence  392 :  malla a la vista mas de 2 semanas sin reparacion
# 	sentence  393 :  manguera rota a la vista alambres
# 	sentence  394 :  sticker de las maquinas surtidoras deteriorados
# 	sentence  395 :  pistola no corta al levantar palanca sueta producto sin apretar el gatillo totilizador marca igual mientras cae el producto vinieron a verla dos veces quedando igual mas de un mes sin poder usar por el problema por favor acudir cuanto antes gracias
# 	sentence  396 :  estacion de servicio sin venta
# 	sentence  397 :  se produce un corte de luz y las maquinas no vuelven a su funcionamiento
# 	sentence  398 :  diferencia de producto diesel reglas
# 	sentence  399 :  tapa del sam n 1 de gas 93 se encuentra quebrada fabiola guajardo
# 	sentence  400 :  cliente manifiesta diferencias importantes de combustibles se requiere evaluar condicion actual de tanque y regla de medicion controles numerales son a diarios
# 	sentence  401 :  mediante la presente me permito solicitar revision y reparacion de tablero electrico falla puerta no cierra y no queda resguaradado el interior y ordenamiento de los cables lisbeth niemann
# 	sentence  402 :  se solicita remarcar tapas de acceso canos de descargas
# 	sentence  403 :  accesorios en mal estado tomas saavedra
# 	sentence  404 :  falla en dispensadores 93 y 95 todos en este momento la estacion se encuentra sin venta de esos productos eduardo andreani r
# 	sentence  405 :  surtidor 5 y 6 los accesorios malos mas brack suelto
# 	sentence  406 :  mantencion preventivames de julio
# 	sentence  407 :  automatico de g93 se cae y no puede levantarse llamado de emergencia 28 6
# 	sentence  408 :  los surtidores se programan con la cantidad que el cliente solicita pero este al llegar a la cantidad solicitada sigue entregando producto y los clientes no cancelan la diferencia y los clientes piensan que tienen las maquinas arregladas por lo cual se solicita con urgencia una mantencion ya que el problema esta en todas las bocas
# 	sentence  409 :  manguera gasolina 95 danada malla a la vista
# 	sentence  410 :  servicio para reparacion estanque no 01 mismo estanque que fue reparado anteriormente y nuevamente rompiendose en el mismo lugar lo que significa que al cargarlo derrame combustible
# 	sentence  411 :  instalar destorcedores
# 	sentence  412 :  no corta pistola urgente por favor
# 	sentence  413 :  manguera se salio de breakaway
# 	sentence  414 :  en isla n 4 maquina tiene display malo maquina alumbra luz
# 	sentence  415 :  pistola no corta totalmente al realizar una venta marca el totalizador antes de colocar la pistola en el vehiculo
# 	sentence  416 :  breakway danado gasolina 97
# 	sentence  417 :  breakaway roto por fuga de cliente
# 	sentence  418 :  cuando se levanta la pistola se cae el automatico y nos quedamos sin energia en todo el servicentro
# 	sentence  419 :  pistola danada
# 	sentence  420 :  displey para cambiar precios en maquina no funciona
# 	sentence  421 :  fundas de pistolas danadas fundas verdes largas
# 	sentence  422 :  auto arranca manguera y dana breakaway
# 	sentence  423 :  retiro de tambores de aceite marisela liempi
# 	sentence  424 :  alarma en videe root l5 aviso liquido
# 	sentence  425 :  bano personales tapados el dia 3 julio vinieron y lo destaparon al dia siguiente ya estaba nuevamente tapado favor realizar visita a la brevedad
# 	sentence  426 :  tengo veederroot con alarma l 3 alarm comb q 2 no pasa pcatas lin q 2 alarma apagado dflp no sale combustible de 93
# 	sentence  427 :  agua superior a 2 5 cm en estanque de diesel y agua superior a 2 5 cm en kerosene
# 	sentence  428 :  tapa quebrada diesel descarga de ombustible
# 	sentence  429 :  favor se solicita retiro de agua en los estanques n 1 gas93 y 4 gas97 debido a las altas precipitaciones que hemos tenido en la zona los estanques nuevamente presentan 3 cm de agua
# Cluster 7 : area de atencion mantencion preventiva solicitado por fono
# 	sentence  0 :  area de atencion mantencion preventiva solicitado por fono
# 	sentence  1 :  area de atencion mantencion preventiva solicitado por fono
# 	sentence  2 :  area de atencion mantencion preventiva solicitado por fono
# 	sentence  3 :  area de atencion mantencion preventiva solicitado por fono
# 	sentence  4 :  area de atencion mantencion preventiva solicitado por fono
# 	sentence  5 :  mantencion preventiva
# 	sentence  6 :  mantencion preventiva
# 	sentence  7 :  mantencion preventiva
# 	sentence  8 :  mantencion preventiva
# 	sentence  9 :  mantencion preventiva
# 	sentence  10 :  mantencion preventiva
# 	sentence  11 :  mantencion preventiva
# 	sentence  12 :  mantencion preventiva
# 	sentence  13 :  mantencion preventiva
# 	sentence  14 :  mantencion preventiva
# 	sentence  15 :  area de atencion mantencion preventiva solicitado por fono
# 	sentence  16 :  area de atencion mantencion preventiva solicitado por fono
# 	sentence  17 :  mantencion preventiva
# 	sentence  18 :  mantencion preventiva
# 	sentence  19 :  mantencion preventiva
# 	sentence  20 :  mantencion preventiva
# 	sentence  21 :  mantencion preventiva
# 	sentence  22 :  mantencion preventiva
# 	sentence  23 :  mantencion preventiva
# Cluster 8 : mantencion preventiva mes de noviembre
# 	sentence  0 :  revision srv mes noviembre diciembre
# 	sentence  1 :  mantencion preventiva mes de noviembre
# 	sentence  2 :  mantencion preventiva mes de noviembre
# 	sentence  3 :  mantencion preventiva correspondiente al me noviembre
# 	sentence  4 :  mantencion preventiva mes noviembre
# 	sentence  5 :  muestreo segun sorteo sec mes noviembre
# 	sentence  6 :  mantencion preventiva correspondiente al mes noviembre
# 	sentence  7 :  mantencion preventiva correspondiente al mes noviembre
# 	sentence  8 :  muestreo segun sec correspondiente al mes noviembre
# Cluster 9 : area de atencion combustible estanque de combustible 97 se encuentra con variacion negativa
# 	sentence  0 :  area de atencion combustible estanque 4 sigue cin variacion negativa consecutiva
# 	sentence  1 :  area de atencion combustible surtidor 3 esta despachando sin marcaje en la gas 95 y variaciones negativas en la 97 avelaida gutierrez
# 	sentence  2 :  area de atencion combustible variacion acumulada de diesel por 3 dias consecutivos en negativo
# 	sentence  3 :  area de atencion combustible variacion acumulada de 97 por 3 dias consecutivos en negativo muy por abajo de lo permitido ejemplo 20 331 087 127
# 	sentence  4 :  area de atencion combustible recepcion de cem mes junio variacion negativa 13 000 litros segun facturas y segun reportes de soim
# 	sentence  5 :  area de atencion combustible variacion negativa por mas de 3 dias consecutivo en diesel y sobrante de 1400 lts en gasolina 93
# 	sentence  6 :  area de atencion combustible variacion negativa por 3 dias consecutivos en bencina 97
# 	sentence  7 :  area de atencion combustible se requiere revisar gas 97 y diesel ya que llevan 4 dias con variacion negativa
# 	sentence  8 :  area de atencion combustible estanque 4 de 97 con variacion negativa consecutiva por 5 dias
# 	sentence  9 :  area de atencion combustible tendencia negativa por mas de tres dias consecutivos en kerosene
# 	sentence  10 :  area de atencion combustible sobrante acumulado en soims tanque gas 93 1406 litros variaciones negativas en tanque de 97 y kerosene
# 	sentence  11 :  area de atencion combustible se solicita revisar estanque 1 diesel ya que presenta variacion negativa por tres dias seguido
# 	sentence  12 :  area de atencion combustible variacion negativa acumulada de kero y gasolina 97
# 	sentence  13 :  area de atencion combustible variacion negativa soims dias consecutivos en tanque de kerosene
# 	sentence  14 :  area de atencion combustible variacion kerosene negativa siendo que no hay venta del producto
# 	sentence  15 :  area de atencion combustible variacion consecutivas en las gasolinas 93 y 97 en la reconciliacion diaria
# 	sentence  16 :  area de atencion combustible mas de 3 dias variacion negativa en diesel es un tema recurrente
# 	sentence  17 :  area de atencion combustible diferencia negativa comb 97
# 	sentence  18 :  area de atencion combustible variacion negativa dias consecutivos kerosene
# 	sentence  19 :  area de atencion combustible estanque gasolina 93 con variacion negativa en total estacion
# 	sentence  20 :  area de atencion combustible variaciones negativas en estanque 97 y kerosene se solicita realizar pruebas
# 	sentence  21 :  area de atencion combustible variacion negativa consecutivas en gas de 93 97
# 	sentence  22 :  area de atencion combustible estimados solicito por favor su ayuda por septimo dia consecutivo en variacion negativa de diesel saludos
# 	sentence  23 :  area de atencion combustible comportamiento de estanque 4 presenta variaciones negativas durante todo marzo acumulando en promedio 1 de variacion variacion diaria estacion esta en negativo constante abril mantiene la tendencia
# 	sentence  24 :  area de atencion combustible se registra volumen negativo en total estacion en soims de gasolina 93 favor verificar
# 	sentence  25 :  area de atencion combustible estimado solicito su ayuda por variacion negativa durante tres dias consecutivos en 97 y diesel muchas gracias
# 	sentence  26 :  area de atencion combustible variacion de kerosene siendo que no hay venta en el mes surtidor se encuentra cerrado
# 	sentence  27 :  area de atencion combustible variacion diaria de gasolina 97
# 	sentence  28 :  area de atencion combustible revision tanque 5 comb 95 por variacion negativa
# 	sentence  29 :  area de atencion combustible variacion negativa en mas de 3 dias consecutiva en gas 97 y variacion acumulada sobre 500 litros en diesel variaciones negativas diarias sobre 100
# 	sentence  30 :  area de atencion combustible variacion negativa en tanque diesel durante 9 dias
# 	sentence  31 :  area de atencion combustible variacion negativa gasolina 93 con tres dias consecutivos
# 	sentence  32 :  area de atencion combustible variacion combustible 93 negativa acumulada desde ano 2018
# 	sentence  33 :  area de atencion combustible a pedido de jefe de zona se solicita revision de mediciones de tk 93 ya que en enero y febrero hay una variacion por sobre el 05 permitido variacion positiva
# 	sentence  34 :  area de atencion combustible revisar variacion sobrante gas 93 fuera de tolerancia febrero 2019
# 	sentence  35 :  area de atencion combustible estanque de combustible 97 se encuentra con variacion negativa
# 	sentence  36 :  area de atencion combustible variacion negativa de combustible en tanque 4 gas de 97
# 	sentence  37 :  area de atencion combustible variacion acumulada durante 2 dias en positivo y al tercer dia negativo tanto en 9397 y diesel durante los dias 123 de marzo
# 	sentence  38 :  area de atencion combustible se solicita revision de variacion negativa del producto diesel
# Elapsed time: 1.2478749752 seconds.

# %%
# Clusters representativos (con n = 10)
for cluster in range(nclusters):
    print ("\033[1mCluster ",cluster,":\033[0m",sentences[clusters[cluster][representativos[cluster]]])
# Out:
# Cluster  0 : programacion mantencion preventiva
# Cluster  1 : mantencion preventiva cambio de filtros y surtidor
# Cluster  2 : mantencion preventiva mes de octubre
# Cluster  3 : area de atencion combustible isla 2 surtidor 2 y 3 isla 1 surtidor 1 y 2 despachan antes de lo programado y cargan lento isla 3 surtidor 6 reparacion manguera claudio gonzalez
# Cluster  4 : programa mantencion preventiva
# Cluster  5 : srv mes de diciembre
# Cluster  6 : area de atencion
# Cluster  7 : area de atencion mantencion preventiva solicitado por fono
# Cluster  8 : mantencion preventiva mes de noviembre
# Cluster  9 : area de atencion combustible estanque de combustible 97 se encuentra con variacion negativa

# %%
# Plot - Cantidad de sentences por cluster
len_clusters(dic=clusters,n = nclusters, save = False)
