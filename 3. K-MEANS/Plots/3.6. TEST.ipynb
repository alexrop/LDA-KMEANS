# %% [markdown]
# # APLICACIÓN KMEANS

# %% [markdown]
# **Contenido**
#
# 1. DiSEÑO DEL ALGORITMO
# 2. OBSERVACIONES
# 3. REQUERIMIENTOS
#
#
# El objetivo de este notebook es la implementación del algoritmo Kmeans con el fin de extraer patrones de comportamiento.

# %% [markdown]
# <div class="alert alert-info" style="margin: 20px">
# Se decide crear este algoritmo con el fin de obtener mayor grado de detales en las OT de las base de datos. En otras palabras, se busca identificar clusters específicos, conservando el sentido semantico de la oración, a diferencia del anterior estructura LDA que permitió tener una visión general. </div>

# %% [markdown]
# # I. DISEÑO DEL ALGORITMO

# %% [markdown]
# #### Importar paquetes

# %%
import collections
from sklearn.cluster import KMeans, SpectralClustering
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from pprint import pprint
import numpy as np
from string import punctuation
from time import time
import os
import pandas as pd
from IPython.display import Image
import matplotlib.pyplot as plt

# Stop Words
with open('spanish4.0.txt','r') as f:
    stop_words = f.read().splitlines()

# %% [markdown]
# #### Estructura del algoritmo

# %% [markdown]
# ##### Selección de K óptimo

# %%
# Tokenizar palabras
def word_tokenizer(text):    
    tokens = word_tokenize(text)   # tokenizes and stems the text
    # non_words = list(punctuation)  # removes punctuation 
    # text = ''.join([c for c in text if c not in non_words]) ---> Data ingresada ya está libre de puntuación
    stemmer = SnowballStemmer('spanish')
    tokens = [stemmer.stem(t) for t in tokens if t not in stop_words] # Posibilidad de extender stopwords
    return tokens

# Elbow Method
def elbow_method(sentences,figsize = (8,5),  namecol=None, nro_top=None, save = False,width_text=0.82, height_text=0.90):
    tfidf_vectorizer = TfidfVectorizer(tokenizer=word_tokenizer,stop_words=stop_words,lowercase=True)
    tfidf_matrix = tfidf_vectorizer.fit_transform(sentences)   #builds a tf-idf matrix for the sentences
    import warnings
    
    try:
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            if len(sentences)<= 30:
                list_k = list(range(1,len(sentences)+1))
                elbow = []
                for i in list_k:
                    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 101)
                    kmeans.fit(tfidf_matrix)
                    elbow.append(kmeans.inertia_)

            elif len(sentences)> 30 and len(sentences)<= 70:
                list_k = list(range(2,len(sentences)+1,2))
                elbow = []
                for i in list_k:
                    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 101)
                    kmeans.fit(tfidf_matrix)
                    elbow.append(kmeans.inertia_)     

            else:     
                list_k = list(range(2,51,2))
                elbow = []
                for i in list_k:
                    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 101)
                    kmeans.fit(tfidf_matrix)
                    elbow.append(kmeans.inertia_)

            from kneed import KneeLocator
            kn = KneeLocator(list_k, elbow, curve='convex', direction='decreasing')
            print(f'Número óptimo de clusters: {kn.knee}')

            plt.rcParams.update({'figure.figsize':figsize})
            plt.xlabel('Número de clusters k')
            plt.ylabel('Suma de distancias cuadradas')
            plt.plot(list_k, elbow, 'bo-')
            plt.title('Método del Elbow')
            plt.text(width_text, height_text, f'k óptimo: {kn.knee}', transform=plt.gca().transAxes)
            plt.vlines(kn.knee, plt.ylim()[0], plt.ylim()[1], linestyles='dashed')
            if save :
                plt.savefig(f'{namecol} {nro_top} - Método del elbow.jpg', dpi= 200, quality=95)
            plt.show()

    except ValueError:
        print('You must enter at least two sentences')

# %%
# Análisis de Silueta General
def silhouette(sentences,figsize = (8,5),  namecol=None, nro_top=None, save = False, width_text=0.82, height_text=0.10):
    tfidf_vectorizer = TfidfVectorizer(tokenizer=word_tokenizer,stop_words=stop_words,lowercase=True)
    X_std = tfidf_vectorizer.fit_transform(sentences)
    import warnings
    
    try:
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            if len(sentences)<= 30:
                list_k = list(range(1,len(sentences)+1))
                silhouette_scores= []
                for i in list_k:
                    km = KMeans(n_clusters = i, init = 'k-means++', random_state = 101)
                    labels = km.fit_predict(X_std)
                    centroids = km.cluster_centers_
                    silhouette_vals = silhouette_samples(X_std, labels)
                    silhouette_scores.append(np.mean(silhouette_vals))

            elif len(sentences)> 30 and len(sentences)<= 70:
                list_k = list(range(2,len(sentences)+1,2))
                silhouette_scores= []
                for i in list_k:
                    km = KMeans(n_clusters = i, init = 'k-means++', random_state = 101)
                    labels = km.fit_predict(X_std)
                    centroids = km.cluster_centers_
                    silhouette_vals = silhouette_samples(X_std, labels)
                    silhouette_scores.append(np.mean(silhouette_vals))     

            else:     
                list_k = list(range(2,51,2))
                silhouette_scores= []
                for i in list_k:
                    km = KMeans(n_clusters = i, init = 'k-means++', random_state = 101)
                    labels = km.fit_predict(X_std)
                    centroids = km.cluster_centers_
                    silhouette_vals = silhouette_samples(X_std, labels)
                    silhouette_scores.append(np.mean(silhouette_vals))
                    
            from kneed import KneeLocator
            kn = KneeLocator(list_k, silhouette_scores, curve='concave', direction='increasing')
            print(f'Número óptimo de clusters: {kn.knee}')

            plt.rcParams.update({'figure.figsize':figsize})
            plt.xlabel('Número de clusters k')
            plt.ylabel('Coeficientes de silueta')
            plt.plot(list_k, silhouette_scores, 'ro-')
            plt.title('Análisis de silueta')
            plt.text(width_text, height_text, f'k óptimo: {kn.knee}', transform=plt.gca().transAxes)
            plt.vlines(kn.knee, plt.ylim()[0], plt.ylim()[1], linestyles='dashed')
            if save :
                plt.savefig(f'{namecol} {nro_top} - Análisis de silueta general.jpg', dpi= 200, quality=95)
            plt.show()

    except ValueError:
        print('You must enter at least two sentences')

# %%
# Análisis de Silueta Particular (Gráfico de barras por tópico)
def silhouette_plot(sentences, n_clusters, figsize=(9,5), width=1.02, height=0.96):
    fig, ax1 = plt.subplots()
    plt.rcParams.update({'figure.figsize':figsize})
    plt.rcParams.update({'figure.autolayout': True})
    tfidf_vectorizer = TfidfVectorizer(tokenizer=word_tokenizer,stop_words=stop_words,lowercase=True)
    X_std = tfidf_vectorizer.fit_transform(sentences)

    # Run the Kmeans algorithm
    km = KMeans(n_clusters = n_clusters, init = 'k-means++', random_state = 101)
    labels = km.fit_predict(X_std)
    centroids = km.cluster_centers_

    # Get silhouette samples
    silhouette_vals = silhouette_samples(X_std, labels)

    # Silhouette plot
    y_ticks = []
    y_lower, y_upper = 0, 0
    for i, cluster in enumerate(np.unique(labels)):
        cluster_silhouette_vals = silhouette_vals[labels == cluster]
        cluster_silhouette_vals.sort()
        y_upper += len(cluster_silhouette_vals)
        ax1.barh(range(y_lower, y_upper), cluster_silhouette_vals, edgecolor='none', height=1)
        ax1.text(-0.03, (y_lower + y_upper) / 2, str(i))
        y_lower += len(cluster_silhouette_vals)

    # Get the average silhouette score and plot it
    avg_score = np.mean(silhouette_vals)
    ax1.axvline(avg_score, linestyle='--', linewidth=2, color='green')
    ax1.set_yticks([])
    ax1.set_xlim([-0.1, 1])
    ax1.set_xlabel('Coeficientes de Silueta')
    ax1.set_ylabel('Clusters')
    ax1.set_title(f'Análisis de Silueta para k = {n_clusters}', y=1.02)
    plt.text(width, height, f'Silhouette Score: {round(avg_score,4)}', transform=plt.gca().transAxes);
    
def silhouette_analysis(sentences, n_clusters, save = False, name= None):
    for k in n_clusters:
        silhouette_plot(sentences,n_clusters=k)
        if save:
            plt.savefig(f'Silueta - {name} con k {k}.jpg', dpi= 200, quality=95)

# %% [markdown]
# ##### Algoritmo K-Means

# %%
# Algoritmo Kmeans
def cluster_sentences(sentences, nb_of_clusters):

    tfidf_vectorizer = TfidfVectorizer(tokenizer=word_tokenizer,stop_words=stop_words,lowercase=True)
    tfidf_matrix = tfidf_vectorizer.fit_transform(sentences)   #builds a tf-idf matrix for the sentences
    
    kmeans = KMeans(n_clusters = nb_of_clusters, init = 'k-means++', random_state = 101, max_iter=300)
    #kmeans.fit(tfidf_matrix)
    X_dist=kmeans.fit_transform(tfidf_matrix)**2  #Se calcula la distancia del cluster y se multiplica al cuadrado
    clusters = collections.defaultdict(list)
    for i, label in enumerate(kmeans.labels_):
        clusters[label].append(i)

    Distancia=X_dist.sum(axis=1)  #Se calcula la distancia por columna de la matriz

    distDict={}  #Se traspasa a un diccionario con las distancias por cluster
    for key,val in clusters.items():
        distDict[key]=Distancia[val]

    representativos=[]   # Se guarda en una lista los valores mínimos de cada cluster (Menor distancia al centro mejor es el representativo)
    
    #Verificacion de los numeros de clusters
    #Si se intenta obtener los representativos de un número mas grande de cluster que el permitido, se procesa el número de clusters
    if len(distDict)<nb_of_clusters:
        nb_of_clusters=len(distDict)
        
    #Verificacion de los números de clústers
    for i in range(nb_of_clusters):
        representativos.append(np.where(distDict[i]==min(distDict[i]))[0][0])

    return dict(clusters),representativos

# Plot cantidad de sentences por cluster
def len_clusters(dic, n, namecol=None, nro_top=None, save = False, width = 0.6, color = "royalblue", figsize = (8,5)):
    keys = list(range(0,n))
    len_values = [len(dic[i]) for i in keys]
    plt.rcParams.update({'figure.figsize': figsize})
    plt.bar(keys,len_values , align='center', color = color, width = width)
    plt.title('Cantidad de OT por cluster')
    plt.xlabel('Clusters')
    plt.ylabel('Orden de Trabajo (OT)')
    plt.xticks(np.arange(min(keys), max(keys)+1, 1.0))
    if save:
        plt.savefig(f'{namecol} {nro_top} - Distribucion clusters .jpg', dpi= 200, quality=95)
    plt.show()

# %% [markdown]
# <div class="alert alert-success" style="margin: 20px">En todos los data frames ya está implementada la función word_cleaner() que permitió limpiar la base de datos. Para más información de esta función ir al segundo notebook.</div>

# %% [markdown]
# #### Importar Data Frame

# %%
df_total = pd.read_pickle('BD_original_cleaned_TOPICO_DOMINANTE.pkl')
df_total.head()
# Out:
#   Region                                           Estacion  \
# 0    13°                                       Tingaro Spa.
# 1     8°                       Combustibles El Volcan Ltda.
# 2    10°           LLANOS Y WAMMES SOCIEDAD COMERCIAL LTDA.
# 3     1°     Soc. Imp. y Exp. Nuevo Amanecer Ltda. (SOCIEX)
# 4     3°  Inmobiliaria e Inversiones San José Ltda (Vall...
#
#                Tipo de Falla Prioridad Cliente  Estado OT Tecnico Asignado  \
# 0  Carrete RetractilOTROOTRO   Normal 48 Horas    CERRADA      Juan Aliaga
# 1  Carrete RetractilOTROOTRO   Normal (48 hrs)    CERRADA          On Line
# 2  Carrete RetractilOTROOTRO   Normal 24 Horas  PRECIERRE   Luis Almonacid
# 3  Carrete RetractilOTROOTRO   Normal (48 hrs)    CERRADA          On Line
# 4  Carrete RetractilOTROOTRO   Normal (48 hrs)    CERRADA          On Line
#
#        Dia  Nro Dia     Mes  Hora Rango Recep/Arribo Rango Arribo/Cierre  \
# 0  Viernes       30  AGO 19    16    Error en fechas        Más de 1 mes
# 1  Viernes       30  AGO 19    12    Error en fechas         Menos de 1h
# 2  Viernes       30  AGO 19    12       0 a 24 horas         Menos de 1h
# 3  Viernes       30  AGO 19    12       0 a 24 horas         Menos de 1h
# 4  Viernes       30  AGO 19    12    Error en fechas         Menos de 1h
#
#                                          Observación  \
# 0  se cambia placa de tk 2 gas95 por placa que in...
# 1  cambio de graficas de equipos no esta contempl...
# 2  se visita eds para chequeo de dispensador el c...
# 3  remplazo de graficas no esta contemplado en es...
# 4  remplazo de graficas no esta contemplado en co...
#
#                                        Requerimiento  Topico Dominante
# 0  area de atencion habilitar estanque de combust...                 2
# 1  area de atencion combustible maria veronica go...                23
# 2  area de atencion surtidor de diesel a ratos co...                 3
# 3  area de atencion combustible cambiar graficas ...                 4
# 4  area de atencion combustible solicita grafica ...                 4

# %% [markdown]
# # II. OBSERVACIONES

# %%
# SELECCIONANDO UNA COLUMNA Y UN ELEMENTO DE ESA COLUMNA (Escribir con comillas. Ej: 'Tecnico Asignado')

columna = 'Estacion'
elemento = 'CL - Buses Vule S.A.'

# %%
df = df_total[df_total[columna] == elemento] 
sentences = [sent for sent in df['Observación']]
len(sentences)
# Out:
# 151

# %%
# Extracto obs 
sentences[:2]
# Out:
# ['en surtidor numero 1 se detecto se cambio 01 breakaways de 1 cortado se realizan pruebas con ventas quedando operativa en surtidor numero 1 se detecto se cambio 01 breakaways de 1 cortado se realizan pruebas con ventas quedando operativa',
#  'en surtidor numero 2 se revisa consumo electrico de motor y se detecto fases sueltas desde guardamotor en tablero electrico hacia motor del surtidor se realizan pruebas con ventas y midiendo consumo electrico del motor no detectando anomalias una vez reapretado y reajustado rango y sistema electrico en surtidor numero 2 se revisa consumo electrico de motor y se detecto fases sueltas desde guardamotor en tablero electrico hacia motor del surtidor se realizan pruebas con ventas y midiendo consumo electrico del motor no detectando anomalias una vez reapretado y reajustado rango y sistema electrico']

# %%
# %%time
# Identificando el número óptimo de clústers por medio del Método del Elbow
elbow_method(sentences, save = True, namecol=columna, nro_top=elemento)
# Out:
# Número óptimo de clusters: 16
# Wall time: 6.44 s

# %%
# %%time
# Identificando el número óptimo de clústers por medio del Análisis de Silueta General
silhouette(sentences, save = True, namecol=columna, nro_top=elemento)
# Out:
# Número óptimo de clusters: 16
# Wall time: 6.05 s

# %%
# %%time
# Identificando el número óptimo de clústers por medio del Análisis de Silueta Particular (por tópico)
silhouette_analysis(sentences, n_clusters=[10,14,16,18,20,22], name= elemento, save=True)
# Out:
# Wall time: 3.78 s

# %%
# Ejecutando el algoritmo Kmeans para el número óptimo de clústers 
print('\033[1mCLUSTERS \n\033[0m')
start_time = time()

nclusters=16
clusters,representativos = cluster_sentences(sentences, nclusters)

for cluster in range(nclusters):
    print (f"\033[1mCluster {cluster} : {sentences[clusters[cluster][representativos[cluster]]]}\033[0m")
    for i,sentence in enumerate(clusters[cluster]):
        print ("\tsentence ",i,": ",sentences[sentence])

elapsed_time = time() - start_time
print("\033[1mElapsed time: %.10f seconds.\033[0m" % elapsed_time)
# Out:
# CLUSTERS
#
# Cluster 0 : ods mal emitida
# 	sentence  0 :  ods mal emitida
# 	sentence  1 :  ods mal emitida
# 	sentence  2 :  ods mal emitida
# 	sentence  3 :  ods mal emitida
# 	sentence  4 :  ods mal emitida
# 	sentence  5 :  ods mal emitida
# 	sentence  6 :  ods mal emitida
# 	sentence  7 :  ods mal emitida
# 	sentence  8 :  ods mal emitida
# 	sentence  9 :  ods mal emitida
# 	sentence  10 :  ods mal emitida
# 	sentence  11 :  ods mal emitida
# 	sentence  12 :  ods mal emitida
# 	sentence  13 :  ods mal emitida
# 	sentence  14 :  ods mal emitida
# 	sentence  15 :  ods mal emitida
# 	sentence  16 :  ods mal emitida
# 	sentence  17 :  ods mal emitida
# 	sentence  18 :  ods mal emitida
# 	sentence  19 :  ods mal emitida
# 	sentence  20 :  ods mal emitida
# 	sentence  21 :  ods mal emitida
# 	sentence  22 :  ods mal emitida
# 	sentence  23 :  ods mal emitida
# Cluster 1 : surt 1 d se realizo remplazo de un filtro de alta cap surt 1 d se realizo remplazo de un filtro de alta cap
# 	sentence  0 :  se coordinara una proxima visita para am surtidor con llave encargado se retiro surt 1 d se realizo remplazo de una valvula medidor weyne p16500 surt 12d se sacaron y reintalaron las 4 valv de medidor los 2 filtros de centrifuga para chequeo y limpieza surt 12d se saco y reinstalo valvula de retencion en lomo est para chequeo y limpieza se coordinara una proxima visita para am surtidor con llave encargado se retiro surt 1 d se realizo remplazo de una valvula medidor weyne p16500 surt 12d se sacaron y reintalaron las 4 valv de medidor los 2 filtros de centrifuga para chequeo y limpieza surt 12d se saco y reinstalo valvula de retencion en lomo est para chequeo y limpieza
# 	sentence  1 :  surt 1 d se realizo remplazo de una pistola de 1 opw p14781 surt 1 d se realizo remplazo de una pistola de 1 opw p14781
# 	sentence  2 :  surt 1 d se realizo remplazo de un filtro de alta cap p14187 surt 1 d se realizo remplazo de un filtro de alta cap p14187
# 	sentence  3 :  surt 1 2 d se acude para remplazo de una pistola de 1 x pistola de 34 segun informacion de encargado el sr rodrigo aedo este remplazo no se necesita surt 1 2 d se acude para remplazo de una pistola de 1 x pistola de 34 segun informacion de encargado el sr rodrigo aedo este remplazo no se necesita
# 	sentence  4 :  est 1 d se realizo remplazo de una tapa 4 opw est 1 d se saco y reintalo valv de drenaje del spill para chequeo y limpieza est 1 d se realizo remplazo de una tapa 4 opw est 1 d se saco y reintalo valv de drenaje del spill para chequeo y limpieza
# 	sentence  5 :  surt 12 d se sacaron y reinstalaron filtro de malla en succion de las centrifugas para chequeo limpieza quedan surtidores funcionando ok surt 12 d se sacaron y reinstalaron filtro de malla en succion de las centrifugas para chequeo limpieza quedan surtidores funcionando ok
# 	sentence  6 :  surt 1 d se realizo remplazo de un filtro de alta cap surt 1 d se realizo remplazo de un filtro de alta cap
# 	sentence  7 :  surt 1 d se realizo remplazo de un swivel de 1 opw surt 1 d se realizo remplazo de un swivel de 1 opw
# Cluster 2 : mantencion preventiva se calibran 2 de 2
# 	sentence  0 :  mantencion preventiva se calibran 2 de 2
# 	sentence  1 :  mantencion preventiva se calibran 2 de 2
# 	sentence  2 :  mantencion preventiva no se realiza por no encontrarse personal encargado del punto
# 	sentence  3 :  mantencion preventiva se calibran 2 de 2
# 	sentence  4 :  mantencion preventiva se calibran 2 de 2
# 	sentence  5 :  mantencion preventiva se calibran 2 de 2
# 	sentence  6 :  mantencion preventiva se calibran 2 de 2
# 	sentence  7 :  mantencion preventiva se calibran 2 de 2
# 	sentence  8 :  mantencion preventiva se calibran 2 de 2
# 	sentence  9 :  mantencion preventiva no se realiza por no encontrarse personal encargado se coordina para el proximo ciclo
# Cluster 3 : se realiza el cambio de 2 filtros spin on quedando equipo operativo
# 	sentence  0 :  se realiza el cambio de 2 filtros spin on quedando equipo operativo
# 	sentence  1 :  se realiza el cambio de 2 filtros spin on quedando equipo operativo
# 	sentence  2 :  se realiza el cambio de 2 filtros spin on quedando equipo operativo
# 	sentence  3 :  se realiza el cambio de 2 filtros spin on quedando equipo operativo
# 	sentence  4 :  se realiza el cambio de 2 filtros spin on quedando equipo operativo
# Cluster 4 : os mal emitida
# 	sentence  0 :  os mal emitida
# 	sentence  1 :  os mal emitida
# 	sentence  2 :  os mal emitida
# 	sentence  3 :  os mal emitida
# 	sentence  4 :  os mal emitida
# 	sentence  5 :  os mal emitida
# 	sentence  6 :  os mal emitida
# 	sentence  7 :  os mal emitida
# 	sentence  8 :  os mal emitida
# 	sentence  9 :  os mal emitida
# 	sentence  10 :  os mal emitida
# 	sentence  11 :  os mal emitida
# 	sentence  12 :  os mal emitida
# 	sentence  13 :  os mal emitida
# 	sentence  14 :  os mal emitida
# 	sentence  15 :  os mal emitida
# 	sentence  16 :  os mal emitida
# 	sentence  17 :  os mal emitida
# 	sentence  18 :  os mal emitida
# 	sentence  19 :  os mal emitida
# 	sentence  20 :  os mal emitida
# 	sentence  21 :  os mal emitida
# 	sentence  22 :  os mal emitida
# 	sentence  23 :  os mal emitida
# Cluster 5 : mantencion preventiva se realizara bajo ot 5
# 	sentence  0 :  incidencia fue reasignada a otra contratista
# 	sentence  1 :  mp se realiza bajo ot 4
# 	sentence  2 :  mp se realiza bajo la ot 6 en el mes de agosto
# 	sentence  3 :  mantencion preventiva se realiza bajo la ot 5
# 	sentence  4 :  mp se realiza bajo la ot 3 en mes de agosto
# 	sentence  5 :  mantencion preventiva se realizara bajo ot 5
# 	sentence  6 :  se cierra incidencia bajo la ot 6
# 	sentence  7 :  mp se realiza en agosto bajo la ot 3
# 	sentence  8 :  mp se realiza bajo la ot 8
# 	sentence  9 :  mp se realizo en agosto bajo ot 9
# 	sentence  10 :  incidencia es atendida bajo ot 3
# Cluster 6 : en surtidores 1 y 2 diesel se cambia 02 filtros p14187 quedando 100 operativos en surtidores 1 y 2 diesel se cambia 02 filtros p14187 quedando 100 operativos
# 	sentence  0 :  se realiza visita a punto industrial en donde no se encuentra personal que autorice labores incidencia es cerrada y se queda a la espera de un nuevo reporte
# 	sentence  1 :  en surtidor 1 y 2 se cambian 02 filtros alto galonage y se intercambian backlights para visibilizar litros y monto surtidor queda 100 operativo en surtidor 1 y 2 se cambian 02 filtros alto galonage y se intercambian backlights para visibilizar litros y monto surtidor queda 100 operativo
# 	sentence  2 :  en surtidores 1 y 2 diesel se cambia 02 filtros p14187 quedando 100 operativos en surtidores 1 y 2 diesel se cambia 02 filtros p14187 quedando 100 operativos
# 	sentence  3 :  se revisa entrega volumetrica a surtidor doble de diesel a solicitud de cliente se encuentra en parametros normales se reviso interior de equipo sin fugas queda operando normalmente se revisa entrega volumetrica a surtidor doble de diesel a solicitud de cliente se encuentra en parametros normales se reviso interior de equipo sin fugas queda operando normalmente
# 	sentence  4 :  en surtidor numero 1 de diesel wayne 3 g2222 p se cambia 01 ampolleta rosca 80 watts luz clara surtidor queda 100 operativo en surtidor numero 1 de diesel wayne 3 g2222 p se cambia 01 ampolleta rosca 80 watts luz clara surtidor queda 100 operativo
# 	sentence  5 :  se chequea falla y se detecta filtros saturados se realiza cambio de filtros y se prueba queda 100 operativa repuesto filtros de alta capacidad codigo p14187 cantidad 02 se chequea falla y se detecta filtros saturados se realiza cambio de filtros y se prueba queda 100 operativa repuesto filtros de alta capacidad codigo p14187 cantidad 02
# 	sentence  6 :  en dispensador 1 boca numero 2 diesel se detecto terminal giratorio de la manguera desarmado se cambia 01 manguera de 1 x 5 mts y se realizan pruebas con preset en ambas bocas quedando 100 operativas en dispensador 1 boca numero 2 diesel se detecto terminal giratorio de la manguera desarmado se cambia 01 manguera de 1 x 5 mts y se realizan pruebas con preset en ambas bocas quedando 100 operativas
# 	sentence  7 :  en surtidores numeros 1 y 2 diesel se detectaron tensor de correa sueltos se dejan en posicion y se apretan tensores se realizan pruebas quedando ambas bocas 100 operativas en surtidores numeros 1 y 2 diesel se detectaron tensor de correa sueltos se dejan en posicion y se apretan tensores se realizan pruebas quedando ambas bocas 100 operativas
# 	sentence  8 :  se realiza el cambio de 2 filtros de alta capacidad se deja en observacion debido a que segun aplicacion no tengo stock en mi bodega punto industrial queda operativo se realiza chequeo a surtidores verificando que flujos eran bajos debido a que filtros estaban saturados se procede al cambio de estos mejorando considerablemente se realizan pruebas de despacho arrojando un flujo de 60 litros por minuto en el surtidor 1 y 80 litros por minuto en el surtidor 2
# 	sentence  9 :  se revisa dispensador doble lado 1 con breakaway cortado por tiron de bus se cambia breakaway de 1 reconectabke y se prueba recirculando litros queda operando normal se revisa dispensador doble lado 1 con breakaway cortado por tiron de bus se cambia breakaway de 1 reconectabke y se prueba recirculando litros queda operando normal
# 	sentence  10 :  el surtidor numeros 1 y 2 diesel se detecto y se cambio un motor weg 220 volt control interno con bobinado de partida malo se recircula producto en ambas bocas quedando 100 operativas ambas bocas el surtidor numeros 1 y 2 diesel se detecto y se cambio un motor weg 220 volt control interno con bobinado de partida malo se recircula producto en ambas bocas quedando 100 operativas ambas bocas
# 	sentence  11 :  se efectua el cambio de 2 filtros en surtidor 12 producto diesel se realiza cambio de pistola la cual presenta problema en su cano
# 	sentence  12 :  se realiza el cambio de 2 mangueras 1x5 mts quedando equipo operativo
# Cluster 7 : se realiza el cambio de 2 codos giratorio 1 2 swivel 1 y 2 filtros alta capacidad quedando equipo operativo
# 	sentence  0 :  se rev surtidor 1 cara 1 la cual se encuentra con la correa cortada se cambia correa plus queda funcionando se rev surtidor 1 cara 1 la cual se encuentra con la correa cortada se cambia correa plus queda funcionando
# 	sentence  1 :  se realiza el cambio de 1 correa wayne quedando equipo operativo
# 	sentence  2 :  se realiza el cambio de 1 kit reparacion bomba centrifuga blackmer 1 emisor de pulso y 1 filtro alta capacidad quedando equipo operativo
# 	sentence  3 :  se realiza el cambio de 1 manguera 1x5 mts 1 whipe hose 1 y 1 breackaway 1 quedando equipo operativo
# 	sentence  4 :  se realiza el cambio de 1 pistola 1 quedando equipo operativo
# 	sentence  5 :  se realiza el cambio de 1 pistola 1 quedando equipo operativo
# 	sentence  6 :  se realiza el cambio de 1 swivel 1 y 1 swivel 34 conv quedando equipo operativo
# 	sentence  7 :  se realiza el cambio de 2 codos giratorio 1 2 swivel 1 y 2 filtros alta capacidad quedando equipo operativo
# 	sentence  8 :  se realiza el cambio de 1 swivel 1 y 1 swivel 34 conv quedando equipo operativo
# 	sentence  9 :  se realiza el cambio de 1 motor monofasico rele interno y 1 placa fuente de poder bp quedando equipo operativo
# 	sentence  10 :  se realiza el cambio de 1 filtro alta capacidad quedando equipo operativo
# 	sentence  11 :  se realiza el cambio de 1 swivel 1 quedando equipo operativo
# Cluster 8 : en surtidor numero 1 se detecto y se cambiaron 02 pistolas convencionales de 1 con sensor malo se revisan y se limpian los dos filtros de malla de entrada de bomba se ajust a presion general realizando pruebas con preset y con ventas dispensadores queda con despacho normal repuestos utilizados 02 pistolas convencionales de 1 p14781 en surtidor numero 1 se detecto y se cambiaron 02 pistolas convencionales de 1 con sensor malo se revisan y se limpian los dos filtros de malla de entrada de bomba se ajust a presion general realizando pruebas con preset y con ventas dispensadores queda con despacho normal repuestos utilizados 02 pistolas convencionales de 1 p14781
# 	sentence  0 :  en surtidor numero 1 se detecto se cambio 01 breakaways de 1 cortado se realizan pruebas con ventas quedando operativa en surtidor numero 1 se detecto se cambio 01 breakaways de 1 cortado se realizan pruebas con ventas quedando operativa
# 	sentence  1 :  en surtidor numero 2 se detecto y se cambio 01 pistola convensional de 1 con fuga en recamara y cano se realizan pruebas quedando operativa en surtidor numero 2 se detecto y se cambio 01 pistola convensional de 1 con fuga en recamara y cano se realizan pruebas quedando operativa
# 	sentence  2 :  en surtidor numero 2 se detecto y se cambio 01 breakaways de metal reconectable de 1 cortado se realizan pruebas con preset quedando 100 operativa repuesto utilizado 01 breakaways reconectable de 1 p16672 en surtidor numero 2 se detecto y se cambio 01 breakaways de metal reconectable de 1 cortado se realizan pruebas con preset quedando 100 operativa repuesto utilizado 01 breakaways reconectable de 1 p16672
# 	sentence  3 :  en surtidor numero 1 se detecto y se cambio 01 pistola convencional de 1 con cano quebrado se realizan pruebas con ventas quedando 100 operativa repuesto utilizado 01 pistola convencional de 1 p 14781 en surtidor numero 1 se detecto y se cambio 01 pistola convencional de 1 con cano quebrado se realizan pruebas con ventas quedando 100 operativa repuesto utilizado 01 pistola convencional de 1 p 14781
# 	sentence  4 :  en surtidor numero 1 se detecto y se cambiaron 02 pistolas convencionales de 1 con sensor malo se revisan y se limpian los dos filtros de malla de entrada de bomba se ajust a presion general realizando pruebas con preset y con ventas dispensadores queda con despacho normal repuestos utilizados 02 pistolas convencionales de 1 p14781 en surtidor numero 1 se detecto y se cambiaron 02 pistolas convencionales de 1 con sensor malo se revisan y se limpian los dos filtros de malla de entrada de bomba se ajust a presion general realizando pruebas con preset y con ventas dispensadores queda con despacho normal repuestos utilizados 02 pistolas convencionales de 1 p14781
# 	sentence  5 :  se chequea falla y se detecta problema en pistola 34 con fuga se realiza cambio de pistola 34 y se eprueba quedandomoperativa 100 repussto pistola 34 codigo p14776 cantidad 01 se chequea falla y se detecta problema en pistola 34 con fuga se realiza cambio de pistola 34 y se eprueba quedandomoperativa 100 repussto pistola 34 codigo p14776 cantidad 01
# 	sentence  6 :  en boca numero uno se reparo portapistola se realizan pruebas con preset quedando 100 operativo 01 mecanismo de cierre de portapistolas banco de prueba en boca numero uno se reparo portapistola se realizan pruebas con preset quedando 100 operativo 01 mecanismo de cierre de portapistolas banco de prueba
# 	sentence  7 :  se chequea falla detectando pistola de 1 con automatico sensor danado se realiza el cambio de pisyola y se prueba quedando operativo en un 100 se chequea falla detectando pistola de 1 con automatico sensor danado se realiza el cambio de pisyola y se prueba quedando operativo en un 100
# Cluster 9 : se realiza el cambio de 1 tapa adaptdor descarga 4 quedando equipo operativo
# 	sentence  0 :  se realiza el cambio de 1 tapa adaptdor descarga 4 quedando equipo operativo
# 	sentence  1 :  mantencion preventiva se calibran 4 de 4
# 	sentence  2 :  mantencion preventiva se calibran 4 de 4
# Cluster 10 : mp se realizara cuando se repare surtidor n 2 se efectua proceso de mantencion preventiva de estanque y surtidores se realiza revision limpieza y verificacion volumetrica a los surtidores 1 y 2 con matraz de 20 lts se cambian 2 filtros de alta capacidad debido a flujo lento mejorando considerablemente 65 litros por minutos aprox se reaprietan porta pistolas boca 1 y 2 ademas se remarcan adhesivos bocaestanque regla incompleta comienza desde los 200 litros aprox y estanque sin agua bocas dentro de la tolerancia establecida por la compania bocas verificadas 2 de 2 punto industrial queda operativo mp se realizara cuando se repare surtidor n 2 se efectua proceso de mantencion preventiva de estanque y surtidores se realiza revision limpieza y verificacion volumetrica a los surtidores 1 y 2 con matraz de 20 lts se cambian 2 filtros de alta capacidad debido a flujo lento mejorando considerablemente 65 litros por minutos aprox se reaprietan porta pistolas boca 1 y 2 ademas se remarcan adhesivos bocaestanque
# 	sentence  0 :  se efectua proceso de mantencion preventiva de estanque y surtidor se realiza revision limpieza y verificacion volumetrica al surtidor 1 y 2 con matraz de 20lts se detecta flujo lento en ambos surtidores se procede a realizar el cambio de 2 filtros ac mejorando flujo considerablemente se remarcan adhesivos bocaestanque regla completa y tk sin agua bocas verificadas 2 de 2 punto enap queda operativo se efectua proceso de mantencion preventiva de estanque y surtidor se realiza revision limpieza y verificacion volumetrica al surtidor 1 y 2 con matraz de 20lts se detecta flujo lento en ambos surtidores se procede a realizar el cambio de 2 filtros ac mejorando flujo considerablemente se remarcan adhesivos bocaestanque regla completa y tk sin agua bocas verificadas 2 de 2 punto enap queda operativo
# 	sentence  1 :  se efectua proceso de mantencion preventiva de estanque y surtidor se realiza revision limpieza y verificacion volumetrica al surtidor 12 con matraz de 20lts se instalan 2 adhesivos bocaestanque regla completa y tk sin agua bocas verificadas 2 de 2 punto industrial queda operativo se efectua proceso de mantencion preventiva de estanque y surtidor se realiza revision limpieza y verificacion volumetrica al surtidor 12 con matraz de 20lts se instalan 2 adhesivos bocaestanque regla completa y tk sin agua bocas verificadas 2 de 2 punto industrial queda operativo
# 	sentence  2 :  se efectua proceso de mantencion preventiva de estanque y surtidor se realiza revision limpieza y verificacion volumetrica al surtidor 1 y 2 con matraz de 20lts se detecta flujo lento en ambos surtidores se procede a realizar el cambio de 2 filtros ac mejorando flujo considerablemente se pinta tapa spill se remarcan adhesivos bocaestanque regla incompleta comienza desde los 200lts y tk sin agua bocas verificadas 2 de 2 punto enap queda operativo se efectua proceso de mantencion preventiva de estanque y surtidor se realiza revision limpieza y verificacion volumetrica al surtidor 1 y 2 con matraz de 20lts se detecta flujo lento en ambos surtidores se procede a realizar el cambio de 2 filtros ac mejorando flujo considerablemente se pinta tapa spill se remarcan adhesivos bocaestanque regla incompleta comienza desde los 200lts y tk sin agua bocas verificadas 2 de 2 punto enap queda operativo
# 	sentence  3 :  se efectua proceso de mantencion preventiva de estanques y surtidor se realiza revision limpieza y verificacion volumetrica a los dispensadores 12 con matraz de 20lts se remarcan adhesivos bocaestanque se pintan ambas tapas spill de descargas reglas completas y estanques sin agua bocas verificadas 2 de 2 punto industrial queda operativo se efectua proceso de mantencion preventiva de estanques y surtidor se realiza revision limpieza y verificacion volumetrica a los dispensadores 12 con matraz de 20lts se remarcan adhesivos bocaestanque se pintan ambas tapas spill de descargas reglas completas y estanques sin agua bocas verificadas 2 de 2 punto industrial queda operativo
# 	sentence  4 :  se efectua proceso de mantencion preventiva de estanque y surtidor se realiza revision limpieza y verificacion volumetrica al surtidor 12 con matraz de 20lts no se pinta tapa spill debido a alto flujo de buses regla completa y tk sin agua bocas verificadas 2 de 2 punto industrial queda operativo se efectua proceso de mantencion preventiva de estanque y surtidor se realiza revision limpieza y verificacion volumetrica al surtidor 12 con matraz de 20lts se remarcan adhesivos bocaestanque no se pinta tapa spill debido a alto flujo de buses regla completa y tk sin agua bocas verificadas 2 de 2 punto industrial queda operativo
# 	sentence  5 :  se efectua proceso de mantencion preventiva de estanques y dispensadores se realiza revision limpieza y verificacion volumetrica a los dispensadores 12 y 34 con matraz de 20lts se detecta flujo lento en ambos dispensadores se procede a realizar el cambio de 4 filtro ac mejorando flujo considerablemente se pintan ambas tapas spill de descargas reglas completas y estanques sin agua bocas verificadas 4 de 4 punto industrial queda operativo se efectua proceso de mantencion preventiva de estanques y dispensadores se realiza revision limpieza y verificacion volumetrica a los dispensadores 12 y 34 con matraz de 20lts se detecta flujo lento en ambos dispensadores se procede a realizar el cambio de 4 filtro ac mejorando flujo considerablemente se pintan ambas tapas spill de descargas reglas completas y estanques sin agua bocas verificadas 4 de 4 punto industrial queda operativo
# 	sentence  6 :  se efectua proceso de mantencion preventiva de estanque y surtidor se realiza revision limpieza y verificacion volumetrica al surtidor 1 con matraz de 20lts se cambia 1 pistola de 1 debido a que no retenia el flujo provocando que surtidor siguiera despachando sin presionar el gatillo se realizan pruebas de funcionamiento quedando operativo se pinta tapa spill regla completa y tk sin agua bocas verificadas 1 de 1 punto industrial queda operativo se efectua proceso de mantencion preventiva de estanque y surtidor se realiza revision limpieza y verificacion volumetrica al surtidor 1 con matraz de 20lts se cambia 1 pistola de 1 debido a que no retenia el flujo provocando que surtidor siguiera despachando sin presionar el gatillo se realizan pruebas de funcionamiento quedando operativo se pinta tapa spill regla completa y tk sin agua bocas verificadas 1 de 1 punto industrial queda operativo
# 	sentence  7 :  se efectua proceso de mantencion preventiva de estanque y surtidor se realiza revision limpieza y verificacion volumetrica al surtidor 12 con matraz de 20lts se detecta tapa spill rota se procede al cambio quedando operativo se pinta tapa spill se remarcan adhesivos bocaestanque regla completa y tk sin agua bocas verificadas 2 de 2 punto enap queda operativo se efectua proceso de mantencion preventiva de estanque y surtidor se realiza revision limpieza y verificacion volumetrica al surtidor 12 con matraz de 20lts se detecta tapa spill rota se procede al cambio quedando operativo se pinta tapa spill se remarcan adhesivos bocaestanque regla completa y tk sin agua bocas verificadas 2 de 2 punto enap queda operativo
# 	sentence  8 :  se efectua proceso de mantencion preventiva de estanque y surtidor se realiza revision limpieza y verificacion volumetrica al surtidor 12 con matraz de 20lts se pinta tapa spill regla completa y tk sin agua bocas verificadas 2 de 2 punto enap queda operativo se efectua proceso de mantencion preventiva de estanque y surtidor se realiza revision limpieza y verificacion volumetrica al surtidor 12 con matraz de 20lts se pinta tapa spill regla completa y tk sin agua bocas verificadas 2 de 2 punto enap queda operativo
# 	sentence  9 :  mp se realizara cuando se repare surtidor n 2 se efectua proceso de mantencion preventiva de estanque y surtidores se realiza revision limpieza y verificacion volumetrica a los surtidores 1 y 2 con matraz de 20 lts se cambian 2 filtros de alta capacidad debido a flujo lento mejorando considerablemente 65 litros por minutos aprox se reaprietan porta pistolas boca 1 y 2 ademas se remarcan adhesivos bocaestanque regla incompleta comienza desde los 200 litros aprox y estanque sin agua bocas dentro de la tolerancia establecida por la compania bocas verificadas 2 de 2 punto industrial queda operativo mp se realizara cuando se repare surtidor n 2 se efectua proceso de mantencion preventiva de estanque y surtidores se realiza revision limpieza y verificacion volumetrica a los surtidores 1 y 2 con matraz de 20 lts se cambian 2 filtros de alta capacidad debido a flujo lento mejorando considerablemente 65 litros por minutos aprox se reaprietan porta pistolas boca 1 y 2 ademas se remarcan adhesivos bocaestanque
# 	sentence  10 :  mp se realizara cuando se repare surtidor n 2 se efectua proceso de mantencion preventiva de estanque y surtidores se realiza revision limpieza y verificacion volumetrica a los surtidores 1 y 2 con matraz de 20 lts se cambian 2 filtros de alta capacidad debido a flujo lento mejorando considerablemente 65 litros por minutos aprox se reaprietan porta pistolas boca 1 y 2 ademas se remarcan adhesivos bocaestanque regla incompleta comienza desde los 200 litros aprox y estanque sin agua bocas dentro de la tolerancia establecida por la compania bocas verificadas 2 de 2 punto industrial queda operativo mp se realizara cuando se repare surtidor n 2 se efectua proceso de mantencion preventiva de estanque y surtidores se realiza revision limpieza y verificacion volumetrica a los surtidores 1 y 2 con matraz de 20 lts se cambian 2 filtros de alta capacidad debido a flujo lento mejorando considerablemente 65 litros por minutos aprox se reaprietan porta pistolas boca 1 y 2 ademas se remarcan adhesivos bocaestanque
# Cluster 11 : pendiente remplazo de 2 filtros disp 12d se realizo remplazo de 2 filtros de alta cap pendiente remplazo de 2 filtros disp 12d se realizo remplazo de 2 filtros de alta cap
# 	sentence  0 :  surt 12d se realizo remplazo de dos filtros de alta cap p14187 est 1d se realizo remplazo de una tapa 4 opw p16264 surt 12d se realizo remplazo de dos filtros de alta cap p14187 est 1d se realizo remplazo de una tapa 4 opw p16264
# 	sentence  1 :  se acude por atencion de disp no se encuentra encargado la atencion es de 0800 a 1600 hrs se coordinara una proxima visita disp 12 34 se realizo remplazo de cuatro filtros de alta cap p14187 se acude por atencion de disp no se encuentra encargado la atencion es de 0800 a 1600 hrs se coordinara una proxima visita disp 12 34 se realizo remplazo de cuatro filtros de alta cap p14187
# 	sentence  2 :  disp 12 34d se realizo remplazo de 4 filtros de alta cap p14187 disp 12 34d se realizo remplazo de 4 filtros de alta cap p14187
# 	sentence  3 :  pendiente remplazo de 2 filtros disp 12d se realizo remplazo de 2 filtros de alta cap pendiente remplazo de 2 filtros disp 12d se realizo remplazo de 2 filtros de alta cap
# Cluster 12 : pendiente el cambio de un motor trifasico a surtidor numero 2 se instala 1 motor trifasico surtidor n 2 al momento de operar equipo se detecta filtracion en bomba centrifuga se instala empaquetadura quedando en tiempo de secado para un buen sellado se repara equipo cambiando motor trifasico ya que se encontraba defectuoso produciendo corte energia electrica ademas se repara filtracion en bomba centrifuga quedando 100 operativo el surtidor pendiente el cambio de un motor trifasico a surtidor numero 2 se instala 1 motor trifasico surtidor n 2 al momento de operar equipo se detecta filtracion en bomba centrifuga se instala empaquetadura quedando en tiempo de secado para un buen sellado se repara equipo cambiando motor trifasico ya que se encontraba defectuoso produciendo corte energia electrica ademas se repara filtracion en bomba centrifuga quedando 100 operativo el surtidor
# 	sentence  0 :  en surtidor numero 2 se revisa consumo electrico de motor y se detecto fases sueltas desde guardamotor en tablero electrico hacia motor del surtidor se realizan pruebas con ventas y midiendo consumo electrico del motor no detectando anomalias una vez reapretado y reajustado rango y sistema electrico en surtidor numero 2 se revisa consumo electrico de motor y se detecto fases sueltas desde guardamotor en tablero electrico hacia motor del surtidor se realizan pruebas con ventas y midiendo consumo electrico del motor no detectando anomalias una vez reapretado y reajustado rango y sistema electrico
# 	sentence  1 :  pendiente el cambio de un motor trifasico a surtidor numero 2 se instala 1 motor trifasico surtidor n 2 al momento de operar equipo se detecta filtracion en bomba centrifuga se instala empaquetadura quedando en tiempo de secado para un buen sellado se repara equipo cambiando motor trifasico ya que se encontraba defectuoso produciendo corte energia electrica ademas se repara filtracion en bomba centrifuga quedando 100 operativo el surtidor pendiente el cambio de un motor trifasico a surtidor numero 2 se instala 1 motor trifasico surtidor n 2 al momento de operar equipo se detecta filtracion en bomba centrifuga se instala empaquetadura quedando en tiempo de secado para un buen sellado se repara equipo cambiando motor trifasico ya que se encontraba defectuoso produciendo corte energia electrica ademas se repara filtracion en bomba centrifuga quedando 100 operativo el surtidor
# 	sentence  2 :  se chquea falla y realiza el cambio de hn swiwel 1 con filtracion por uso se prueba quefando operativo en un 100 se chquea falla y realiza el cambio de hn swiwel 1 con filtracion por uso se prueba quefando operativo en un 100
# 	sentence  3 :  se realiza tension de polea y correa de motor quedando equipo operativo
# 	sentence  4 :  se realiza reapriete de conecciones elctrica s en tablero y se tensa correa de motor quedando equipo operativo
# 	sentence  5 :  se rev bomba piusi la cual mantiene funcionamiento normal se rev bomba piusi la cual mantiene funcionamiento normal
# 	sentence  6 :  se revisa surtidor doble por falla descrita y se detecta agua en caneria electrica que llega a la caja electrica del surtidor se sopletea para retirar el agua ademas se cambia diferencial en tablero electrico por tecnico de empresa vule se prueba cargando buses quedan operando normal se revisa surtidor doble por falla descrita y se detecta agua en caneria electrica que llega a la caja electrica del surtidor se sopletea para retirar el agua ademas se cambia diferencial en tablero electrico por tecnico de empresa vule se prueba cargando buses quedan operando normal
# Cluster 13 : se realiza limpieza y mantencion de filtro malla quedando equipo operativo
# 	sentence  0 :  se realiza limpieza y mantencion de valvulas check lomo tk y filtros malla quedando equipo operativo
# 	sentence  1 :  se realiza reparacion y mantencion de valvula retencion quedando equipo operativo
# 	sentence  2 :  se realiza reparacion y fijacion de palanca de accionamiento quedando equipo operativo
# 	sentence  3 :  se realiza limpieza y mantencion de filtro malla quedando equipo operativo
# Cluster 14 : se realiza revision de equipo encontrandose despacho operativo
# 	sentence  0 :  se realiza revision de equipo encontrandose despacho operativo
# 	sentence  1 :  se realiza revison de accesorios encontrandose despacho ok
# 	sentence  2 :  se realiza revison de equipo encontrandose despacho a buses ok
# Cluster 15 : se acude por falla en venteo segun informacion de encargado ellos no realizaron insidencia por este tema o el disp con falla venteo se encuentra en pilae canopy se acude por falla en venteo segun informacion de encargado ellos no realizaron insidencia por este tema o el disp con falla venteo se encuentra en pilae canopy
# 	sentence  0 :  se chequea falla detectando mecanismo de partida malo se revisa y realiza adaptacion para solucion quesando operativo en un 100 se chequea falla detectando mecanismo de partida malo se revisa y realiza adaptacion para solucion quesando operativo en un 100
# 	sentence  1 :  en visita realizada se observa ducto de venteo por medio de canopy lo cual genera complicacion para efectuar labores
# 	sentence  2 :  en visita realizada no se puede ejecutar labores ya que ducto de venteo pasa por el medio del canopy lo cual impide llegar para efectuar revision
# 	sentence  3 :  se acude por falla en venteo segun informacion de encargado ellos no realizaron insidencia por este tema o el disp con falla venteo se encuentra en pilae canopy se acude por falla en venteo segun informacion de encargado ellos no realizaron insidencia por este tema o el disp con falla venteo se encuentra en pilae canopy
# Elapsed time: 0.3002178669 seconds.

# %%
# Clusters representativos (con n = 16)
for cluster in range(nclusters):
    print ("\033[1mCluster ",cluster,":\033[0m",sentences[clusters[cluster][representativos[cluster]]])
# Out:
# Cluster  0 : ods mal emitida
# Cluster  1 : surt 1 d se realizo remplazo de un filtro de alta cap surt 1 d se realizo remplazo de un filtro de alta cap
# Cluster  2 : mantencion preventiva se calibran 2 de 2
# Cluster  3 : se realiza el cambio de 2 filtros spin on quedando equipo operativo
# Cluster  4 : os mal emitida
# Cluster  5 : mantencion preventiva se realizara bajo ot 5
# Cluster  6 : en surtidores 1 y 2 diesel se cambia 02 filtros p14187 quedando 100 operativos en surtidores 1 y 2 diesel se cambia 02 filtros p14187 quedando 100 operativos
# Cluster  7 : se realiza el cambio de 2 codos giratorio 1 2 swivel 1 y 2 filtros alta capacidad quedando equipo operativo
# Cluster  8 : en surtidor numero 1 se detecto y se cambiaron 02 pistolas convencionales de 1 con sensor malo se revisan y se limpian los dos filtros de malla de entrada de bomba se ajust a presion general realizando pruebas con preset y con ventas dispensadores queda con despacho normal repuestos utilizados 02 pistolas convencionales de 1 p14781 en surtidor numero 1 se detecto y se cambiaron 02 pistolas convencionales de 1 con sensor malo se revisan y se limpian los dos filtros de malla de entrada de bomba se ajust a presion general realizando pruebas con preset y con ventas dispensadores queda con despacho normal repuestos utilizados 02 pistolas convencionales de 1 p14781
# Cluster  9 : se realiza el cambio de 1 tapa adaptdor descarga 4 quedando equipo operativo
# Cluster  10 : mp se realizara cuando se repare surtidor n 2 se efectua proceso de mantencion preventiva de estanque y surtidores se realiza revision limpieza y verificacion volumetrica a los surtidores 1 y 2 con matraz de 20 lts se cambian 2 filtros de alta capacidad debido a flujo lento mejorando considerablemente 65 litros por minutos aprox se reaprietan porta pistolas boca 1 y 2 ademas se remarcan adhesivos bocaestanque regla incompleta comienza desde los 200 litros aprox y estanque sin agua bocas dentro de la tolerancia establecida por la compania bocas verificadas 2 de 2 punto industrial queda operativo mp se realizara cuando se repare surtidor n 2 se efectua proceso de mantencion preventiva de estanque y surtidores se realiza revision limpieza y verificacion volumetrica a los surtidores 1 y 2 con matraz de 20 lts se cambian 2 filtros de alta capacidad debido a flujo lento mejorando considerablemente 65 litros por minutos aprox se reaprietan porta pistolas boca 1 y 2 ademas se remarcan adhesivos bocaestanque
# Cluster  11 : pendiente remplazo de 2 filtros disp 12d se realizo remplazo de 2 filtros de alta cap pendiente remplazo de 2 filtros disp 12d se realizo remplazo de 2 filtros de alta cap
# Cluster  12 : pendiente el cambio de un motor trifasico a surtidor numero 2 se instala 1 motor trifasico surtidor n 2 al momento de operar equipo se detecta filtracion en bomba centrifuga se instala empaquetadura quedando en tiempo de secado para un buen sellado se repara equipo cambiando motor trifasico ya que se encontraba defectuoso produciendo corte energia electrica ademas se repara filtracion en bomba centrifuga quedando 100 operativo el surtidor pendiente el cambio de un motor trifasico a surtidor numero 2 se instala 1 motor trifasico surtidor n 2 al momento de operar equipo se detecta filtracion en bomba centrifuga se instala empaquetadura quedando en tiempo de secado para un buen sellado se repara equipo cambiando motor trifasico ya que se encontraba defectuoso produciendo corte energia electrica ademas se repara filtracion en bomba centrifuga quedando 100 operativo el surtidor
# Cluster  13 : se realiza limpieza y mantencion de filtro malla quedando equipo operativo
# Cluster  14 : se realiza revision de equipo encontrandose despacho operativo
# Cluster  15 : se acude por falla en venteo segun informacion de encargado ellos no realizaron insidencia por este tema o el disp con falla venteo se encuentra en pilae canopy se acude por falla en venteo segun informacion de encargado ellos no realizaron insidencia por este tema o el disp con falla venteo se encuentra en pilae canopy

# %%
# Plot - Cantidad de sentences por cluster
len_clusters(dic=clusters,n = nclusters, save = True, namecol=columna, nro_top=elemento)

# %% [markdown]
# # III. REQUERIMIENTOS

# %%
# SELECCIONANDO UN ESTADO OT ('PENDIENTE')
df = df_total[df_total[columna] == elemento] 
sentences = [sent for sent in df['Requerimiento']]
len(sentences)
# Out:
# 151

# %%
# Extracto req 
sentences[:2]
# Out:
# ['area de atencion breakaway esta suelto y filtra combustible solicitado por jonathan ibanez fono',
#  'area de atencion surtidor doble funciona no despacha solicitado por walter pafian fono']

# %%
# %%time
# Identificando el número óptimo de clústers por medio del método del Elbow
elbow_method(sentences, save = False)
# Out:
# Número óptimo de clusters: 14
# Wall time: 5.68 s

# %%
# %%time
# Identificando el número óptimo de clústers por medio del Análisis de Silueta General
silhouette(sentences, save = False)
# Out:
# Número óptimo de clusters: 10
# Wall time: 5.73 s

# %%
# %%time
# Identificando el número óptimo de clústers por medio del Análisis de Silueta Particular (por tópico)
silhouette_analysis(sentences, n_clusters=[10,18,22,26], name= elemento+'Req', save=False)
# Out:
# Wall time: 1.33 s

# %%
# Ejecutando el algoritmo Kmeans para el número óptimo de clústers 
print('\033[1mCLUSTERS \n\033[0m')
start_time = time()

nclusters= 10
clusters,representativos = cluster_sentences(sentences, nclusters)

for cluster in range(nclusters):
    print (f"\033[1mCluster {cluster} : {sentences[clusters[cluster][representativos[cluster]]]}\033[0m")
    for i,sentence in enumerate(clusters[cluster]):
        print ("\tsentence ",i,": ",sentences[sentence])

elapsed_time = time() - start_time
print("\033[1mElapsed time: %.10f seconds.\033[0m" % elapsed_time)
# Out:
# CLUSTERS
#
# Cluster 0 : programa mantencion preventiva
# 	sentence  0 :  programa mantencion preventiva
# 	sentence  1 :  programa mantencion preventiva
# 	sentence  2 :  programa mantencion preventiva
# 	sentence  3 :  programa mantencion preventiva
# 	sentence  4 :  programa mantencion preventiva
# 	sentence  5 :  programa mantencion preventiva
# 	sentence  6 :  programa mantencion preventiva
# 	sentence  7 :  programa mantencion preventiva
# 	sentence  8 :  programa mantencion preventiva
# Cluster 1 : fuga de combustible por el codo de torcion de la pistola
# 	sentence  0 :  gatillo de la pistola no danado no despacha combustible
# 	sentence  1 :  filtra combustible desde la pistola cuando se realiza la carga de combustible
# 	sentence  2 :  no despacha combustible regula emerg
# 	sentence  3 :  se demora despachar combustible
# 	sentence  4 :  fuga de combustible desde el breakaway ademas la otra pistola no funciona al accionar la palanca
# 	sentence  5 :  codo de torcion danado presenta fuga de combustible se solicita mantencion con caracter de urgente
# 	sentence  6 :  fuga de combustible por eel codo de torcion
# 	sentence  7 :  perdida de combustible por el codo de torcion
# 	sentence  8 :  fuga de combustible por el codo de torcion de la pistola
# 	sentence  9 :  fuga por el codo de torcion de la pistola
# 	sentence  10 :  fuga de combustible por las dos pistolas
# 	sentence  11 :  surtidor con problemas no dispensa combustible
# 	sentence  12 :  fuga de combustible a traves del codo de la pistola isla abierta desde las 800 a las 1600 hrs
# Cluster 2 : programacion mantencion preventiva
# 	sentence  0 :  programacion mantencion preventiva
# 	sentence  1 :  programacion mantencion preventiva
# 	sentence  2 :  programacion mantencion preventiva
# 	sentence  3 :  programacion mantencion preventiva
# 	sentence  4 :  programacion mantencion preventiva
# 	sentence  5 :  programacion mantencion preventiva
# 	sentence  6 :  programacion mantencion preventiva
# 	sentence  7 :  programacion mantencion preventiva
# 	sentence  8 :  programacion mantencion preventiva
# 	sentence  9 :  programacion mantencion preventiva
# 	sentence  10 :  programacion mantencion preventiva
# 	sentence  11 :  programacion mantencion preventiva
# 	sentence  12 :  programacion mantencion preventiva
# 	sentence  13 :  programacion mantencion preventiva
# 	sentence  14 :  programacion mantencion preventiva
# 	sentence  15 :  programacion mantencion preventiva
# 	sentence  16 :  programacion mantencion preventiva
# 	sentence  17 :  programacion mantencion preventiva
# 	sentence  18 :  programacion mantencion preventiva
# 	sentence  19 :  programacion mantencion preventiva
# 	sentence  20 :  programacion mantencion preventiva
# 	sentence  21 :  programacion mantencion preventiva
# 	sentence  22 :  programacion mantencion preventiva
# 	sentence  23 :  programacion mantencion preventiva
# 	sentence  24 :  programacion mantencion preventiva
# 	sentence  25 :  programacion mantencion preventiva
# 	sentence  26 :  programacion mantencion preventiva
# 	sentence  27 :  programacion mantencion preventiva
# 	sentence  28 :  programacion mantencion preventiva
# 	sentence  29 :  programacion mantencion preventiva
# 	sentence  30 :  programacion mantencion preventiva
# 	sentence  31 :  programacion mantencion preventiva
# 	sentence  32 :  programacion mantencion preventiva
# 	sentence  33 :  programacion mantencion preventiva
# 	sentence  34 :  programacion mantencion preventiva
# 	sentence  35 :  programacion mantencion preventiva
# 	sentence  36 :  programacion mantencion preventiva
# 	sentence  37 :  programacion mantencion preventiva
# 	sentence  38 :  programacion mantencion preventiva
# 	sentence  39 :  programacion mantencion preventiva
# 	sentence  40 :  programacion mantencion preventiva
# 	sentence  41 :  programacion mantencion preventiva
# 	sentence  42 :  programacion mantencion preventiva
# 	sentence  43 :  programacion mantencion preventiva
# 	sentence  44 :  programacion mantencion preventiva
# 	sentence  45 :  programacion mantencion preventiva
# 	sentence  46 :  programacion mantencion preventiva
# 	sentence  47 :  programacion mantencion preventiva
# 	sentence  48 :  programacion mantencion preventiva
# 	sentence  49 :  programacion mantencion preventiva
# 	sentence  50 :  programacion mantencion preventiva
# 	sentence  51 :  programacion mantencion preventiva
# 	sentence  52 :  programacion mantencion preventiva
# 	sentence  53 :  programacion mantencion preventiva
# 	sentence  54 :  programacion mantencion preventiva
# 	sentence  55 :  programacion mantencion preventiva
# 	sentence  56 :  programacion mantencion preventiva
# 	sentence  57 :  programacion mantencion preventiva
# 	sentence  58 :  programacion mantencion preventiva
# 	sentence  59 :  programacion mantencion preventiva
# 	sentence  60 :  programacion mantencion preventiva
# Cluster 3 : surtidor despacha lento se solicita mantencion
# 	sentence  0 :  area de atencion surtidor doble funciona no despacha solicitado por walter pafian fono
# 	sentence  1 :  area de atencion surtidor despacha muy lento ademas el display del surtidor se encuentra sin luz solicitado por jonathan ibanez fono
# 	sentence  2 :  area de atencion se necesita calibracion del surtidor ya que estan con muchas diferencias solicitado por david cisternas fono
# 	sentence  3 :  area de atencion surtidor no funciona solicitado por jmz fono
# 	sentence  4 :  area de atencion necesita de forma urgente cambio de filtros es un terminal muy grande por lo que el surtidor lento provoca grandes problemas de congestion solicitado por rodrigo aedo fono
# 	sentence  5 :  surtidor despacha demasado lento lo que provoca aotchamiento dentro del terminal
# 	sentence  6 :  necesidad urgente de cambio de filtros
# 	sentence  7 :  surtidor despacha muy lento lo que provoca atochamiento en el terminal
# 	sentence  8 :  surtidor malo
# 	sentence  9 :  el surtidor despacha muy lento lo que provoca un gran problema dentro del terminal se solicita acudir lo antes posible
# 	sentence  10 :  se solicita mantencion a surtidores ya que estos despachan lento grasias
# 	sentence  11 :  surtidores despachan muy lento se solicita servicio tecnico urgente gracias
# 	sentence  12 :  necesitamos cambiar la pistola por una pistola de boca chica
# 	sentence  13 :  surtidores despachan lento asistir con urgencia porfavor
# 	sentence  14 :  se pide visita urgente equipo tapados venta lenta llevar filtros de remplazo
# 	sentence  15 :  asistir lo antes posible dado que esl surtidor despacha de manera muy lenta
# 	sentence  16 :  cliente senala que el surtidor despacha lento los filtros estan sucios deben ser cambiados
# 	sentence  17 :  surtidor despacha lento se solicita mantencion
# 	sentence  18 :  surtidor despacha demasiado lento provocando atochamiento en la isla de combustible se solicita acudir lo mas pronto posible
# 	sentence  19 :  se solicita cambio de filtro surtidor despacha lento
# 	sentence  20 :  dos surtidores despachan lento emergencia
# 	sentence  21 :  el surtidor despacha muy lento necesita cambio de filtro
# 	sentence  22 :  se solicita visita urgente paracambio de filtro en los 4 surtidores
# 	sentence  23 :  ademas de presentar fuga por los codos de las pistolas el surtidor esta muy lento por lo que considerar el cambio de filtros
# 	sentence  24 :  surtidor de ad blue no despacha producto
# 	sentence  25 :  surtidor despacha muy lento necesita cambio de filtro
# 	sentence  26 :  surtidor necesita cambio de filtro despacha muy lento
# Cluster 4 : coordinar barrido de linea tk de pd y revision de valvula de presion y vacio coordinar camion alza hombre segun corresponda
# 	sentence  0 :  coordinar barrido de linea tk de pd y revision de valvula de presion y vacio coordinar camion alza hombre segun corresponda
# 	sentence  1 :  coordinar barrido de linea tk de pd y revision de valvula de presion y vacio coordinar camion alza hombre segun corresponda
# Cluster 5 : tapa de descarga quebrada
# 	sentence  0 :  area de atencion tapa camara quebrada solicitado por david cisternas fono
# 	sentence  1 :  tapa de descarga quebrada
# 	sentence  2 :  tapa de descarga quebrada
# 	sentence  3 :  descarga demasiado lenta hay que abrir todas las tapas para evitar devolucion de producto linea de ventilacion tapada urgente revisar
# Cluster 6 : pistola no corta urgente visita
# 	sentence  0 :  pistola no corta urgente visita
# 	sentence  1 :  pistola no corta
# 	sentence  2 :  corte electrico sin despacho todo el p i emergencia
# 	sentence  3 :  corte en surtidor emergencia
# Cluster 7 : area de atencion ambas pistolas despachan demasiado lento lo que provoca gran atochamiento dentro del terminal ademas de derrame por que las pistolan no cortan se solicita acudir lo antes posible solicitado por jonathan ibanez fono
# 	sentence  0 :  area de atencion breakaway esta suelto y filtra combustible solicitado por jonathan ibanez fono
# 	sentence  1 :  area de atencion filtracion de combustible por la pistola se solicita por favor visita urgente gracias solicitado por jonathan ibanez fono
# 	sentence  2 :  area de atencion filtracion de combustible pistola solicitado por jonathan ibanez fono
# 	sentence  3 :  area de atencion ambas pistolas despachan demasiado lento lo que provoca gran atochamiento dentro del terminal ademas de derrame por que las pistolan no cortan se solicita acudir lo antes posible solicitado por jonathan ibanez fono
# 	sentence  4 :  area de atencion surtidor no despacha por favor acudir lo antes posible solicitado por jonathan ibanez fono
# 	sentence  5 :  area de atencion pistola filtra por el codo necesitamos que acudan urgentemente solicitado por jonathan ibanez fono
# 	sentence  6 :  pistola danada a parte ya no corta por favor acudir lo antes posible por que al trabajar con una sola pistola complica mucho la operacion
# 	sentence  7 :  se solicita servicio tecnico el horario para vuestra visita es desde las 0800 hasta las 1600 de ante mano gracias
# 	sentence  8 :  filtra combustible por el codo de la pistola favor asistir desde las 1400 en adelante
# Cluster 8 : area de atencion mantencion preventiva solicitado por fono
# 	sentence  0 :  area de atencion mantencion preventiva solicitado por fono
# 	sentence  1 :  area de atencion mantencion preventiva solicitado por fono
# 	sentence  2 :  area de atencion mantencion preventiva solicitado por fono
# 	sentence  3 :  area de atencion mantencion preventiva solicitado por fono
# 	sentence  4 :  area de atencion mantencion preventiva solicitado por fono
# 	sentence  5 :  area de atencion mantencion preventiva solicitado por fono
# 	sentence  6 :  area de atencion mantencion preventiva solicitado por fono
# 	sentence  7 :  area de atencion mantencion preventiva solicitado por fono
# 	sentence  8 :  area de atencion mantencion preventiva solicitado por fono
# 	sentence  9 :  mantencion preventiva
# Cluster 9 : surtidor sin despacho llamado emergencia 29 8
# 	sentence  0 :  area de atencion surtidor falla solicitado por jmz fono
# 	sentence  1 :  area de atencion problemas con la turbina de bomba sumergida solicitado por danilo cisternas fono
# 	sentence  2 :  iluminacion interna no funciona y la isla trabaja de noche con lo que dificulta mucho su labor
# 	sentence  3 :  no sale cl regularizacion emergencia
# 	sentence  4 :  reemplazar colgante
# 	sentence  5 :  llamado emergencia equipo con fallas
# 	sentence  6 :  atencion de emergencia 24 12 18 atiende sgs
# 	sentence  7 :  llamado emergencia 22 12 a las 920 horas equipo con filtracion interna problema correa y lentitud despacho
# 	sentence  8 :  se solicita servicio tecnico falla la pistola 2
# 	sentence  9 :  manguera rota atiende de emergencia sgs 23 11
# 	sentence  10 :  surtidor sin despacho llamado emergencia 29 8
# 	sentence  11 :  falla electrica favor asistir con urgencia
# Elapsed time: 0.1662189960 seconds.

# %%
# Clusters representativos (con n = 10)
for cluster in range(nclusters):
    print ("\033[1mCluster ",cluster,":\033[0m",sentences[clusters[cluster][representativos[cluster]]])
# Out:
# Cluster  0 : programa mantencion preventiva
# Cluster  1 : fuga de combustible por el codo de torcion de la pistola
# Cluster  2 : programacion mantencion preventiva
# Cluster  3 : surtidor despacha lento se solicita mantencion
# Cluster  4 : coordinar barrido de linea tk de pd y revision de valvula de presion y vacio coordinar camion alza hombre segun corresponda
# Cluster  5 : tapa de descarga quebrada
# Cluster  6 : pistola no corta urgente visita
# Cluster  7 : area de atencion ambas pistolas despachan demasiado lento lo que provoca gran atochamiento dentro del terminal ademas de derrame por que las pistolan no cortan se solicita acudir lo antes posible solicitado por jonathan ibanez fono
# Cluster  8 : area de atencion mantencion preventiva solicitado por fono
# Cluster  9 : surtidor sin despacho llamado emergencia 29 8

# %%
# Plot - Cantidad de sentences por cluster
len_clusters(dic=clusters,n = nclusters, save = False)
